# %%
#hide
#skip
! [ -e /content ] && pip install -Uqq fastai  # upgrade fastai on colab

# %% [markdown]
# # Tutorial - Using fastai on a custom new task
#
# > How to use the mid-level API for data collection, model creation and training

# %%
#all_slow

# %% [markdown]
# In this tutorial, we will see how to deal with a new type of task using the middle layer of the fastai library. The example we will use is a Siamese network, that takes two images and determine if they are of the same class or not. In particular we will see:
#
# - how to quickly get `DataLoaders` from a standard PyTorch `Datasets`
# - how to adapt this in a `Transform` to get some of the show features of fastai
# - how to add some new behavior to `show_batch`/`show_results` for a custom task
# - how to write a custom `DataBlock`
# - how to create your own model from a pretrained model
# - how to pass along a custom `splitter` to `Learner` to take advantage of transfer learning

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# To make our data ready for training a model, we need to create a `DataLoaders` object in fastai. It is just a wrapper around a training `DataLoader` and a validation `DataLoader`, so if you already have your own PyTorch dataloaders, you can create such an object directly.
#
# Here we don't have anything ready yet. Usually, when using PyTorch, the first step is to create a `Dataset` that is then wrapped inside a `DataLoader`. We will do this first, then see how to change this `Dataset` into a `Transform` that will let us take advantage of fastai's functionality for showing a batch or using data augmentation on the GPU. Lastly we will see how we can customize the data block API and create our own new `TransformBlock`.

# %% [markdown]
# ### Purely in PyTorch

# %% [markdown]
# To begin with, we will only use PyTorch and PIL to create a `Dataset` and see how to get this inside fastai. The only helper functions from fastai we will use are `untar_data` (to download and untar the dataset) and `get_image_files` (that looks for all images in a folder recursively). Here, we will use the [Oxford-IIIT Pet Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/).

# %%
from fastai.data.external import untar_data,URLs
from fastai.data.transforms import get_image_files

# %% [markdown]
# `untar_data` returns a `pathlib.Path` object with the location of the decompressed dataset, and in this case, all the images are in an images subfolder:

# %%
path = untar_data(URLs.PETS)
files = get_image_files(path/"images")
files[0]
# Out:
# Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Birman_187.jpg')

# %% [markdown]
# We can open the first image with PIL and have a look at it:

# %%
import PIL

# %%
img = PIL.Image.open(files[0])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F316E6ADD90>

# %% [markdown]
# Let's wrap all the standard preprocessing (resize, conversion to tensor, dividing by 255 and reordering of the channels) in one helper function:

# %%
import torch
import numpy as np

# %%
def open_image(fname, size=224):
    img = PIL.Image.open(fname).convert('RGB')
    img = img.resize((size, size))
    t = torch.Tensor(np.array(img))
    return t.permute(2,0,1).float()/255.0

# %%
open_image(files[0]).shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# We can see the label of our image is in the filename, before the last `_` and some number. We can then use a regex expression to create a label function:

# %%
import re

# %%
def label_func(fname):
    return re.match(r'^(.*)_\d+.jpg$', fname.name).groups()[0]

label_func(files[0])
# Out:
# 'Birman'

# %% [markdown]
# Now lets gather all unique labels:

# %%
labels = list(set(files.map(label_func)))
len(labels)
# Out:
# 37

# %% [markdown]
# So we have 37 different breeds of pets. To create our Siamese datasets, we will need to create tuple of images for inputs and the target will be `True` if the images are of the same class, `False` otherwise. It will be useful to have a mapping from class to list of filenames of that class, to quickly pick a random image for any class.

# %%
lbl2files = {l: [f for f in files if label_func(f) == l] for l in labels}

# %% [markdown]
# Now we are ready to create our datasets. For the training set, we will go through all our training filenames for the first image, then pick randomly:
#
# - a filename of the same class for the second image (with probability 0.5)
# - a filename of a different class for the second image (with probability 0.5)
#
# We will go through that random draw each time we access an item, to have as many samples as possible. For the validation set however, we will fix that random draw once and for all (otherwise we will validate on a different dataset at each epoch).

# %%
import random

# %%
class SiameseDataset(torch.utils.data.Dataset):
    def __init__(self, files, is_valid=False):
        self.files,self.is_valid = files,is_valid
        if is_valid: self.files2 = [self._draw(f) for f in files]
        
    def __getitem__(self, i):
        file1 = self.files[i]
        (file2,same) = self.files2[i] if self.is_valid else self._draw(file1)
        img1,img2 = open_image(file1),open_image(file2)
        return (img1, img2, torch.Tensor([same]).squeeze())
    
    def __len__(self): return len(self.files)
    
    def _draw(self, f):
        same = random.random() < 0.5
        cls = label_func(f)
        if not same: cls = random.choice([l for l in labels if l != cls]) 
        return random.choice(lbl2files[cls]),same

# %% [markdown]
# We just need to split our filenames between a training and validation set to use it.

# %%
idxs = np.random.permutation(range(len(files)))
cut = int(0.8 * len(files))
train_files = files[idxs[:cut]]
valid_files = files[idxs[cut:]]

# %% [markdown]
# We can then use it to create datasets.

# %%
train_ds = SiameseDataset(train_files)
valid_ds = SiameseDataset(valid_files, is_valid=True)

# %% [markdown]
# All of the above would be different for your custom problem, the main point is that as soon as you have some `Dataset`s, you can create a fastai's `DataLoaders` with the following factory method:

# %%
from fastai.data.core import DataLoaders

# %%
dls = DataLoaders.from_dsets(train_ds, valid_ds)

# %% [markdown]
# You can then use this `DataLoaders` object in a `Learner` and start training. Most methods that don't rely on showing something (e.g. `DataLoaders.show_batch` and `Learner.show_results` for instance) should work. For instance, you can get and inspect a batch with:

# %%
b = dls.one_batch()

# %% [markdown]
# If you want to use the GPU, you can just write:

# %%
dls = dls.cuda()

# %% [markdown]
# Now, what is a bit annoying is that we have to rewrite everything that is already in fastai if we want to normalize our images, or apply data augmentation. With minimal changes to the code we wrote, we can still access all of that and get all the show method to work as a cherry on the top. Let's see how.

# %% [markdown]
# ### Using the mid-level API

# %% [markdown]
# When you have a custom dataset like before, you can easily convert it into a fastai `Transform` by just changing the `__getitem__` function to <code>encodes</code>. In general, a `Transform` in fastai calls the <code>encodes</code> method when you apply it on an item (a bit like PyTorch modules call `forward` when applied on something) so this will transform your python dataset in a function that transforms integer to your data.
#
# If you then return a tuple (or a subclass of a tuple), and use fastai's semantic type, you can then apply any other fastai's transform on your data and it will be dispatched properly. Let's see how that works:

# %%
from fastai.vision.all import *

# %%
class SiameseTransform(Transform):
    def __init__(self, files, is_valid=False):
        self.files,self.is_valid = files,is_valid
        if is_valid: self.files2 = [self._draw(f) for f in files]
        
    def encodes(self, i):
        file1 = self.files[i]
        (file2,same) = self.files2[i] if self.is_valid else self._draw(file1)
        img1,img2 = open_image(file1),open_image(file2)
        return (TensorImage(img1), TensorImage(img2), torch.Tensor([same]).squeeze())
    
    def _draw(self, f):
        same = random.random() < 0.5
        cls = label_func(f)
        if not same: cls = random.choice([l for l in labels if l != cls]) 
        return random.choice(lbl2files[cls]),same

# %% [markdown]
# So three things changed:
#
# - the `__len__` disappeared, we won't need it
# - `__getitem___` became <code>encodes</code>
# - we return `TensorImage` for our images
#
# How do we build a dataset with this? We will use `TfmdLists`. It's just an object that lazily applies a collection of `Transform`s on a list. Here since our transform takes integers, we will pass simple ranges for this list.

# %%
train_tl= TfmdLists(range(len(train_files)), SiameseTransform(train_files))
valid_tl= TfmdLists(range(len(valid_files)), SiameseTransform(valid_files, is_valid=True))

# %% [markdown]
# Then, when we create a `DataLoader`, we can add any transform we like. fastai replaces the PyTorch `DataLoader` with its own version that has more hooks (but is fully compatible with PyTorch). The transforms we would like to be applied to items should be passed to `after_item`, the one we would like to be applied on a batch of data should be passed to `after_batch`.

# %%
dls = DataLoaders.from_dsets(train_tl, valid_tl, 
                             after_batch=[Normalize.from_stats(*imagenet_stats), *aug_transforms()])
dls = dls.cuda()

# %% [markdown]
# So with little change, we can use fastai normalization and data augmentation. If we are ready to do a bit more additional coding, we can even get the show behavior to work properly.

# %% [markdown]
# ### Making show work

# %% [markdown]
# The show methods in fastai all rely on some types being able to show themselves. Additionally, some transforms that need to be reversed for showing purposes (like changing a category to an index, or normalizing) have a <code>decodes</code> method to undo what their encodes did. In general, fastai will call those decodes method until it arrives at a type that knows how to show itself, then call the show method on this type.
#
# So to make this work, let's first create a new type with a show method!

# %%
class SiameseImage(fastuple):
    def show(self, ctx=None, **kwargs): 
        if len(self) > 2:
            img1,img2,similarity = self
        else:
            img1,img2 = self
            similarity = 'Undetermined'
        if not isinstance(img1, Tensor):
            if img2.size != img1.size: img2 = img2.resize(img1.size)
            t1,t2 = tensor(img1),tensor(img2)
            t1,t2 = t1.permute(2,0,1),t2.permute(2,0,1)
        else: t1,t2 = img1,img2
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), title=similarity, ctx=ctx, **kwargs)

# %% [markdown]
# There is bit of code in the first part of the test that you can ignore, it's mostly to make the show method work on PIL Image as well as tensors. The main stuff happens in the last two lines: we create a black line of 10 pixels and show the tensor with our two images concatenated, with the black line in the middle. In general, `ctx` represents the object where we will show our thing. In this case, it could be a given matplotlib axis.
#
# Let's see an example:

# %%
img = PILImage.create(files[0])
img1 = PILImage.create(files[1])
s = SiameseImage(img, img1, False)
s.show();

# %% [markdown]
# Note that we used the fastai type `PILImage` instead of a PIL.Image. That is to get access to fastai's transforms. For instance, we can use `Resize` and `ToTensor` directly on our `SiamesImage`. Since it subclasses tuple, those transforms are dispatched and applied to the part that make sense (the `PILImage`s, not the bool).

# %%
tst = Resize(224)(s)
tst = ToTensor()(tst)
tst.show();

# %% [markdown]
# Now let's rewrite a bit our previous transform. Instead of taking integers, we can take files directly for instance. Also, in fastai, splits are usually handled by helper functions that return two lists of integers (the ones in the training set and the ones in the validation set), so let's adapt a bit the code from before to have the validation images drawn once and for all. We also need to add in the mapping dictionaries from class to list of filenames of that class, separately for the train and valid splits, so that there is total separation between the training and validation sets, i.e. 'train' files should only draw samples from train split; 'valid' from valid split.

# %%
class SiameseTransform(Transform):
    def __init__(self, files, splits):
        self.splbl2files = [{l: [f for f in files[splits[i]] if label_func(f) == l] for l in labels}
                          for i in range(2)]
        self.valid = {f: self._draw(f,1) for f in files[splits[1]]}
    def encodes(self, f):
        f2,same = self.valid.get(f, self._draw(f,0))
        img1,img2 = PILImage.create(f),PILImage.create(f2)
        return SiameseImage(img1, img2, same)
    
    def _draw(self, f, split=0):
        same = random.random() < 0.5
        cls = label_func(f)
        if not same: cls = random.choice(L(l for l in labels if l != cls)) 
        return random.choice(self.splbl2files[split][cls]),same

# %% [markdown]
# Then we create our splits using a `RandomSplitter`:

# %%
splits = RandomSplitter()(files)
tfm = SiameseTransform(files, splits)

# %% [markdown]
# And we test that tfm.valid does not contain items from the train split:

# %%
valids = [v[0] for k,v in tfm.valid.items()]      
assert not [v for v in valids if v in files[splits[0]]]

# %% [markdown]
# And we can pass those splits to `TfmdLists`, which will then create the validation and the training set for us.

# %%
tls = TfmdLists(files, tfm, splits=splits)

# %% [markdown]
# We can now use methods like `show_at`:

# %%
show_at(tls.valid, 0)
# Out:
# <AxesSubplot:title={'center':'True'}>

# %% [markdown]
# And we can create a `DataLoaders` like before, by adding our custom transforms for `after_item` and `after_batch`.

# %%
dls = tls.dataloaders(after_item=[Resize(224), ToTensor], 
                      after_batch=[IntToFloatTensor, Normalize.from_stats(*imagenet_stats)])

# %% [markdown]
# If we try just now, `show_batch` will not quite work: the default behavior relies on some data build using data blocks, and we used one big transform for everything. In consequence, instead of having an input with a certain type and an output of a certain type, we have one big type for the whole data. If we look at a batch, we can see that the fastai library has propagated that type for us through every transform and batching operation:

# %%
b = dls.one_batch()
type(b)
# Out:
# __main__.SiameseImage

# %% [markdown]
# When we call `show_batch`, the fastai library will realize the batch as a whole has a show method, so it must know how to show itself. It will send that batch directly to the type-dispatched function `show_batch`. The signature of this function is the following:
# ```python
# show_batch(x, y, samples, ctxs=None, **kwargs)
# ```
# where the kwargs are specific to the application (here we will have `nrows`, `ncols` and `figsize` for instance). In our case, the batch will be sent as a whole to `x` and `y` and `samples` will be `None` (those arguments are used when the batch does not have a type that knows how to show itself, see the next section).
#
# To write our custom `show_batch` we just need to use the type annotation on `x` like this:

# %%
@typedispatch
def show_batch(x:SiameseImage, y, samples, ctxs=None, max_n=6, nrows=None, ncols=2, figsize=None, **kwargs):
    if figsize is None: figsize = (ncols*6, max_n//ncols * 3)
    if ctxs is None: ctxs = get_grid(min(x[0].shape[0], max_n), nrows=None, ncols=ncols, figsize=figsize)
    for i,ctx in enumerate(ctxs): SiameseImage(x[0][i], x[1][i], ['Not similar','Similar'][x[2][i].item()]).show(ctx=ctx)

# %% [markdown]
# We will see in the next section that the behavior is different when we have a batch that does not have a show method (which is the case most of the time, only the input and target of the batch have those show methods). In that case, the arguments `y` and `samples` are useful. Here, everything is in `x`, because since the batch knows how to show itself as a whole, it is sent as a whole.
#
# Here, we create a list of matplotlib axis with the utility function `get_grid` then pass it along to all `SiameseImage.show`. Let's see how this looks in practice:

# %%
b = dls.one_batch()

# %%
dls._types
# Out:
# {__main__.SiameseImage: [fastai.torch_core.TensorImage,
#   fastai.torch_core.TensorImage,
#   torch.Tensor]}

# %%
dls.show_batch()

# %% [markdown]
# And we will see in the training section it's as easy to make a custom `show_results`. Now let's see how we could have written our own data block.

# %% [markdown]
# ### Writing your custom data block

# %% [markdown]
# The siamese problem is just a particular case of problem with our inputs being a tuple of images and our target being a category. If the type "tuple of images" comes again in other problems with a different target, it might be useful to create a custom block for it, to be able to leverage the power of the data block API.
#
# **NB:** if your problem only has one particular setup and you don't need the modular aspect for various targets, what we did before is perfectly fine and you should look no further.
#
# Let's create a type to represent our tuple of two images:

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %% [markdown]
# Since it's a subclass of `fastuple`, `Transform`s will be applied over each part of the tuple. For instance `ToTensor` will convert this `ImageTuple` to a tuple of `TensorImage`s:

# %%
img = ImageTuple.create((files[0], files[1]))
tst = ToTensor()(img)
type(tst[0]),type(tst[1])
# Out:
# (fastai.torch_core.TensorImage, fastai.torch_core.TensorImage)

# %% [markdown]
# In the show method, we did not bother with non-tensor elements this time (we could copy and paste the same code as before). Showing assumes we have a resize transform and that we convert the images to tensors in our procesing pipeline:

# %%
img1 = Resize(224)(img)
tst = ToTensor()(img1)
tst.show();

# %% [markdown]
# We can now define a block associated to `ImageTuple` that we will use in the data block API. A block is basically a set of default transforms, here we specify how to create the `ImageTuple` and the `IntToFloatTensor` transform necessary for image preprocessing:

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %% [markdown]
# To gather our data with the data block API we will use the following functions:

# %%
splits_files = [files[splits[i]] for i in range(2)]
splits_sets = mapped(set, splits_files)

# %%
def get_split(f):
    for i,s in enumerate(splits_sets):
        if f in s: return i
    raise ValueError(f'File {f} is not presented in any split.')

# %%
splbl2files = [{l: [f for f in s if label_func(f) == l] for l in labels} for s in splits_sets]

# %%
def splitter(items): 
    def get_split_files(i): return [j for j,(f1,f2,same) in enumerate(items) if get_split(f1)==i]
    return get_split_files(0),get_split_files(1)

# %%
def draw_other(f):
    same = random.random() < 0.5
    cls = label_func(f)
    split = get_split(f)
    if not same: cls = random.choice(L(l for l in labels if l != cls)) 
    return random.choice(splbl2files[split][cls]),same

# %%
def get_tuples(files): return [[f, *draw_other(f)] for f in files]

# %% [markdown]
# And we are ready to define our block:

# %%
def get_x(t): return t[:2]
def get_y(t): return t[2]

# %%
siamese = DataBlock(
    blocks=(ImageTupleBlock, CategoryBlock),
    get_items=get_tuples,
    get_x=get_x, get_y=get_y,
    splitter=splitter,
    item_tfms=Resize(224),
    batch_tfms=[Normalize.from_stats(*imagenet_stats)]
)

# %%
dls = siamese.dataloaders(files)

# %% [markdown]
# We can check the types of the elements in one batch with the `explode_types` method. Here we have a tuple with one `ImageTuple` of two `TensorImage`s and one `TensorCategory`. The transform properly kept the types of everything even after collating the samples together!

# %%
b = dls.one_batch()
explode_types(b)
# Out:
# {tuple: [{__main__.ImageTuple: [fastai.torch_core.TensorImage,
#     fastai.torch_core.TensorImage]},
#   fastai.torch_core.TensorCategory]}

# %% [markdown]
# The `show_batch` method here works out of the box, but to customize how things are organized, we can define a dispatched `show_batch` function. Here the whole batch is just a tuple, so doesn't have a show method. The fastai library will dispatch on the first part of the tuple (x) and second part of the tuple (y), the actual samples being in the `samples` variable.
#
# Here we only dispatch on the `x` (which means this method will be used for `x`s that are `ImageTuple` and any `y`s), but we could have custom behaviors depending on the targets.

# %%
@typedispatch
def show_batch(x:ImageTuple, y, samples, ctxs=None, max_n=6, nrows=None, ncols=2, figsize=None, **kwargs):
    if figsize is None: figsize = (ncols*6, max_n//ncols * 3)
    if ctxs is None: ctxs = get_grid(min(len(samples), max_n), nrows=nrows, ncols=ncols, figsize=figsize)
    ctxs = show_batch[object](x, y, samples, ctxs=ctxs, max_n=max_n, **kwargs)
    return ctxs

# %% [markdown]
# As a sidenote, `x`and `y` are not actually used (all that needs to be shown is in the `samples` list). They are only passed along for type-dispatching because they carry the types of our inputs and targets.
#
# We can now have a look:

# %%
dls.show_batch()

# %% [markdown]
# ## Training a model

# %% [markdown]
# ### The model

# %% [markdown]
# We are now at the stage where we can train a model on this data. We will use a very simple approach: take the body of a pretrained model and make the two images pass through it. Then build a head the usual way, with just twice as many features. The model in itself can be written like this:

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x1, x2):
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %% [markdown]
# For our encoder, we use the fastai function `create_body`. It takes an architecture and an index where to cut it. By default it will use the pretrained version of the model we pick. If we want to check where fastai usually cuts the model, we can have a look at the `model_meta` dictionary:

# %%
model_meta[resnet34]
# Out:
# {'cut': -2,
#  'split': <function fastai.vision.learner._resnet_split(m)>,
#  'stats': ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])}

# %% [markdown]
# So we need to cut at -2:

# %%
encoder = create_body(resnet34, cut=-2)

# %% [markdown]
# Let's have a look at the last block of this encoder:

# %%
encoder[-1]
# Out:
# Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %% [markdown]
# It ends up with 512 features, so for our custom head, we will need to multiply this by 4 (i.e. 2*2): 2 because we have two images concatenated, and another 2 because of the fastai concat-pool trick (we concatenate the average pool and the max pool of the features). The `create_head` function will give us the head that is usually used in fastai's transfer learning models.

# %% [markdown]
# We also need to define the number of outputs of our head `n_out`, in our case it's 2: One for predicting both images are from the same class, and the other, to predict the contrary.

# %%
head = create_head(512*2, 2, ps=0.5)
model = SiameseModel(encoder, head)

# %% [markdown]
# Let's have a look at the generated head:

# %%
head
# Out:
# Sequential(
#   (0): AdaptiveConcatPool2d(
#     (ap): AdaptiveAvgPool2d(output_size=1)
#     (mp): AdaptiveMaxPool2d(output_size=1)
#   )
#   (1): Flatten(full=False)
#   (2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): Dropout(p=0.25, inplace=False)
#   (4): Linear(in_features=2048, out_features=512, bias=False)
#   (5): ReLU(inplace=True)
#   (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=512, out_features=2, bias=False)
# )

# %% [markdown]
# ### Train the model

# %% [markdown]
# We are almost ready to train our model. The last piece missing is a custom splitter: in order to use transfer learning efficiently, we will want to freeze the pretrained model at first, and train only the head. A splitter is a function that takes a model and returns lists of parameters. The `params` function is useful to return all parameters of the model, so we can create a simple splitter like so:

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %% [markdown]
# Then we use the traditional `CrossEntropyLossFlat` loss function from fastai (the same as `nn.CrossEntropyLoss`, but flattened). The only thing is, if using the data built by the mid-level API, we have a tensor of bools for our targets, so we need to convert it to integers otherwise PyTorch will throw an error.

# %%
def loss_func(out, targ):
    return CrossEntropyLossFlat()(out, targ.long())

# %% [markdown]
# Let's grab the data as built by the mid-level API:

# %%
class SiameseTransform(Transform):
    def __init__(self, files, splits):
        self.splbl2files = [{l: [f for f in files[splits[i]] if label_func(f) == l] for l in labels}
                          for i in range(2)]
        self.valid = {f: self._draw(f,1) for f in files[splits[1]]}
    def encodes(self, f):
        f2,same = self.valid.get(f, self._draw(f,0))
        img1,img2 = PILImage.create(f),PILImage.create(f2)
        return SiameseImage(img1, img2, int(same))
    
    def _draw(self, f, split=0):
        same = random.random() < 0.5
        cls = label_func(f)
        if not same: cls = random.choice(L(l for l in labels if l != cls)) 
        return random.choice(self.splbl2files[split][cls]),same

# %%
splits = RandomSplitter()(files)
tfm = SiameseTransform(files, splits)
tls = TfmdLists(files, tfm, splits=splits)
dls = tls.dataloaders(after_item=[Resize(224), ToTensor], 
                      after_batch=[IntToFloatTensor, Normalize.from_stats(*imagenet_stats)],
                     bs = 2)

# %% [markdown]
# Again, test that tfm.valid does not contain items from the train split:

# %%
valids = [v[0] for k,v in tfm.valid.items()]      
assert not [v for v in valids if v in files[splits[0]]]

# %% [markdown]
# We can then create our `Learner`:

# %%
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), splitter=siamese_splitter, metrics=accuracy)

# %% [markdown]
# Since we are not using a convenience function that directly creates the `Learner` for us, we need to `freeze` it manually:

# %%
learn.freeze()

# %% [markdown]
# Then we can use the learning rate finder:

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=6.30957365501672e-06, lr_steep=1.9054607491852948e-06)

# %% [markdown]
# Train for a bit the head:

# %%
learn.fit_one_cycle(4, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.893569</td>
#       <td>1.451455</td>
#       <td>0.485115</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.921344</td>
#       <td>3.447901</td>
#       <td>0.482409</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.690687</td>
#       <td>2.225750</td>
#       <td>0.502030</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.709664</td>
#       <td>7.034256</td>
#       <td>0.479702</td>
#       <td>02:29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfreeze and train the full model for a little more:

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1, slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.701531</td>
#       <td>7.847220</td>
#       <td>0.502030</td>
#       <td>02:49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Making show_results work

# %%
@typedispatch
def show_results(x:SiameseImage, y, samples, outs, ctxs=None, max_n=6, nrows=None, ncols=2, figsize=None, **kwargs):
    if figsize is None: figsize = (ncols*6, max_n//ncols * 3)
    if ctxs is None: ctxs = get_grid(min(x[0].shape[0], max_n), nrows=None, ncols=ncols, figsize=figsize)
    for i,ctx in enumerate(ctxs): 
        title = f'Actual: {["Not similar","Similar"][x[2][i].item()]} \n Prediction: {["Not similar","Similar"][y[2][i].item()]}'
        SiameseImage(x[0][i], x[1][i], title).show(ctx=ctx)

# %%
learn.show_results()

# %% [markdown]
# ### Patch in a `siampredict` method to `Learner`, to automatically show images and prediction

# %%
@patch
def siampredict(self:Learner, item, rm_type_tfms=None, with_input=False):
    res = self.predict(item, rm_type_tfms=None, with_input=False)
    if res[0] == tensor(0):
        SiameseImage(item[0], item[1], 'Prediction: Not similar').show()
    else:
        SiameseImage(item[0], item[1], 'Prediction: Similar').show()
    return res

# %%
imgtest = PILImage.create(files[0])
imgval = PILImage.create(files[100])
siamtest = SiameseImage(imgval, imgtest)
siamtest.show();

# %%
res = learn.siampredict(siamtest)

# %%
splits
# Out:
# ((#5912) [7045,1516,1959,4954,6444,7128,4139,3536,358,2692...],
#  (#1478) [6414,7078,6983,616,1209,3542,3190,396,7257,744...])

# %%
splbl2files
# Out:
# [{'japanese_chin': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_15.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_24.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_71.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_19.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_175.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_21.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_161.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_123.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_190.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_135.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_69.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_66.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_125.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_44.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_169.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_178.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_5.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_61.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_28.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_158.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_188.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_37.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_115.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_39.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_56.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_187.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_14.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_167.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_62.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_179.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_107.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_134.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_32.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_182.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_93.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_160.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_192.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_105.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_12.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_189.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_68.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_16.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_111.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_3.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_78.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_166.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_197.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_196.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_191.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_150.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_116.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_42.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_128.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_20.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_87.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_117.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_76.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_29.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_100.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_85.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_138.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_183.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_47.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_145.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_112.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_11.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_194.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_1.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_177.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_75.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_120.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_140.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_174.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_35.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_121.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_162.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_143.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_198.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_155.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_70.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_88.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_136.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_139.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_63.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_55.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_103.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_97.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_185.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_60.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_77.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_186.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_25.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_59.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_156.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_129.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_43.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_172.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_53.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_164.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_94.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_110.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_146.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_73.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_104.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_6.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_124.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_64.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_52.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_106.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_137.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_38.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_101.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_89.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_8.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_7.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_91.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_147.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_81.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_36.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_9.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_50.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_113.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_31.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_151.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_152.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_199.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_195.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_23.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_126.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_193.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_26.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_168.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_141.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_130.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_51.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_65.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_200.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_109.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_163.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_98.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_34.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_180.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_45.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_119.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_67.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_2.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_184.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_46.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_33.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_132.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_83.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_171.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_90.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_10.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_154.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_92.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/japanese_chin_18.jpg')],
#   'Siamese': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_26.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_76.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_128.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_70.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_163.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_151.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_257.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_71.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_95.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_143.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_137.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_131.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_233.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_142.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_100.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_108.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_87.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_170.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_67.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_22.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_237.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_161.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_202.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_120.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_98.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_247.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_39.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_6.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_228.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_81.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_139.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_64.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_110.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_60.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_78.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_196.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_44.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_31.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_160.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_55.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_5.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_205.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_185.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_48.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_35.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_188.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_156.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_198.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_104.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_167.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_91.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_52.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_85.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_232.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_208.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_254.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_21.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_77.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_61.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_72.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_88.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_24.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_33.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_99.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_119.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_155.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_206.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_225.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_74.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_234.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_175.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_172.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_96.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_63.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_231.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_181.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_69.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_41.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_209.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_54.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_222.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_73.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_141.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_210.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_138.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_146.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_29.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_189.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_57.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_36.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_203.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_9.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_126.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_249.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_218.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_240.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_169.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_84.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_34.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_97.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_50.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_79.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_158.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_165.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_182.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_113.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_224.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_66.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_127.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_147.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_125.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_168.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_49.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_27.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_200.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_103.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_19.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_101.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_109.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_238.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_115.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_46.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_136.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_43.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_179.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_42.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_173.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_140.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_180.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_133.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_159.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_157.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_154.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_111.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_183.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_28.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_164.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_135.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_204.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_149.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_194.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_171.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_186.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_227.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_114.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_47.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Siamese_82.jpg')],
#   'havanese': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_94.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_22.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_152.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_50.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_195.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_53.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_8.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_168.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_112.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_74.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_28.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_161.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_111.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_29.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_81.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_76.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_44.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_170.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_36.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_123.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_198.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_141.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_142.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_186.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_138.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_200.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_5.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_189.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_137.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_139.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_86.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_154.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_67.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_2.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_143.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_148.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_88.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_100.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_182.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_49.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_191.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_60.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_90.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_134.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_133.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_125.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_99.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_120.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_58.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_147.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_87.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_85.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_40.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_185.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_9.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_64.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_135.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_59.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_173.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_92.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_107.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_65.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_13.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_7.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_84.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_180.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_181.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_118.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_179.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_43.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_122.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_114.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_155.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_159.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_14.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_30.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_1.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_98.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_75.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_41.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_24.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_117.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_96.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_136.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_102.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_175.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_91.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_176.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_39.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_131.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_21.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_150.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_115.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_82.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_116.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_103.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_38.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_158.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_12.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_78.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_62.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_194.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_146.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_17.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_130.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_174.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_178.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_97.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_11.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_20.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_3.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_160.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_68.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_16.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_27.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_19.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_162.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_167.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_129.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_196.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_193.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_83.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_69.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_35.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_187.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_190.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_108.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_31.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_169.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_37.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_54.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_15.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_33.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_47.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_95.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_166.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_55.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_145.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_6.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_126.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_192.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_80.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_128.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_89.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_101.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_132.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_188.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_149.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_32.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_10.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_42.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_46.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_119.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_63.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_104.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_71.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_73.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_79.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_18.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_183.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_70.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_127.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_163.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_156.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_105.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_171.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/havanese_48.jpg')],
#   'British_Shorthair': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_56.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_8.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_270.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_267.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_127.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_109.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_64.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_158.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_145.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_266.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_3.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_122.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_175.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_30.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_239.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_204.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_176.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_174.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_17.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_21.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_203.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_107.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_160.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_268.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_85.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_34.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_130.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_149.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_104.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_164.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_22.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_133.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_182.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_66.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_263.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_161.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_121.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_38.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_111.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_169.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_185.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_209.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_79.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_67.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_181.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_40.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_212.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_74.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_173.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_62.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_42.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_9.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_118.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_90.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_134.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_92.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_177.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_241.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_269.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_278.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_179.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_26.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_162.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_48.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_116.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_274.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_37.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_27.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_77.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_277.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_101.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_84.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_168.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_123.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_71.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_258.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_201.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_198.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_100.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_75.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_82.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_72.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_172.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_47.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_25.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_223.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_51.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_86.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_128.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_144.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_184.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_272.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_276.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_60.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_157.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_166.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_119.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/British_Shorthair_41.jpg'),
# ...
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_5.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_99.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_156.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_74.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_174.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_178.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_28.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_91.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_29.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_85.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_127.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_190.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_197.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_78.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_9.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_125.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_165.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_94.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/samoyed_67.jpg')],
#   'Abyssinian': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_108.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_66.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_223.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_143.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_164.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_168.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_89.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_13.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_74.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_3.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_114.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_29.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_111.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_94.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_61.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_102.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_221.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_132.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_11.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_7.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_152.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_105.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_44.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_190.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_52.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_33.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_65.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_93.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_125.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_32.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_129.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_157.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_58.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_155.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_36.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_133.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_30.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_140.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_146.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_76.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_226.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_207.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_62.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_55.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_98.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_134.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Abyssinian_5.jpg')],
#   'newfoundland': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_134.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_101.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_53.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_187.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_155.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_18.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_141.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_83.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_32.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_193.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_111.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_176.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_184.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_17.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_147.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_100.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_84.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_188.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_144.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_152.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_73.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_70.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_137.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_165.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_127.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_5.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_51.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_163.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_150.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_124.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_30.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_185.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_65.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_128.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_78.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_133.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_1.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_22.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/newfoundland_35.jpg')],
#   'Ragdoll': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_224.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_219.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_196.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_228.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_184.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_27.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_130.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_235.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_92.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_26.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_116.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_173.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_255.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_210.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_12.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_57.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_174.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_192.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_151.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_148.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_81.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_254.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_259.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_147.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_74.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_89.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_135.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_41.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_164.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_1.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_252.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_56.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_195.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_204.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_156.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_53.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_5.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_126.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_86.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_133.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_122.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_176.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_234.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/Ragdoll_140.jpg')],
#   'leonberger': [Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_85.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_178.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_171.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_6.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_17.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_11.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_192.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_29.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_103.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_37.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_155.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_34.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_50.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_117.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_69.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_168.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_121.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_96.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_151.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_183.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_46.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_185.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_83.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_47.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_44.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_75.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_84.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_145.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_172.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_78.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_164.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_189.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_10.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_180.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_13.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_152.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_132.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_1.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_116.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_30.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_20.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_176.jpg'),
#    Path('/home/karrrrrrrr/.fastai/data/oxford-iiit-pet/images/leonberger_86.jpg')]}]

# %%
dls

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-ebd75a2ea847> in <module>
# ----> 1 dls.valid[0]
#
# TypeError: 'TfmdDL' object is not subscriptable
