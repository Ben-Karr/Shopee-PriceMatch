# %%
from fastai.vision.all import *

import PIL

# %%
base_path = Path('src')

img_train = base_path / 'train_images'
img_test = base_path / 'test_images'

# %%
df_train = pd.read_csv(base_path / 'train.csv')
df_test = pd.read_csv(base_path / 'test.csv')

# %%
files = get_image_files(img_train)

# %%
img = PIL.Image.open(files[0])

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FF424133AC0>

# %%
def open_image(fname, size = 224):
    img = PIL.Image.open(fname).convert('RGB')
    img = img.resize((size, size))
    t = torch.Tensor(np.array(img))
    
    return t.permute(2,0,1).float()/255.

# %%
open_image(files[0]).shape
# Out:
# torch.Size([3, 224, 224])

# %%
def label_func(fname):
    return df_train[df_train['image'] == fname.name]['label_group'].values[0]

# %%
label_func(files[0])
# Out:
# 2419539248

# %%
labels = df_train.label_group.unique()
lbl2files = {label: [img_train / name for name in df_train[df_train['label_group'] == label]['image'].to_list()] for label in labels}

# %%
import random

# %% [markdown]
# ## Remove f from random.choice(lbl2files[cls]) in _draw?

# %%
class SiameseDataset(torch.utils.data.Dataset):
    def __init__(self, files, is_valid = False):
        self.files, self.is_valid = files, is_valid
        if is_valid: 
            self.files2 = [self._draw(f) for f in files]
            
    def __getitem__(self, i):
        file1 = self.files[i]
        (file2, same) = self.files2[i] if self.is_valid else self._draw(file1)
        img1, img2 = open_image(file1), open_image(file2)
        return (img1, img2, torch.Tensor([same]).squeeze())
    
    def __len__(self): return len(self.files)
    
    def _draw(self, f):
        same = random.random() < 0.5 #indicator if draw has the same label as f
        cls = label_func(f) # label of f
        if not same: 
            cls = random.choice([l for l in labels if l != cls]) # choose a class that is different than cls
        return random.choice(lbl2files[cls]), same

# %%
idxs = np.random.permutation(range(len(files)))
cut = int(0.8 * len(files))
train_files = files[idxs[:cut]]
valid_files = files[idxs[cut:]]

# %%
train_files[0]
# Out:
# Path('src/train_images/ec473d17b780e64c330603199501c6ba.jpg')

# %%
train_ds = SiameseDataset(train_files)
valid_ds = SiameseDataset(valid_files, is_valid = True)

# %%
dls = DataLoaders.from_dsets(train_ds, valid_ds)

# %%
b = dls.one_batch()

# %%
dls = dls.cuda()

# %% [markdown]
# --------

# %%
class SiameseTransform(Transform):
    def __init__(self, files, is_valid=False):
        self.files,self.is_valid = files,is_valid
        if is_valid: self.files2 = [self._draw(f) for f in files]
        
    def encodes(self, i):
        file1 = self.files[i]
        (file2,same) = self.files2[i] if self.is_valid else self._draw(file1)
        img1,img2 = open_image(file1),open_image(file2)
        return (TensorImage(img1), TensorImage(img2), torch.Tensor([same]).squeeze())
    
    def _draw(self, f):
        same = random.random() < 0.5
        cls = label_func(f)
        if not same: cls = random.choice([l for l in labels if l != cls]) 
        return random.choice(lbl2files[cls]),same

# %%
train_tl= TfmdLists(range(len(train_files)), SiameseTransform(train_files))
valid_tl= TfmdLists(range(len(valid_files)), SiameseTransform(valid_files, is_valid=True))

# %%
dls = DataLoaders.from_dsets(train_tl, valid_tl, 
                             after_batch=[Normalize.from_stats(*imagenet_stats), *aug_transforms()])
dls = dls.cuda()

# %%
class SiameseImage(fastuple):
    def show(self, ctx = None, **kwarks):
        if len(self) > 2:
            img1, img2, similarity = self
        else:
            img1, img2 = self
            similarity = 'Undetermined'
        if not isinstance(img1, Tensor):
            if img2.size != img1.size:
                img2 = img2.resize(img1.size)
            t1, t2 = tensor(img1), tensor(img2)
            t1, t2 = t1.permute(2,0,1), t2.permute(2,0,1)
        else:
            t1, t2 = img1, img2
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim = 2), title = similarity, ctx = ctx, **kwarks)

# %%
img1 = PILImage.create(files[0])
img2 = PILImage.create(files[1])
s = SiameseImage(img1, img2, False)
s.show()
# Out:
# <AxesSubplot:title={'center':'False'}>

# %%
tst = Resize(600)(s)
tst = ToTensor()(tst)
tst.show()
# Out:
# <AxesSubplot:title={'center':'False'}>

# %%
class SiameseTransform(Transform):
    def __init__(self, files, split_labels):
        self.splbl2files = [
            {label: 
             [img_train / name for name in df_train[df_train['label_group'] == label]['image'].to_list()] 
             for label in split_labels[i]
            }for i in range(2)
            ]
        self.valid = {f: self._draw(f,1) 
                      for f in [img_train / name for name in df_train[df_train['label_group'].isin(splits[1])]['image'].to_list()]}
        
    def encodes(self, f):
        f2, same = self.valid.get(f, self._draw(f,0))
        img1, img2 = PILImage.create(f), PILImage.create(f2)
        return SiameseImage(img1, img2, same)
    
    def _draw(self, f, split=0):
        same = random.random() < 0.5
        cls = label_func(f)
        if cls in split_labels[0]:
            i = 0
        else:
            i = 1
        if not same: 
            labs = L([label for label in split_labels[i] if label != cls])
            cls = random.choice(labs) 
        return random.choice(self.splbl2files[split][cls]),same

# %%
tfm = SiameseTransform(files, split_labels)

# %%
valids = [v[0] for k,v in tfm.valid.items()]

# %%
assert not [v for v in valids if v in files[split_labels[0]]]

# %%
tls = TfmdLists(files, tfm, splits = splits)

# %%
show_at(tls.valid, 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-2867bd59ce0a> in <module>
# ----> 1 show_at(tls.valid, 0)
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastai/data/core.py in show_at(o, idx, **kwargs)
#     304 def show_at(o, idx, **kwargs):
#     305     "Show item at `idx`",
# --> 306     return o.show(o[idx], **kwargs)
#     307
#     308 # Cell
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastai/data/core.py in __getitem__(self, idx)
#     283         res = super().__getitem__(idx)
#     284         if self._after_item is None: return res
# --> 285         return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#     286
#     287 # Cell
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastai/data/core.py in _after_item(self, o)
#     245         return super()._new(items, tfms=self.tfms, do_setup=False, types=self.types, split_idx=split_idx, **kwargs)
#     246     def subset(self, i): return self._new(self._get(self.splits[i]), split_idx=i)
# --> 247     def _after_item(self, o): return self.tfms(o)
#     248     def __repr__(self): return f"{self.__class__.__name__}: {self.items}\ntfms - {self.tfms.fs}"
#     249     def __iter__(self): return (self[i] for i in range(len(self)))
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in __call__(self, o)
#     196         self.fs.append(t)
#     197
# --> 198     def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     199     def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     200     def __getitem__(self,i): return self.fs[i]
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     148     for f in tfms:
#     149         if not is_enc: f = f.decode
# --> 150         x = f(x, **kwargs)
#     151     return x
#     152
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in __call__(self, x, **kwargs)
#      71     @property
#      72     def name(self): return getattr(self, '_name', _get_name(self))
# ---> 73     def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#      74     def decode  (self, x, **kwargs): return self._call('decodes', x, **kwargs)
#      75     def __repr__(self): return f'{self.name}:\nencodes: {self.encodes}decodes: {self.decodes}'
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in _call(self, fn, x, split_idx, **kwargs)
#      81     def _call(self, fn, x, split_idx=None, **kwargs):
#      82         if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 83         return self._do_call(getattr(self, fn), x, **kwargs)
#      84
#      85     def _do_call(self, f, x, **kwargs):
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in _do_call(self, f, x, **kwargs)
#      87             if f is None: return x
#      88             ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 89             return retain_type(f(x, **kwargs), x, ret)
#      90         res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#      91         return retain_type(res, x)
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#     116         elif self.inst is not None: f = MethodType(f, self.inst)
#     117         elif self.owner is not None: f = MethodType(f, self.owner)
# --> 118         return f(*args, **kwargs)
#     119
#     120     def __get__(self, inst, owner):
#
# <ipython-input-243-0518ae2b77e1> in encodes(self, f)
#      11
#      12     def encodes(self, f):
# ---> 13         f2, same = self.valid.get(f, self._draw(f,0))
#      14         img1, img2 = PILImage.create(f), PILImage.create(f2)
#      15         return SiameseImage(img1, img2, same)
#
# <ipython-input-243-0518ae2b77e1> in _draw(self, f, split)
#      25             labs = L([label for label in split_labels[i] if label != cls])
#      26             cls = random.choice(labs)
# ---> 27         return random.choice(self.splbl2files[split][cls]),same
#
# KeyError: 1088591892

# %% [markdown]
# ### Customize RandomSplit to split by label, but be able to pass list of split filepaths
