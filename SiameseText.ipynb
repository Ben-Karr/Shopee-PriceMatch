# %%
from fastai.text.all import *
import codecs

# %%
base_path = Path('src')

img_train = base_path / 'train_images'
img_test = base_path / 'test_images'

# %%
df_train = pd.read_csv(base_path / 'train.csv')
df_test = pd.read_csv(base_path / 'test.csv')

# %%
df_train.title = df_train.title.apply(lambda x: codecs.escape_decode(x)[0].decode('utf8'))

# %%
print(f'Unique images: {df_train.image_phash.nunique()} of {df_train.image.nunique()} unique image-files.')
# Out:
# Unique images: 28735 of 32412 unique image-files.

# %% [markdown]
# Drop duplicate texts.

# %%
df_train.drop_duplicates(['title'], inplace = True)

# %%
df_groupby_label = df_train.groupby(['label_group'])['title'].nunique().to_frame()

# %%
print(f'Number of labels, that contain only one title: {(df_groupby_label.title < 2).sum()}')
# Out:
# Number of labels, that contain only one title: 309

# %% [markdown]
# Only keep instances that belong to a label_group that contains more than one unique texts.

# %%
keep_labels = df_groupby_label[df_groupby_label.title >= 2].index.tolist()
df_train = df_train[df_train['label_group'].isin(keep_labels)].reset_index(drop = True)

# %%
# Sanity check:
print(f"Number of labels, that contain only one image_phash: {(df_train.groupby(['label_group'])['title'].nunique() < 2).sum()}")
print(f"Number of duplicate files: {df_train.duplicated(['title']).sum()}")
# Out:
# Number of labels, that contain only one image_phash: 0
# Number of duplicate files: 0

# %% [markdown]
# We can now make shure to draw image-files with different phashes, when creating the Siamese dataset.

# %% [markdown]
# ## create smaller dataset

# %%
small_pct = 0.1

# %%
x = df_train['label_group'].unique()
y = np.random.choice(x, size = int(len(x)*small_pct), replace = False)
df_train = df_train[df_train['label_group'].isin(y)]
df_train = df_train.reset_index(drop = True)

# %%
print(df_train.shape)
df_train.head()
# Out:
# (3363, 5)
#          posting_id                                 image       image_phash  \
# 0  train_1806152124  0014f61389cbaa687a58e38a97b6383d.jpg  eea7e1c0c04da33d
# 1  train_1180155871  00369839c7d94411e54437b7cf59b603.jpg  bbc1c43ec3633ec0
# 2  train_3921931335  007ed1560a37f2fc76297ed06af5c4a5.jpg  facb8794856d52c2
# 3  train_2510999729  008f8aac1d118f0b318b918aa783e9ed.jpg  934f36b444d03d3b
# 4  train_2962272674  00a8d112066ea78e33d5ef987091a6b4.jpg  ebe19ec4d31ea103
#
#                                                                                                   title  \
# 0             KULOT PLISKET SALUR /CANDY PLISKET /WISH KULOT PREMIUM /KULOT PELANGI PREMIUM/HIEKA KULOT
# 1                                                                [INCLUDE PAJAK] NCT DREAM RELOAD ALBUM
# 2                                                                      KEDAS BEAUTY BODY SERUM BER BPOM
# 3  Anti Blue Light Film Sony Xperia XZ1 XZ3 XZ/XZ2 Premium XA2 Plus/Ultra Xperia 1 10 Plus Screen Guard
# 4     Set Boneka Jari Binatang Hewan Finget Puppet Mainan Edukasi Anak Bayi Balita PAUD Alat Mendongeng
#
#    label_group
# 0   1565741687
# 1   2224428568
# 2   2217827677
# 3   1702111919
# 4   1896239564

# %%
## Save tiny dataset
#df_exp = df_train.drop(['image','image_phash','label_group'], axis = 1)
#df_exp.to_csv('src/small_text_df.csv')

# %%
class SiameseText(fastuple):
    def show(self, ctx = None, **kwargs):
        if len(self) > 2:
            txt1, txt2, same_prod = self
        else:
            txt1, txt2 = self
            same_prod = 'Undetermined'
        
        return print(f'First text: {txt1}\nSecond text: {txt2}\nDescribes same: {same_prod}')

# %%
i,j = np.random.randint(0, high = len(df_train), size = 2)
txt1 = df_train.loc[i, 'title']
txt2 = df_train.loc[j, 'title']
same = df_train.loc[i, 'label_group'] == df_train.loc[j, 'label_group']

siamt = SiameseText(txt1, txt2, same)
siamt.show()
# Out:
# First text: Isomil Advance Soya (0-12 Bln) 850 gr
# Second text: CUSSONS BABY CREAM 50GR
# Describes same: False

# %%
def split_by_label(df, col):
    # L-list of unique labels
    labels = L(df.label_group.unique().tolist())
    # Randomly split labels
    split_labels = RandomSplitter(valid_pct=0.2)(labels)  # Returns 80/20 split of labels

    # Mask labels to receive train/val labels
    train_labels = labels[split_labels[0]]
    validation_labels = labels[split_labels[1]]

    # Add colum to mark file as a part of the training/validation set
    df['is_valid'] = df_train.label_group.isin(validation_labels)

    # Sanity check:
    assert((df.groupby(['label_group'])['is_valid'].nunique() > 1).sum() == 0)
    
    files = L(df[col].tolist())
    train_idx = df[df['is_valid'] == False].index.tolist()
    validation_idx = df[df['is_valid'] == True].index.tolist()
    
    # Sanity check:
    assert(set(files[train_idx]) == set(df[df['is_valid'] == False][col]))
    assert(set(files[validation_idx]) == set (df[df['is_valid'] == True][col]))
    
    return files, train_labels, validation_labels, train_idx, validation_idx

# %%
files, train_labels, validation_labels, train_split, val_split = split_by_label(df_train, 'title')
splits = (train_split, val_split)
labels = (train_labels,validation_labels)

# %%
splits_files = [files[splits[i]] for i in range(2)]
splits_sets = mapped(set, splits_files)

# %%
splbl2files = [(df_train.loc[splits[i]]).groupby(['label_group'])['title'].apply(list).to_dict() for i in range(2)]

# %%
splbl2files
# Out:
# [{5949579: ['Kisonli Speaker Bluetooth Tenteng FojaxFJ-16DW Plus Mic Karaoke, Radio, USB, Micro SD',
#    'Speaker Bluetooth Tenteng Portabable Unitech FJD-16DW Lampu LED Support USB MicroSD Aux FM Radio'],
#   7657592: ['Tote bag wanita BAG TULIP / tas wanita murah/tas kuliah/ tas bahu',
#    'Tote bag cantik TULIP BAG / tas wanita / tas bahu / tas kuliah / tas wanita murah /women bag'],
#   10069919: ['Ellips Hair Vitamin (Pro Keratin Complex) Kemasan Botol Jar 50 kapsul 1 ml',
#    'Ellips Hair Vitamin Rambut jar isi 50 pcs'],
#   19273520: ['SHANNEN LIPSTICK CLP',
#    'SHANNEN LIPSTICK CREAMY LIP PAINT',
#    'SHANNEN CREAMY LIP PAINT',
#    'Promo lipstik Shannen creamy lip paint ORI harga Grossir'],
#   39139032: ['Speaker mini bluetooth usb Advance TP600 TP 600 (Tanpa micro sd)',
#    'Speaker Advance TP 600 Batik Portable Digital TP-600BT Bluetooth Ori'],
#   66057972: ['ROBOT TRANSFORM POLIIISI MOBIL BERUBAH JADI ROBOT - KADO MAINAN ANAK',
#    'ROBOT TRANSFORM POLISI MOBIL BERUBAH JADI ROBOT - KADO MAINAN ANAK'],
#   69606827: ['Lion Star Botol Saus / Sauce Keeper 325 mL (SK-406)',
#    'Botol Saos / Kecap / Lion Star Sauce Keeper SK 406 (325 ml) TS 46'],
#   69923982: ['Mainan bola balon basket karet',
#    'Mainan anak Bola Basket karet Murah',
#    'Bola basket',
#    'BOLA KARET BASKET 5016 - MAINAN BOLA BASKET',
#    'ID BOLA KARET BASKET 5016 - MAINAN BOLA BASKET',
#    'Mainan Bola balon Basket karet',
#    'Mainan Bola balon Basket karet murah'],
#   70029330: ['IK EA05 LERBERG 60X148 WARNA PUTIH RAK BERDIRI EXPEDISI/ OJOL',
#    'rak lerberg besar',
#    'LERBERG Unit Rak  60x35x148cm Baja berlapis'],
#   72043261: ['Tropicana Slim GoldenMil Vanilla Manuka Honey 180gr',
#    'GoldenMil Vanila Susu Dewasa [6 Sachet x 30 g]'],
#   72973914: ['PREMIUM AMORA PANTS',
#    'Celana Wanita Murah Terbaru Amora Pants Katun Strech Multifungsi Fit Jumbo XXL'],
#   73121725: ['PAKAIAN WANITA - POP GIRL SWEATER - SWEATER WANITA - SWEATER FLEECE',
#    'Pop Girl l Sweater Wanita Terbaru'],
#   73153907: ['[✨] 400ml Botol Pump Kompresi untuk Shampo / Kamar Mandi',
#    'Botol Pump Kosong Bahan Plastik Kapasitas 400ml Untuk Sabun Cair/Shampoo/Lotion',
#    'Botol Shower Gel Portable Bahan PP Motif Bunga untuk Kamar Mandi'],
#   81033104: ['otg audio jack 3.5mm',
#    'Kabel Audio OTG MALE AUX to USB Cable Connector jack 3.5mm'],
#   98063691: ['Sandal Sedekah Wakaf Masjid Musholla | Sendal Mushola Musala Mesjid Kantor Pondok Pesantren',
#    'Sandal Wudhu Masjid Musholla ( 16 PASANG ) | Sendal Sodakoh Sedekah Kantor Mushola Musala Mesjid',
#    'Sandal Wudhu Masjid Musholla ( 9 PASANG ) | Sendal Sodakoh Sedekah Kantor Mushola Musala Mesjid',
#    'Sandal Wudhu Masjid Musholla W04 ( 5 PASANG ) | Sendal Sodakoh Sedekah Kantor Mushola Musala Mesjid'],
#   98119379: ['Hand Sanitizer 1 LITER (harga normal)',
#    'Antis hand sanitizer 1 Liter MERK hand sani (murah legit)'],
#   98561409: ['Selimut bulu karakter ivanka',
#    'Selimut Bulu Karakter lucu dan keren merek ivanka uk 130x180'],
#   101129666: ['Seruni Living  Masker Hijab Kain Motif Bunga (headloop)',
#    'Masker kain motif 2 lapis headloop/hijab'],
#   122159316: ['Slop Pria Adidas Neymar Nevy Merah Slip On Sepatu Pria Casual Santai Termurah',
#    'Adidas [Premium Quality] Neymar Sepatu Casual Slip On Pria Keren Grade Ori'],
#   125084078: ['CIVETO PF09 MAP Cactus A4 Stationery File Folder',
#    'Ennwen PF09 MAP Cactus A4 Stationery File Folder'],
#   132875370: ['Kepala Shower Aerator Air Soft Halus Lembut 300 Lubang Low Preasure',
#    'Kepala Sower Mandi Aerator Air Soft Halus Lembut 300 Lubang Low Preasure Premium BN28'],
#   135655018: ['Turban kids beda pita/anak/baby/bayi/balita',
#    'Turban anak beda pita',
#    'Turban bayi /TURBAN PITA BEDA WARNA'],
#   137876122: ['Tenda Anak Model Indian Play Tend Indian Style Tenda Main Anak',
#    'Tenda Anak Castle Indian Kastil Tent Jumbo AN8119',
#    'Tenda Mainan Anak Model Kastil Children Play Tent tenda kastil mainan'],
#   138930320: ['Case OPPO A53 A33 A52 A92 A31 A91 A5 A9 2020 A7 A5S A12 AX7 A1K A3S A12e F1S F11 Pro F9 F7 F5 Youth A83 A71 A39 A57 F3 Lite A37 A37F Reno 3 4 2F 2Z Soft TPU Phone Case Motif Milk Tea',
#    'ST| Casing OPPO A53 A33 2020 A52 A92 A12 A31 A91 A5 A9 2020 Reno 3 2F A1K F1s F1 F3 Plus F5 Youth F9 F11 A3s A7 A5s A39 A57 A83 Realme C1 C2 U1 2 Pro Milk Bear Soft Case'],
#   162365689: ['Zahra blouse // sabrina blouse',
#    '7.7 Fashion Sale | Sabrina Stripe | Best Seller | Atasan murah terbaru'],
#   164698800: ['12 pcs per set Kuas Make Up Tabung',
#    'Brush 12 Set In Tube Kuas Tabung Rias Make Up 12 Set Kuas Make Up',
#    'HH12 Brush 12 Set In Tube Kuas Tabung Rias Make Up 12 Set Kuas Make Up',
#    'Kuas Make Up Tabung 12pcs Make Up Brush 12 Set In Tube Kuas Rias Make Up - Kaylie',
#    'Tube Make Up Brush Set / Kuas makeup 12pcs Tabung',
#    'Brush Set Tube Kuas Rias Make Up 12 Pcs Kuas Make Up Foundation Brush Free Tabung',
#    'Brush Set Tube Kuas Rias Make Up 12 Pcs Kuas Make Up Foundation Brush Free Tabung Love',
#    'MASKER WAJAH PREMIUM OAT BUBUK OHMYSKIN 65gr',
#    'Kuas Rias Make Up 12 Pcs Kuas Make Up Foundation Brush Free Tabung Love Brush Set Tube',
#    'JBS  Brush Set Tube Kuas Rias Make Up 12 Pcs Kuas Make Up Foundation Brush Free Tabung Glitter K327',
#    'NEW..!! KUAS TABUNG MAKE UP ISI 12PCS / BRUSH MAKEUP',
#    '[150gr] LT- [ TABUNG ] Kuas Set Tabung Make Up isi 12/kuas tabung',
#    '[TABUNG] KUAS SET TABUNG MAKE UP ISI 12 / KUAS TABUNG'],
#   165136504: ['FREE MASKER & BUBBLE WRAP!! JOK PORTABLE BONCENGAN MOTOR ANAK / JOK SADEL KURSI BONCENG MOTOR',
#    'FREE BUBBLE WRAP!! JOK PORTABLE BONCENGAN MOTOR ANAK / KUSRSI BONCENG SADEL ANAK PRINTING',
#    'FREE MASKER & BUBBLE WRAP!! JOK PORTABLE KURSI BONCENGAN MOTOR ANAK / JOK MOTOR BONCENG BALITA',
#    'FREE MASKER & BUBBLE WRAP!! JOK PORTABLE PRINTING KURSI BONCENGAN MOTOR ANAK / JOK BONCENG MOTOR LOL',
#    'FREE BUBBLE WRAP!! JOK PORTABLE MULTIFUNGSI KURSI BONCENGAN MOTOR ANAK/ JOK SADEL MOTOR'],
#   184336375: ['Speed Shifter Rem Sepeda 7 Speed 2 PCS Handle Brake Level',
#    'Speed Shifter Handle Brake Rem Sepeda 7 Speed 2 PCS - Black'],
#   188693842: ['ALquran AISYAH kecil A6 Hc/terjemahan/untuk wanita',
#    'Al quran wanita Aisyah kecil A6 Hc quran terjemah tafsir'],
#   191738074: ['AZIZAH BERGO LENGAN • HIJAB JILBAB KERUDUNG KHIMAR SYARI MUSLIMAH PAD ANTEM',
#    'BERGO LENGAN AZIZAH / BERGO SYARI PAD BUSA ANTEM BERLENGAN BAHAN JERSEY ZOYA',
#    'Bergo Lengan Azizah',
#    '(Promo) Bergo Lengan Azizah'],
#   191984645: ['OKHISHOP - Piyama Hotpant HP Satin Velvet',
#    'PIYAMA EMBOS HP 3/4 BAJU TIDUR WANITA'],
#   197411392: ['Perlak Bayi Sugar Baby , Perlak Karet Waterproof Bayi Untuk Ompol , SugarBaby Perlak , Alas Ompol',
#    'PERLAK SUGAR BABY  perlak Bayi ALAS ompol bayi perlak anti air'],
#   198216033: ['Panci Elektrik Multifungsi Advance C-18',
#    'Multi steaming pan merk advance c18 / panci elektrik multifungsi / panci listrik / hiter mug listrik',
#    'AHDAVASHOP Panci Elektrik Panci Listrik Multifungsi C-18'],
#   198574160: ['MARS - HOTPANT SALUR BLASTER | HOTPANTS SALUR BLASTER',
#    'HOT PANTS MUNIKO SALUR | CELANA PENDEK WANITA JUMBO'],
#   220186114: ['Rattle Donat Bayi/ Mainan Bayi',
#    'Rattle Donat / Rattle Bayi / Mainan Bayi / Rattle Donut / Rattle Doughnut'],
#   232646097: ['6 In 1 Stretch Bowl Cover Lid Silicone Food Cover/ Penutup Makanan  Silikon Bisa Meregang K312',
#    '6 In 1 Stretch Bowl Cover Lid Silicone Food Cover/Tutup Makanan Silikon Bisa Meregang K312',
#    'TUTUP MANGKOK SERBAGUNA SILICONE 6 IN 1 STRETCH BOWL COVER LID',
#    'Penutup Makanan Silikon 6 in 1 Stretch Bowl Cover Silicone Food Cover'],
#   237739865: ['Wardah Eyebrow Pencil Black 1.14 g',
#    'Wardah Eyebrow Pencil Black 1.14 G',
#    'WARDAH EYE BROW',
#    'Wardah Eyebrow Pencil Brown 1.14',
#    'Wardah Eyebrow Pencil Brown 1.14 / pensil alis warna coklat [SLO] [SLO]',
#    'Wardah Eyebrow Pencil Brown 1.14 [MTR]',
#    'Wardah Eyebrow Pencil Brown 1.14[SKB]'],
#   242335673: ['Konektor PEREKAT RANDOM READY STOK GROSIR',
#    'BARU!! Konektor Pengait Tali Masker Random'],
#   256111454: ['Koko lis hedlong baju koko lis simple lengan 3/4 four one  kurta pakistan',
#    'M L XL XXL {COD} KOKO KURTA original agam pakistan jahitan Tailor halus al Khalis'],
#   258686129: ['FILM WATER TRANSFER PRINTING SC-C74 UK 100X50CM',
#    'FILM WATER TRANSFER PRINTING SC-C82 UK 100X50CM'],
#   261593436: ['Selimut Bulu Dewasa Motif Uk 180x200 New Motif',
#    'Selimut Bulu Halus King 180x200 Motif Dewasa Keren Terlaris Termurah Impor Berkualitas'],
#   267914218: ['Pharmaskin skincare Paket Whitening Glow',
#    'Pharmaskin Paket whitening glowing series by farmacy skincare'],
#   272496485: ['Citra Hand and Body Lotion Sun Protected White SPF 20 230ml',
#    'Citra Hand & Body Lotion Sun Protect White SPF20 230ml',
#    'Citra Hand & Body Lotion Sun Protect White SPF20 230ml 100%ORIGINAL'],
#   275813572: ['Safi  Age Defy Gold Water Essence 30ml',
#    'Safi Age Defy Gold Water Essence 30 ml Anti Aging',
#    'Safi Age Defy Gold Water Essence 30 ml',
#    'Safi Age Defy Gold Water Essence 30 ml.',
#    'SAFI Age Defy Gold Water Essence 30ml',
#    'SAFI AGE DEFY GOLD WATER ESSENCE 30ml',
#    'Safi Age Defy Gold Water Essence 30 ML',
#    'Safi Age Defy Gold Water Essence 30ml'],
#   275815951: ['Porto Sandal Anak Laki-Laki 1028B Size 30-35',
#    'Porto Sandal Jepit Casual Anak Laki-Laki 1028B Size 30-35'],
#   284594326: ['Ovomaltine Crunchy Cream 240g',
#    'Ovomaltine 240gram / Ovomaltine Crunchy 240gr / Ovomaltine 240'],
#   284754035: ['SEPATU WANITA / SNEAKERS DP06',
#    'SEPATU WANITA JINTU KOREA 2020',
#    'Syra.footwear Sepatu Sneakers Import Wanita Korea Fashion ORIGINAL [FREE KAOSKAKI & KOTAK] - SHG008',
#    'Sepatu Korea Jintu 2020 Wanita Sneakers Cewek Sneaker Sol Karet Putih Fashion Korea Murah Kekinian',
#    'SEPATU SNEAKERS WANITA JINTU',
#    'Globalmarket.id Sepatu Sneakers Fashion Wanita Korea Import SYRA ORI [FREE KAOSKAKI & DUS] - SHG008',
#    'Sepatu KOREA JINTU 2020'],
#   293333952: ['Popsockets Warna / Phone Holder Pop socket ring Polos + Socket',
#    'Popsockets Universal for Smartphone'],
#   295258021: ['Goddesskin - Day Cream Whitening',
#    'Goddesskin - Night Cream Acne'],
#   298475141: ['Balon pastel perpack 12inch', 'Balon Pastel Perpack 12 INCH'],
#   302961006: ['Balonasia Balon Bando Hewan / Animal head band',
#    'Balon Bando Hewan / Animal head band',
#    'Balon Bando Hewan / Animal headband balon karakter pesta anak',
#    'Balon Foil Bando Anak Karakter Hewan / Animal Headband',
#    'Balon Bando Karakter Animal / Balon Bando Hewan / Animal Head Band',
#    'Balon Foil Bando / Headband Ballon Bentuk Kepala Hewan, Mickey, Minnie'],
#   309010310: ['BUBBLE WRAP ( Tambahan Packing )',
#    'Bubble Wrap (plastik gelembung)',
#    'BUBBLE WARP ukuran 0.5M x 1.25M & 1M x 1.25M (hanya untuk tambahan pengaman packing)',
#    'Bubble Wrap 40 cm  per 1 kilo - Packing Tambahan - Supaya Lebih Aman',
#    'Bubble wrap EXTRA PACKING AMAN',
#    'BUBBLE WRAP # 15062',
#    'BUBBLE WRAP UNTUK PENGIRIMAN LEBIH AMAN',
#    'Bubble Wrap untuk extra packing',
#    'buuble wrap packing plastik gelembung plastik pack tambahan',
#    'BUBBLE WRAP Tambahan Packing Bubble Plastik Gelembung Udara Pembungkus/EXTRA PACKING/PACKING AMAN',
#    'XTRA Bubble Warp Tambahan Untuk Packing',
#    'Bubble Wrap Hitam Untuk Pengaman Paket',
#    'Bubble Wrap tambahan packing'],
#   311184318: ['Alat Pel Q2-103 Busa Keras Berkualitas',
#    'Alat Pel Q2-103 Busa Keras Free Refill (Bonus)'],
#   312075884: ['(IZIN BPOM) PARFUM BAYI SWITSBABY 35ML + BOX BONUS POUCH',
#    'PARFUM SWITSAL / SWITSBABY CERRY BLOSSOM PINK 35ML + BOX ORIGINAL BONUS POUCH / MASKER'],
#   320752715: ['Cod ✔O2 st kulot himaru  dan st rok himaru',
#    'SMS 88 - (BISA COD)St Kulot himaru bhn babyterry Ld 108cm + celana kulot karet',
#    'EL GROS 12 - SET HIMARU / Stelan Himaru Kulot / Stelan Himaru ROK / Stelan baju wanita FIT TO M - XL',
#    'VIV TURUN HARGA STELAN KULOT HIMARU'],
#   326201568: ['Back Pack Double Decker_Tas Ransel Anak_Lol_Unicorn_Superhero_Paw Patrol_Shopkins Fashion Cewek W5Q3',
#    'Tas Sekolah anak/Taskuliah/taspunggung/ Tasvanessa/ tasanak/tasmain/ tasgaya/ tasmurah/ tassekolah 1'],
#   327388992: ['Buku Latihan Mengeja Kata - Untuk TK/PAUD',
#    'Buku Aktifitas Mini - Latihan Mengeja Kata'],
#   328785777: ['Strap Nilon Pengganti untuk Apple iWatch Series 6 SE 5 4 3 2 1 40mm 44mm 42mm 38mm',
#    'Strap Nilon Pengganti untuk for Apple Watch 6 se 5 Band 44mm 40mm',
#    'Strap Nilon Sport Loop 38mm 40mm 42mm 44mm for iWatch Series 6 se 5 4 3 2 1'],
#   333597397: ['UMS 200 Habbatussauda Extra Propolis Trigona 200 Kapsul UMS | Habatussauda',
#    'Habbatussauda Extra Propolis Trigona 200 Kapsul UMS | Habatussauda',
#    'Original Habbatussauda Extra Propolis Trigona 200 Kapsul UMS | Habatussauda',
#    'HABBATUSAUDA ORGINAL TRIGONA  200kp / EXTRAFIT',
#    'Obat Herbal Pil Kapsul Habbatussauda Extra Propolis Trigona Habbatussauda Oil Jintan hitam isi 200 Z'],
#   353123255: ['[PIPO MEDAN 6 PCs 60 YARD] PIPO Lakban murah kualitas bagus panjang 60 yard 2 inch isi 6 Pcs',
#    '6 pc PIPO Lakban murah kualitas bagus 60 yard 2 inch isi 6 Pcs'],
#   353320183: ['BOLDe Super Cook Palladium ECO Rice Cooker 3in1 Kapasitas 1 Liter',
#    'BOLDe Rice Cooker 3D SUPER COOK 1 Liter - PALLADIUM'],
#   355267809: ['Lazypod Jepit Lazy Pod Flexible', 'Lazypod'],
#   357412423: ['Tisu Basah MamyPoko Wipes Reguler 52 Perfume',
#    'Mamy Poko tissue basah buy 1 get 1',
#    'b"MAMYPOKO Baby Cleansing Wipes isi 52 Wet Tissue Basah Bayi Anak Isi 52s 52\'s Non Fragrance Parfume"',
#    'Mamypoko Baby Wipes Fragrance Perfumed Non Fragrance isi 52 sheet Tissue Basah Tisu Bayi'],
#   358732132: ['Stiker Kertas Motif Kawaii Lucu untuk Scrapbook / Travel',
#    'Sticker Deco Traveling Tour Bujo Journal Scrapbook DIY Lucu',
#    '45Pcs Stiker Kertas Motif Print untuk Dekorasi Album / Scrapbook DIY'],
#   359468572: ['b"JOHNSON\'S Baby Powder Blossom 300 gr"',
#    'Johnson’s Blossom Baby Powder 300 g'],
#   375388863: ['b"Nutrisari Jeruk Nipis 10\'s"',
#    'Nutrisari jeruk nipis ( 1 renceng )'],
#   375887598: ['iPhone 7 7G 8 8G  Kaca Kamera Belakang / Kaca Lensa Back Camera',
#    'Back Camera Ring Lens Cover / Kaca Lensa Kamera Belakang iPhone 7 Spare Part'],
#   378877183: ['Receiver Parabola KVISION BROMO C2000 K Vision HYBRID C BAND DAN KU BAND',
#    'Receiver Parabola KVISION BROMO C2000 K Vision HYBRID C BAND',
#    'Kvision BROMO C2000  Hybrid C Band dan KU Band Receiver Parabola'],
#   398382060: ['Avent Botol Natural 2.0 125ml Putih Twin NEW DESIGN',
#    'Philips Avent Bottle Natural 2.0 125ML/4OZ Twin Pack - SCF690/23'],
#   406103859: ['DOMPET CHANNEL SAPHIRE SUPER DOMPET WANITA CHANEL FLIP',
#    'DOMPET SAPHIRE CHANNEL DOMPET WANITA CHANEL KULIT BORDIR',
#    'DOMPET CHANNEL SAPHIRE SUPER DOMPET WANITA CHANEL FLIP DOMPET CHANEL MINI FLAT / DOMPET UANG KERTAS'],
#   410996998: ['Pemimpi(N) Edisi Amandemen-208041549',
#    'BUKU NOVEL PEMIMPI(N) WILDAN ALAMSYAH'],
#   411986394: ['My Lady Sarung Tangan Plastik-My Lady Disposable Gloves Isi 100 Pcs',
#    'Sarung tangan plastik sepasang',
#    'Sarung tangan plastik sepasang pelindung tangan',
#    'SARUNG TANGAN PLASTIK 100PCS - CLEANY DISPOSABLE HAND GLOVES - STP - HAND GLOVE',
#    'SARUNG TANGAN PLASTIK SEPASANG',
#    'STP sarung tangan plastik sepasang'],
#   420247011: ['FACE MASK APD SURGICAL MASKER BEDAH SENSI MEDIS 1 BOX ISI 50 PCS HEADLOOP HIJAB ORIGINAL',
#    'Masker sensi isi 50 3ply earloopp'],
#   421691417: ['Kenmaster Kunci Sok Socket Kunci Set Motor 27 Pcs',
#    'Kenmaster Socket Wrench Set 27pcs Kunci Sok 27 Sockets'],
#   424232472: ['Masker Kain Oxford Tali Karet Silang',
#    'MASKER KAIN OXFORD TALI KARET',
#    'Masker Kain Oxford Tali Karet'],
#   424698714: ['Apple iPhone 11 Pro 256GB, Midnight Green',
#    'Apple iPhone 11 Pro 256GB Midnight Green'],
#   424835120: ['Sapu Mini + Cikrak Sebaguna (Paket Hemat)',
#    'Sapu Pengki Set / Sapu dan Pengki Mini Set / Mini Dustpan',
#    'Sapu Pengki Mini Dustpan set Lion Star',
#    'Sapu Pengki Set / Sapu dan Pengki Mini Set / Mini Dustpan / Sapu Mini'],
#   426575092: ['JINISO - Highwaist Kulot Jeans 725 - 735 HYPE BAE',
#    'JINISO - Highwaist Kulot Jeans 720 - 730 HYPE BAE'],
#   431813341: ['NESTLÉ MILO ACTIV-GO Minuman Serbuk Cokelat Paduan dengan Malt Pouch 800g',
#    'Milo Activ-Go 3 In 1 800gr',
#    'Milo 3in1 Activ Go Pouch 800 gr'],
#   446113843: ['Alquran Special Edition Dian Sastro Dusty Pink',
#    'GRATIS TASBIH ALQURAN EDISI DIAN SASTRO DUSTY PINK - ALQURAN WAKAF TERBITAN ALQURAN EMAS'],
#   461576464: ['Pigeon Baby Liquid Soap 100Ml',
#    'Pigeon Baby Liquid Soap 100ml Sabun Mandi Anak Bayi'],
#   461757839: ['SOS HAND SANITIZER ANTISEPTIC SPRAY 100 ML  / ANTISEPTIK',
#    'SOS Hand Sanitizer Antiseptic Botol Spray 100ml'],
#   472964117: ['NICOLE  SEPATU KELSEY GS102', 'SEPATU SNEAKERS KELSEY GS102'],
#   475342649: ['3M 1600 T Double Tape PE Foam tebal: 1.0 mm, size 24 mm x 4m',
#    '3M Double Tape Foam 24 mm PE I Isolasi Solasi Bolak Balik Spon Busa 1600TG Daya Rekat Kuat Original',
#    '3M Double Tape Foam 24 mm PEI Isolasi Solasi Bolak Balik Spon Busa 1600TG Daya Rekat Kuat Original',
#    'DOUBLE TAPE BUSA 3M Pe Foam Tape 24mm x 4M ORIGINAL'],
#   480632610: ['KACA FLAT INJAK HITAM CLEAR',
#    'KACA BOGO Datar Merk INJAK Anti silau dan tahan gores'],
#   485086339: ['SARUNG TANGAN RAJUT TOUCHSCREEN POLOS WARNA',
#    'BUY 1 GET 1!! SARUNG TANGAN MOTOR TOUCH SCREEN / SARUNG TANGAN MOTOR SENTUH HP'],
#   494326981: ['Jellys - Pure Face Serum', 'Jellys Pure Face Serum'],
#   508237146: ['Joran Relix Nusantara Capung 662 UL 1-5 lb',
#    'Joran pancing capung relix nusantara  UL'],
#   510639683: ['MIRANDA TUNIK SALUR FIT XXL',
#    'MIRANDA SALUR TUNIK |  PAKAIAN MUSLIM BAHAN SPANDEK SALUR FIT XXL JUMBO'],
#   512890289: ['OTG Android Robot',
#    'Otg mini micro',
#    'JM OTG Non Kabel Micro (V8) / OTG Android Non Kabel Smart Mini Pack Kit On The Go Micro Usb Port'],
#   517260836: ['Twotone Mini Tas Slempang Polos Kombinasi Polos Sling Bag Slingbag (Tanpa ACC) [B9]',
#    'Twotone Mini Tas Slempang Polos Kombinasi Polos Sling Bag'],
#   521750822: ['SAMPO KUCING SHAMPO KUCING',
#    '[PROMO]Shampo Kucing/Anjing/Kelinci/Hewan Aroma buah EVOPET 100ML'],
#   523074739: ['KERANJANG BAJU LAUNDRY LIPAT SERBAGUNA CANVAS LAUNDRY BAG',
#    '0026 Keranjang Multifungsi bisa untuk tempat pakaian dan mainan anak - white flaminggo',
#    'Keranjang Baju Kotor / tempat baju kotor  Motif Lucu',
#    'Keranjang Baju Kotor Keranjang Pakaian Perlengkapan Rumah Tangga Tempat Penyimpanan Barang N0026',
#    'Keranjang Tempat Pakaian dan Mainan Anak'],
#   527536762: ['wallpaper dinding sticker  45cmx10m',
#    'Wallpaper dinding sticker 45 cm x 10 m'],
#   533127384: ['Bahan kain sprei disperse per 0,5 meter', 'Bahan seprei'],
#   544819779: ['Kedaung Superdoll Sendok Sop / Soup Ladle 6 Pcs',
#    'SUPER DOLL 404 Soup Spoon Sendok Sup Stainless Steel',
#    'Eros / Sendok Sayur Stainless Steel SC 504 Kedaung'],
#   554458429: ['Celana Chino Original Motz Khaki / Abu Muda / Cream / Hitam / Abu Tua',
#    'SMST Celana Chino Motz Reguler'],
#   555497581: ['Animal Farm Piano Mainan Piano dengan aneka musik ceria - A003',
#    'Mainan Anak musik animal piano farm lampu'],
#   565141089: ['LED 3 Sisi RTD M02D', 'LED RTD 3 Sisi M02D'],
#   567332828: ['CREAM MALAM Whitening / SPC 0,05 / HTD 0,05',
#    'SPC 0,05 / HTD 0.05 cream malam whitening / krim flek'],
#   570596922: ['Kertas lakmus 80 pcs suncare ph paper 80 strip blue red litmus paper cek tes air ketuban [PH80]',
#    'Alat tes air ketuban ibu hamil / Kertas lakmus merah / biru RED & BLUE LITMUS PAPER'],
#   571550607: ['Safi Age Defy Cream Cleanser Deep Moisturizer 150ml',
#    'Safi Age Defy Cream Cleanser Deep Moisturer 150ml',
#    'Safi Age Defy Cream Cleanser Deep Moisturizing 150ml',
#    'Safi Age Defy Cream Cleanser Deep Moisturizer -150ml',
#    '❤️SAFI❤️Age Defy Cream Cleanser Deep Moisturizer 150 ml',
#    'SAFI Age Defy Cream Cleanser Deep Moisturer 150ml'],
#   573213028: ['CS - Kaftan Falda Free Belt',
#    'KAFTAN CALAMARY // VNEXT CALAMARY'],
#   580982659: ['Emina Sun Protection SPF30',
#    'Emina sun screen spf pelindung wajah dari matahari'],
#   597750467: ['FE1ID Gigi Taring Palsu untuk Kostum / Cosplay nvcw',
#    'TB Gigi Taring Palsu Vampir untuk Kostum Halloween'],
#   598373701: ['Party Popper / Confetti ukuran 50 CM ( wilayah jawa timur )',
#    'Party popper /confetti (khusus wil. Jawa timur)',
#    'KHUSUS WILAYAH JABODETABEK / JAWA BARAT: Konfeti / Party Popper 30cm'],
#   603126590: ['GGMART KERTAS MINYAK WAJAH LINEN ISI 50PCS',
#    'Kertas Minyak Linen Alami'],
#   604966629: ['HANDGRIP HAND GRIP SPEEDS LX 011-05 ISI 2PCS LATIHAN TANGAN',
#    'Hand grip Foam Fitness Untuk memperkuat Tangan Original Speeds 011-05 isi 2 pcs,6bag=1.3kg',
#    'Handgrip Foam Alat Latih Otot Tangan Hand Grip Original SPEEDS',
#    'SPEEDS LX 011-5 HANDGRIP HAND GRIP ISI 2PCS LATIHAN TANGAN'],
#   608145621: ['Oishi Suky - Suky Seaweed 70gr',
#    'Oishi Suky-Suky Seaweed 14gr'],
#   609623801: ['Kirkland Minoxidil & Biotin 7500 mcg - Original',
#    'Kirkland Minoxidil 5% for men USA - penumbuh rambut jambang dan jenggot Original 100%',
#    'MINOXIDIL KIRKLAND SIGNATURE 5% 100% ORIGINAL .Penumbuh rambut .brewok dan lain lain.bukan wakdoyok'],
#   609989844: ['Paket Tabita 40Gr Exclusive Barcode + Exp Date Original',
#    'Paket Tabita Exclusive 40Gr Barcode + Exp Date'],
#   617416302: ['Manset tangan baselayer tangan thumbhole arm sleeve futsal voli badminton climbing hiking cycling',
#    'BEST SELLER - MANSET TANGAN BASELAYER ARM SLEVEE TANGAN PRIA / WANITA - FUTSAL/VOLI/BASKET',
#    'MANSET TANGAN OLAHRAGA MANSET BASELAYER TANGAN MANSET TANGAN PRIA WANITA'],
#   617690666: ['SanDisk Cruzer Glide 3.0 USB Flash Drive 64GB (CZ600)',
#    'SanDisk Flashdisk USB 3.0 Cruzer Glide CZ600 - 256GB',
#    'SanDisk Flashdisk USB 3.0 Cruzer Glide CZ600 - 64GB'],
#   618519444: ['Ringlight/ Lampu Selfie Led/ Ring Light',
#    'Ring Light selfie led bulat untuk camera hp flash'],
#   626965399: ['READY STOCK - Brosse HairRemover ORIGINAL + BERGARANSI - White & Rosegold',
#    'Flawless Finishing Touch Women Hair Remover Face / Penghilang bulu'],
#   628879513: ['Ready Stock Velvet Masker Kain masker motif Dewasa/ Masker Anak motif Velvet Masker NonMedis',
#    'Velvet Junior Masker Kain 2 Lapis Anak dan Dewasa Bamboo Katun',
#    'Velvet Junior Masker Kain Anak dan Dewasa Bamboo Katun / Masker 2 Lapis',
#    'VELVET JUNIOR Masker Anak dan Dewasa Hijab Nyaman Digunakan Masker kain 2 Lapis SBC'],
#   629327221: ['JILBAB INSTAN ADIBA SERUT JOKOWI POLOS murah | Jilbab Serut Polos | Jilbab Serut | Pet tali',
#    'JILBAB INSTAN jilbab serut adiba termurah hijab instan'],
#   644651698: ['Lap Fiber mobil - kain Lap cendol - Lap sarung Tangan microfiber F139',
#    'Sarung Tangan Microfiber/Sarung Tangan Kain/Lap Microfiber Serbaguna Murah',
#    'Serba Grosir Murah Sarung Tangan Cendol Microfiber Lap Tangan Serbaguna'],
#   655505601: ['Helm anak shincan karakter  - cip pst',
#    'Helm anak retro karakter - cip pst - sekilo isi 5',
#    'Helm anak sinchan karakter lucu - cip pst'],
#   659856182: ['chandrasurya TUSPIN BUNGA 7 Hijab Jarum Jilbab Aksesoris Wanita Korea Muslim Cantik',
#    'TUSPIN HIJAB PERAK PENITI JILBAB KERUDUNG',
#    'TUSPIN HIJAB PIN PENITI JILBAB FASHION AKSESORIS HIJAB PERAK',
#    'chandrasurya TUSPIN PITA Jarum Jilbab Hijab Aksesoris Wanita Muslim Korea Cantik Kerudung'],
#   661566022: ['mukena sarmilla katun polos renda rajut 2 | seri warna',
#    'Mukena Sarmila Renda Rajut 2 (1kg dapet 2mukena)'],
#   664348430: ['Wireless Door Chime Bell / Bel Pintu Rumah Tanpa Kabel V-ZORR 32 Musik',
#    'Bel Pintu Rumah Tanpa Kabel GP-1766 32 Musik - Wireless Door Chime Bell'],
#   667973873: ['ZN01 GUNTING KUKU KARAKTER MINI LUCU / CUTE NAIL CLIPPER',
#    'Gunting Kuku Karakter Mini Imut-Imut / Mini Nail Clipper Lucu',
#    'NA Gunting Kuku Karakter / Cartoon Nail Clipper / Nail Clipper'],
#   669096037: ['HADA LABO GOKUJYUN ULTIMATE MOISTURIZING LIGHT LOTION 100ml (GARIS HIJAU)',
#    '(Hijau) HADA LABO Gokujyun Ultimate Moisturizing Light Lotion 100ml BY AILIN'],
#   673158714: ['Glulagen', 'Glulagen original'],
#   675590285: ['Pompa Angin Tabung Meter Atlantis',
#    'Termurah Pompa Tabung Sepeda Motor / sepeda Merk Atlantis'],
#   676426694: ['Film Pelindung Layar Tempered Glass untuk Apple iPad Pro 2018 11 Inch 11" 2018 Apple iPad Pro 11 inch 11" 10.5 inch iPad Air 2 2017 3 Pro 9.7" 9.7 10.2 inch 2018 2020 air3 10.2" 2019 mini 2 3 4 5 2019 7.9" Tablet Screen Protector Tempered Glass Film',
#    'Tempered Glass Anker GlassGuard for iPad mini 4 Clear - A7400'],
#   678236612: ['COUPLE ARON 4WARNA',
#    'Couple Aron | Mosecrepe',
#    'COUPLE ARON / SET MOSCREPE PREMIUM CP ARON TERMURAH BAJU PASANGAN MUSLIM TERLARIS',
#    '[ Spesial Harga Grosir ] Baju Couple Set l COUPLE ARON',
#    '[ SUPER SALE ] Baju Couple Muslim Terlaris | Aron Cp Termurah',
#    'COUPLE ARON MUSLIM TERBARU CP ARON VH1'],
#   687378422: ['Ikat Pinggang Kanvas Pria Taktikal Militer - Canvas Military Tactical Belt - 125cm',
#    '(KK) SABUK GESPER TACTICAL MILITARY'],
#   696426687: ['SALE!!! GOLDENFIL STRAWBERRY & BLUEBERRY ( EXP MARET 2021 )',
#    'GOLDENFIL STRAWBERRY BLUBERRY JAM 250GR - SELAI PREMIUM RASA STOBERI BLUBERI - ISIAN OLESAN ROTI'],
#   696596987: ['Indomie Goreng Ayam Geprek HYPE - Netto 85 gram',
#    'Indomie Goreng Ayam Geprek (5 PCS)  - 85 Gram',
#    'Indomie Rasa Ayam Geprek 80g'],
#   717019588: ['READY SURABAYA!! Susu Almond Lactamond Bubuk /Premium 5x Minum/ ASI Booster Minuman Pelancar',
#    'BEST SELLER!! Susu Almond Lactamond Bubuk /Premium 5x minum/ ASI Booster Minuman Pelancar'],
#   717063212: ['Nan pH Pro 3 800 gr / Nan Ha 3 800 gr',
#    'NAN PH PRO 3',
#    'NESTLE NAN pH Pro Optipro Susu Pertumbuhan 1-3 Tahun Kaleng 400 gr',
#    'NESTLE NAN pH Pro Optipro Susu Pertumbuhan 1-3 Tahun Kaleng 800 gr'],
#   719136585: ['Mukena Dewasa Rayon Terusan Polos Clara',
#    'Mukena Terusan Bali Polos Clara Rayon Janger'],
#   719384223: ['Heavy Chiffon Pashmina / Arabian Pashmina Premium Quality Chiffon hijab Import Hijab Mayalsian',
#    'Turkish shawl katalog 2 ( Green & brown series )'],
#   719867603: ['adonit jot pro fine point round thin tip capacitive stylus pen ipad dan android',
#    '2 in 1 fine point round thin tip stylus pen capacitive ipad iPhone android universal',
#    'Adonit jot pro stylus pen drawing android',
#    'Capacitive Pen Two-in-one Conductive Cloth Silicone Suction Cup Dual Touch Full Metal Disc Painting Pen Stylus',
#    '(cou)(HOT!!!)Capacitive Pen Touch Screen Drawing Pen Stylus for iPhone'],
#   721296483: ['FYGALERYJAKARTA - Kaos Kaki Polos 6 Garis Unisex Fashion Wanita/Pria Kaos Kaki Import Murah Jakarta',
#    'DODORY - D020 Kaos Kaki Polos 6 Garis Unisex Fashion Wanita/Pria Kaos Kaki Import Murah Jakarta',
#    '✧YUKSHOPING✧ R103 Kaos Kaki Polos 6 Garis Unisex Fashion Wanita/Pria Kaos Kaki Import Murah Jakarta',
#    'MGM432 COD Kaos Kaki Ankle Wanita Fashion Korea Polos 6 Garis Murah Produk Import',
#    'ELFYDO - Kaos Kaki Polos 6 Garis Kaos Kaki Unisex Fashion Wanita/Pria Kaos Kaki Import Murah Jakarta'],
#   723872739: ['ELFYDO - Pulpen Emoticon Goyang Per Karakter Gel Unik Lucu Pena Emoji Goyang Import',
#    'FYGALERYJAKARTA - HL0089 Pulpen Emoticon Goyang Per Karakter Gel Unik Lucu Pena Emoji Goyang Import'],
#   727365641: ['ciput rajut dua warna / inner dua warna / ciput rajut /inner bandana rajut anpus',
#    'Bandana Rajut Twotone anti pusing !'],
#   731755076: ['Bawang merah brebes murah 1kg',
#    'Bawang merah Brebes 1kg',
#    'DNatural Bawang merah(1000gr )',
#    'Bawang merah'],
#   732573709: ['Pengharum Mobil Aroma Kopi Bali MINI/ Parfum Kopi Bali MINI Murah HIGH QUALITY ORIGINAL',
#    'Parfum Mobil Kopi Bali // Pengharum Mobil Aroma Kopi Bali "ORIGINAL"'],
#   737488646: ['BTC GAMIS KAKTUS RAYON VISCOSE IMPORT PREMIUM',
#    'GAMIS KAKTUS RAYON VISCOSE IMPORT PREMIUM'],
#   739038796: ['Selang Air Taman Magic Hose 30 Meter / Semprotan Air Fleksibel / Selang Air Ajaib 100FT SG-30',
#    'Termurah - Selang Air Magic Hose 30M'],
#   739474947: ['Ceradan Hydra 80gr',
#    'ORIGINAL Ceradan Hydra 80 g krim bayi pelembab kulit sensitif. Hydrating moisturising with Ceramide'],
#   768382632: ['Sustagen Kid Madu 800gr',
#    'susu sustagen kid 3 rasa vanila / madu 800gr',
#    'Sustagen Kid 3+ Vanila 800 gr '],
#   769563897: ['Sarung Tangan Karet Palm Fit Glove CG 805 BK  touch screen merek Comet',
#    'Sarung Tangan Karet Palm Fit Glove CG 805 BK'],
#   772217144: ['Cussons Baby Mini Bag / Cussons Gift Bag Set',
#    'ORIGINAL Cussons Gift Bag Set / Cussons Mini Bag & Cussons Medium Bag / Cusson / LEDI MART',
#    'Cussons Baby Gift Mini Bag',
#    'Cussons Gift Bag mini / Cussons Baby Mini Bag, Gift Set Bayi, Kado Bayi, Set Bedak Bayi',
#    'Cussons Baby Mini Bag Gift Set Bayi Cussons Set Bedak Bayi Cussons',
#    'CUSSONS BABY MINI BAG 1029',
#    'Cussons Baby Mini Bag - Perlengkapan Mandi Bayi',
#    'Cussons Baby Small Bag Set 4 Pcs - Perlengkapan Perawatan Bayi',
#    'Cussons Gift Bag Mini / Cussons Baby Mini Bag , Gift Set Bag',
#    'Cussons Gift Bag Mini / Cussons Baby Mini Bag, Gift Set Bayi/cussons',
#    'Cussons Baby Gift Mini Bag / Cussons Gift Bag Set',
#    '[BPOM] Cussons Gift Bag Mini Cussons Baby Mini Bag Set /',
#    '[BPOM] Cussons Gift Bag Set / Cussons Mini Bag & Cussons Medium Bag / MY MOM',
#    'Cusson Baby Value Pack Cusson Gift Set Cusson Baby Gift Set',
#    'Cussons Gift Bag mini / Cussons Baby Mini Bag, Gift Set Bayi, Kado Bayi, Set Bedak Bayi/100%original'],
#   779683199: ['Penjepit bulu mata magnetik/Alat bantu pasang bulu mata magnetik/Magnetic Eyelashes Applicator',
#    'Alat pasang bulumata magnet/magnetic eyelash applicator/penjepit bulu mata magnet/alat bantu magnet'],
#   781136593: ['Pakaian Olahraga Wanita Sport Bra Yoga Wanita Tanpa Kawat Murah Produk Import',
#    'TB 459 Sport Bra Wanita Olahraga Yoga Bra Tanpa Kawat Murah Produk Import'],
#   781924816: ['311 Pensil Alis JustMiss Oren PENDEK Pencil Eyebrow Just Miss Brown--g.k--',
#    '311 Pensil Alis JustMiss Oren PENDEK Pencil Eyebrow Just Miss Brown--grosir--',
#    'Pensil Alis JustMiss Oren PENDEK / Pencil Eyebrow Just Miss Brown (311) [ pusat ]',
#    '311 Pensil Alis JustMiss Oren PENDEK Pencil Eyebrow Just Miss Brown',
#    'Just Miss Eyebrow Pencil 311'],
#   785297015: ['Bonibol Cokelat Bola Toples isi 4 Toples @ 250 gram',
#    'Bonibol Cokelat',
#    'Bonibol Cokelat Bola Toples isi 4 Toples @ 250 gram PAKET LEBARAN'],
#   788453012: ['RAK DAPUR PORTABLE SUSUN 2 / RAK BAWAH WASTAFEL DAPUR KITCHEN RACK RUANG MAKAN SERBAGUNA STAINLESS',
#    'RAK PANCI SERBAGUNA SUSUN TEMPAT BUMBU ALAT DAPUR MASAK PANCI KITCHEN SET'],
#   794027803: ['Daster Bali / Dress Bali Black series pilih motif',
#    'DASTER BALI SIZE XL'],
#   800610000: ['WIRELESS STEREO AUDIO RECEIVER BLUETOOTH ADAPTER USB / USB BLUETOOTH',
#    'BLUETOOTH RECEIVER MUSIC USB WIRELESS BLUETOOTH STEREO AUDIO VEHICLE WARNA HITAM'],
#   805209030: ['Korean Style Jam Tangan Wanita Transparan Custom',
#    '[Bayar Di Tempat]Jam tangan wanita warna jelly transparan. mahasiswa baru yang kecil'],
#   807353588: ['NIVEA Body Serum Extra White Anti Age 180 ml',
#    'Nivea body serum extra white anti age 180 ml',
#    'Nivea Extra White Anti Age Body Serum 180ml'],
#   809466744: ['Emina Masquerade Face Mask 1 sachet',
#    'EMINA MASQUERADE FACE MASK 23GR',
#    'Emina Face Mask / Emina sheet Mask'],
#   812087588: ['Kaos turtleneck / kaos kerah tinggi',
#    'NEW RIB Turtle neck (Premium) Ribb kerah Berdiri/ turtle nex full catton  terlaris'],
#   814731988: ['Setelan Oblong Pendek Bayi & Anak Miabelle KN01',
#    'Miabelle Set Baju Pendek + Celana KN01'],
#   817678170: ['[FREE GIFT Min. Order 5pc] MASKER  POUPEEPOU 25GR / ORGANIC MASK POUPEEPOU (BISA COD)',
#    'PROMO [Beli 4 free GIFT] 25gr Masker Organik/ Organic Mask by Poupeepou',
#    '✅ BUY 9 GET 10 POUPEEPOU + FREE ONGKIR⭐️ Masker Organik 25 Gram By / Face Organic Original / COD'],
#   819794274: ['**PROMO JBL BT Speaker 113 Bass Wireless Portable Sound Bluetooth',
#    'Speaker Bluetooth JBL TG-113 Tabung Portable'],
#   821904178: ['Humidifier Air Aromaterapi Difuser Pelembab Penjernih Udara Air Purifier Atomizer 1000ml',
#    'Air Humidifier aroma oil diffuser Atomizer Ultrasonic USB portable 1000ml'],
#   823391133: ['[BS] BISA COD Pop Socket BTS BT21 KPOP Phone Holder Grip Popsocket HE001',
#    '[READY/COD] POPSOCKET BT21'],
#   826167769: ['Mic Speaker Bluetooth karaoke',
#    'MIC BLUETOOTH WS-858 ( bahan besi) WSTER SMULE WIRELESS / MICKROFON KARAOKE'],
#   834239325: ['Thai Boy Tom Yum Paste 500gr',
#    'THAI BOY TOM YUM SOUP PASTE 500g'],
#   835765986: ['Celana Dalam Pria Boxer Rajut - MR DAX UK L,XL',
#    'Celana dalam boxer pria rajut  MR DAX / UK L X'],
#   852044639: ['Lcd+Touchscreen Xiaomi Redmi 4X Fullset',
#    'LCD + Touchscreen FULLSET Xiaomi Redmi 4X',
#    'Lcd Touchscreen Xiaomi Redmi 4x Fullset Original Terlaris New',
#    'Lcd Touchscreen Xiaomi Redmi 2 / 2s Kualitas Original'],
#   856048725: ['Jam Dinding DIY Besar 130cm',
#    'Jam dinding diy besar 80-130cm diameter'],
#   857254217: ['Cream leher dosting whitening arbutin,cream leher dosis tinggi,cream leher original',
#    'CREAM LEHER / PEMUTIH LEHER 30gr',
#    'CREAM LEHER',
#    'CREAM LEHER PUTIH',
#    'Cream leher dosting whitening, cream leher arbutin, cream. Leher pot hitam original bpom'],
#   862718904: ['Uno Stacko Kayu Jenga 54 Balok Dengan 4 Dadu - Permainan Uno',
#    'Termurah Paling Murah Uno Stacko Kayu Jenga 54 Balok Dengan 4 Dadu'],
#   870195979: ['CARYN DRESS BY SHIERAKI INDONESIA', 'ZIARA DRESS'],
#   875243828: ['Mainan alat perkakas anak lelaki bahan kayu - wooden tools set - mainan edukasi',
#    'Wooden Tool Builder Construction Set - Pretend Play Handyman - Mainan Kayu Edukasi Anak Kado'],
#   885835646: ['LOLA TUNIK KOMBINASI / NINDYATUNIK / OCHA TUNIK MOSCREPE PREMIUM',
#    'TUNIK LOLA/ NINDYA/ OCHA MOSCREPE'],
#   885968235: ['Kertas A4 Paperone 80 gsm 1 Ream',
#    'Kertas - Paper one - A4 80Gsm - PO',
#    'Kertas PAPERONE A4 80 Gram Office Paper Print',
#    '[ GRAB - RIM ] Kertas PAPERONE A4 80 Gram Office Paper Print (PER RIM)',
#    'PaperOne Kertas Fotocopy A4 80gr - 1 Ream (500 lembar)'],
#   886336390: ['Tas pinggang consina coda waistbag consina',
#    'Consina Waist Bag Coda'],
#   895665581: ['cd gt man bw 704 I celana dalam pria merk gt man original full waist brief katun',
#    'celana dalam gt man bw704 jumbo 3 warna original - ukuran jumbo'],
#   896796648: ['WPC Pembersih Toilet Floral Botol 600ml',
#    'Pembersih Kloset WPC Extra Strong Floral 600ml'],
#   897689323: ['KURU WALKING ASSISTANT/ ALAT BANTU JALAN BABY / BELAJAR JALAN BAYI / BABY WALKING',
#    'KURU Walking Assistant Belt | Alat Bantu / Belajar Jalan Bayi',
#    'Kuru Walking Assistant Belt Belajar Jalan Bayi'],
#   917624949: ['Ponds Age Miracle Krim Wajah Youthful Glow Day Cream Moisturizer 50 gr - Krim Wajah Face Day Cream',
#    'Ponds Age Miracle Night Cream Moisturizer Krim Wajah Youthful Glow 50g'],
#   923083431: ['Bebelove gold 2 700gr', 'Bebelove 2 gold 700g'],
#   923851978: ['Serba Grosir Murah Bando Elastis Bergelombang Bando Rambut Bentuk Gelombang',
#    '❤TOKO MURAH ONLINE❤ Bando Elastis Bergelombang Bando Rambut Bentuk Gelombang'],
#   934827064: ['ENGRAVE IT / ALAT UKIR / PULPEN UKIR ELEKTRIK',
#    'EZ Engrave It / Alat Ukir / Pengukir Grafir Kain Kayu Besi / Engrave Ukiran / Engraver pen'],
#   936668906: ['Meihuadeer litepro MTB Road Bike Folding Bicycle Square Hole Left Right Chainring Crank Arm',
#    'Hellgood Litepro or JIANKUN Crank Arm Kiri/Kanan Lipat Untuk Sepeda Balap/Mtb'],
#   944479978: ['Jepit Rambut Hairclip Mutiara Set Jepitan Wanita Gaya Korea Style Pearl',
#    'SC!!!Jepit Rambut Bobby Pin P001 Hairclip Hairpin Aksesoris Jepit Rambut',
#    '2PC -4Pcs Jepit Rambut Gaya Korea untuk Wanita',
#    '4Pcs Jepit Rambut Korea dengan Mutiara untuk Wanita',
#    'Pearl Jepit Rambut hairpin four-piece suit Korean fashion women hair clips clip hair accessories F6',
#    'Set Jepit Rambut Hairpin Hairclip Korea Fashion Dengan Mutiara + Berlian Imitasi Untuk Wanita'],
#   950575580: ['CELANA TRAINING SAKU SLETING BAHAN TEBAL | CELANA TRENING OLAHRAGA SAKU SLETING',
#    'Celana training panjang adidas saku resleting'],
#   955309960: ['Botol Makanan, Bumbu Interlock Grain Container 1L-INL312 ORIGINAL LOCK&LOCK',
#    'Lock&Lock Interlock Grain Bottle'],
#   959118143: ['Spidol Ban Mobil Motor TOYO Karet Car Tyre Paint Marker Toyo Permanent - Putih',
#    'Spidol Ban TOYO PUTIH - Paint Marker Toyo Kualitas Terbaik'],
#   961119785: ['[Ecer] Garland Tassel Kertas Rumbai Metalik',
#    'Balonasia Garland Tassel Kertas Rumbai Metalik'],
#   962113684: ['Peci Songkok NU | Peci Bordir | peci Nu',
#    'Songkok peci Bordir Logo NU Tinggi 9 & 10'],
#   971745133: ['Cream hn 1000% original 15 gr segel bersertifikat/pemutih wajah glowing acne flek komedo jerawat',
#    'Cream HN Ori 15gr/krim HN ori,beli 10 gratis 1',
#    'PAKET PERAWATAN WAJAH -CREAM HN ORIGINAL 15GR - KRIM HN ORIGINAL || BELI 10 FREE 1',
#    'Cream HN Original 15gr',
#    'Paket Cream Hn - Cream Hn Original 15 gr beli 10 gratis 1',
#    'Cream HN 15 gr Beli 10 free 1 + FC Sertifikat'],
#   971802729: ['MIX NATURAL MASK BY ASEYORIKU SARERANG KAWUNG',
#    'JAKET CANVAS CSL-MR/ HOODIE / SWEATER /MASKER MIX NATURAL MASK',
#    '[DIST. RESMI] MIX NATURAL MASK by ASEYORIKU.ID',
#    'MIX NATURAL MASK BY ASEYORIKU'],
#   975885187: ['Shampo Pantene Pro-V Rambut Rontok & Anti Ketombe/Dandruff 900 ml',
#    'SHAMPO PANTENE ANTI KETOMBE 900 ML',
#    'Pantene pro-v 900ml',
#    'Shampo pentene',
#    'shampo pantene anti ketombe 900ml',
#    'Shampo pantene 900ml',
#    'Pantene Shampoo Anti Dandruff Anti Ketombe 750ml 750 ml / 900ml 900 ml'],
#   976528648: ['Buavita Orange 250 ml', 'Buavita Orange 250Ml vit C & A'],
#   978724801: ['Pixy Waterproof Mascara 7 ml',
#    'PIXY Waterproof Mascara 7ml',
#    'Pixy Waterproof Mascara Blue',
#    'Pixy Waterproof Mascara'],
#   988006312: ['MASKER KAIN NON MEDIS 3 PLY MOTIF READY STOCK (PART 3) BY AZHANIA',
#    'Masker Motif Kotak "BALI"'],
#   993561200: ['ISI STAPLES ETONA NO.10 stapler steples hekter kecil stepler murah meriah',
#    'isi staples etona no 10'],
#   1013219548: ['Highlighter Stabilo Boss Original Pastel set isi 6',
#    'STABILO Set 6 - BOSS Pastel Edition / Highlighter Original 6 pcs / Marker and Pen'],
#   1014487628: ['Kipas angin fan mini portable usb non powerbank power bank recharge cas portabel manusia',
#    'Kipas Mini Portable + Senter'],
#   1016178132: ['Tunik Longtop',
#    'Longtop Polos 6 Ukuran',
#    'Long top tunik polos',
#    'Long top polos',
#    'Longtop polos(LP)'],
#   1024453873: ['SENDAL JEPIT SPON PRIA / COWO SUMMER EVERY STEP  LOULUEN',
#    'sandal jepit spon pria owen murah',
#    'TERBARU!!! Sandal jepit pria LOULUEN',
#    'sandal jepit spon pria owen'],
#   1026787833: ['Novel - SENJA & PAGI',
#    'Senja dan Pagi/Alffy Rev/Bhumi Anoma x Loveable/Novel Romansa Original'],
#   1034382231: ['1 KG MUAT 4 PCS | LIRA OVERALL / OVERALL WOLFIS / OVERALL POLOS / OVERALL SELEBGRAM',
#    '1 KG BISA 4 PCS | LIRA OVERALL / OVERALL WOLFIS POLOS',
#    'LIRA OVERALL / OVERALL WOLFIS / OVERALL POLOS / OVERALL SELEBGRAM'],
#   1036330570: ['Sandal (Sendal) Masjid Musholla Wudhu Wakaf Sedekah - Sandal Jepit SJW 10',
#    'sandal Wudhu Masjid Musholla Sedekah Wakaf Murah - Sandal Jepit SWM 10',
#    'Sendal Wudhu~sendal jepit musholla',
#    'PROMOGROSIR 5 PASANG Sandal Wudhu  9 Warna',
#    'Sandal Wudhu Masjid promo murah',
#    'Sandal wudhu untuk wakaf dan sedekah'],
#   1036782779: ['Lampu tembak LED Bar CREE sorot kabut 6 mata worklight Offroad drl Motor Mobil Terang Tembus Hujan',
#    'E97 Lampu tembak LED Bar CREE 6 mata titik worklight Offroad',
#    'Lampu tembak LED Bar CREE sorot kabut 6 mata titik worklight Offroad',
#    'VSC134 Lampu Tembak LED Bar CREE 6 mata 6 titik Work Light Lampu Sorot'],
#   1037635218: ['Fedorafashion Fringe Loose Jeans Kemeja',
#    'Jaya_Co Jaket Jeans Fringe / jaket jeans rawis',
#    'HOPYLOVY - Kemeja Wanita Fringe Loose jeans 6208',
#    'JNY.Co Jaket Jeans Mirra Rumbai /Fringe Jeans 3 Warna',
#    'CS - Kemeja Jeans Wanita Fringe Rawis'],
#   1037916122: ['Jahe Merah Instan / Seduh Gholiban Kemasan Baru',
#    'jahe merah instan /bubuk gholiban',
#    'Jahe Merah Instan / Seduh Gholiban',
#    'Jahe Merah Instan / Seduh Gholiban 200 gr Kemasan BOTOL'],
#   1039816787: ['Kunci Sock Set Kenmaster ORIGINAL Key Shock Wrench Tools Kit 27 Pcs',
#    'Kunci Shock / sok set 27 Pcs Merek Kenmaster Original'],
#   1047766797: ['CELANA DALAM SUPER SOFT SOREX ART. 1253',
#    'Sorex Cd Basic Super Soft 1253 Halus Lembut'],
#   1056178808: ['Wallpaper Salur Biru - Wallpaper Dinding 9M x 45Cm',
#    'xvf-153 (3roll 2kg khusus JNE) Wallpaper dinding salur biru,hijau,pink,rainbow ukuran 45cm*10m ^^',
#    'Falecia7 Pekanbaru Wallpaper salur pink'],
#   1056998396: ['Longdres Kencana Ungu Label Biru / KUB Longdres Kalong  / KUB Longdres Kalong Serot',
#    'ECER harga GROSIR /daster jumbo/payung / yukensi jumbo /super jumbo / longdres / stelan gogo'],
#   1059857959: ['NYX Professional MakeUp 3 Steps to Sculpt - Face Sculpting Palette Make',
#    'NYX Professional MakeUp 3 Steps to Sculpt Make Up - Light (Highlighter, Contour, Illuminator Powder)'],
#   1060961612: ['Kpop Fashion Bando dan Bandana Cuci Muka Desain BTS Karakter BT21 Lucu untuk Wanita',
#    'ONE-C8 Bendo Fashion Wanita Headband / Bando Kepala Bangstan Boys'],
#   1071020646: ['Pintar Facil Basic Tool Paint Roll',
#    'BISA BAYAR COD Kuas Cat Tembok Roller Pintar Facil Kuas Cat Rol Cat Tembok Rol Cat Pintar Kuas Rol',
#    'Pintar Facil Alat Roll Paint Buat Cat Rumah Peralatan Tukang Bangunan  Lukisan Dinding Wall',
#    'Pintar Facil Smart Paint Roller Alat Cat Dinding Bangunan Rumah Kantor Toko Tembok Murah Praktis',
#    'Pintar Facil Paint Roller Kuas Cat Tembok Rumah',
#    'Pintar Facil Paint Roller / Kuas Cat Tembok Rumah',
#    'VOM Pintar Facil Paint Roller / Kuas Cat Tembok Rumah - 0354'],
#   1081076968: ['New IPad 2017 2018 2019 IPad 2 3 4 Pro 9.7 10.2 10.5 Mini 1 2 3 4 5 Air 1/2/3 Case, Smart Case Flexible Soft TPU Cover',
#    'Smart Case iPad Pro iPad Air iPad Mini iPad 2 3 4 iPad 11 The New iPad Stand Flip Case Cover iPad'],
#   1090017658: ['Sarung Tangan Plastik masak sarung plastik stp hand glove cleany kharisma stp',
#    'Cleany Sarung Tangan plastik disposable hand gloves isi 100'],
#   1091239019: ['Dress anak Pony / red strip pony / bahan scuba / usia 2thn s/d dewasa / dress anak import',
#    'Dress Princes Bahan Scuba Import / Dress Anak umur 2-9 thn / Baju Anak import LOL /'],
#   1098120565: ['Alkohol 70% Sol 100 Ml (Ika)', 'Alkohol Merk Ika 100 ml'],
#   1100459627: ['Stainless Steel Ruler Penggaris Besi Joyko RL-ST15 15 cm',
#    'Penggaris besi Rl-st15 stainless steel ruler 15cm Joyko'],
#   1102815811: ['Home-Klik Maxim Valentino Wok Teflon 30 cm Wajan Penggorengan',
#    'MAXIM Wok 30cm Valentino wajan penggorengan Teflon 30 cm two handle',
#    'Maxim Valentino Wok Wajan Penggorengan Teflon 36 cm (Merah)'],
#   1105071141: ['HS [COD] Tas Selempang Pria  Usb Port Terlaris',
#    'Selempang Kanvas Pria Tas Hp/Tas Dada Usb/Tas Impor Batam /Sling Bag Usb Kanvas/Selempang Kanvas#03',
#    'Tas selempang pria dengan port USB',
#    'Selempang Kanvas Pria Tas Hp/Tas Dada Usb/Tas Impor Batam /Sling Bag Usb Kanvas/Selempang Kanvas #03',
#    'Tas selempang usb'],
#   1107390930: ['Timbangan Gantung Besi 50kg/Timbangan Dus jarum 50kg -06',
#    'Timbangan Gantung Besi 100kg/Timbangan Gantung jarum 100kg'],
#   1110556867: ['[Bayar Di Tempat]Strap Jam Tangan Sport Bahan Nilon Woven 20mm 22mm 24mm untuk Gear S3',
#    'STRAP CANVAS 20MM 22MM 24MM NYLON TALI JAM TANGAN NATO ZULU DAN SMARTWATCH'],
#   1122805688: ['Thea overall jeans', 'THEA OVERALL JEANS  BEST SELLER'],
#   1124629473: ['MCDODO Kabel Charger MICRO USB Gaming Series 90 derajat',
#    'McDoDo 1.8M Kabel Gaming Fast Charging 3.0 Micro Original 90 Degree'],
#   1125778397: ['Super UTENSILE Granite 7 pcs Spatula Set Beige Original Bolde',
#    'BOLDe Super Utensil Set 7 Pcs Beige Series',
#    'BOLDë Set Sendok Masak + Tempat Sendok / Super Utensilë 7 Pcs - Beige'],
#   1130629555: ['Mommyclopedia 567 Fakta Tentang MPASI - ORIGINAL oleh Dr. Meta Hanindita',
#    'MOMMYCLOPEDIA  567 FAKTA TENTANG MPASI dr META',
#    'MOMMYCLOPEDIA 567 FAKTA TENTANG MPASI',
#    'Mommyclopedia 567 Fakta Tentang Mpasi By DR. META HANINDITA, SP.A(K)',
#    'Mommyclopedia 567 Fakta Tentang MPASI',
#    'Buku Mommyclopedia 567 Fakta tentang MPASI dr Meta Hanindita Original',
#    'Mommyclopedia 567 Fakta Tentang MPASI dr Meta Hanindita',
#    'MOMMYCLOPEDIA  567 FAKTA TENTANG MPASI',
#    'Mommyclopedia 567 Fakta Tentang Mpasi',
#    '((READY STOCK )) CUCI GUDANG Mommyclopedia 567 Fakta tentang MPASI',
#    'MOMMYCLOPEDIA 567 Fakta Tentang MPASI',
#    'Buku Mommyclopedia 567 Fakta Tentang Mpasi By DR META HANINDITA'],
#   1131724280: ['Cosmos Rice Cooker Harmond SPEKTRUM CRJ-6288 - 2 L',
#    'Cosmos Rice Cooker Harmond SPEKTRUM CRJ-6288 Green - 2 L',
#    'Cosmos Rice Cooker Harmond SPEKTRUM CRJ-6288 Red - 2 L'],
#   1135705464: ['【COD】Digital Tensimeter Blood Pressure Monitor Automatic Blood Pressure Gauge With LCD Monitor',
#    'Tensimeter Digital Alat Pengukur Tekanan Tensi Darah Blood Pressure Otomatis Dengan Monitor LCD'],
#   1137975225: ['Mukena Bayi Baby  Disney Tsum Tsum Pink Telekung Anak Cantik Lucu Imut Terbaru',
#    'mukena anak bayi balita karakter disney tsum pink usia 1 -2 tahun bahan full katun adem tas ransel',
#    'GROSIR MUKENA BABY DISNEY TSUM / 1-2 TAHUN',
#    'MUKENA KATUN BABY DISNEY  ( 1 - 2 Tahun )',
#    'Mukena Anak Bayi Karakter Size XXS Balita 1-2 Tahun Mukenah Baby Terbaru Tsum Pink',
#    'MUKENA ANAK DISNEY TSUM PINK (BABY/1-2 TAHUN)'],
#   1142999791: ['(ORIGINAL) KOMIK COOKIE RUN SWEET ESCAPE ADVENTURE MASA DEPAN',
#    'SCIENCE MASA DEPAN : Cookie  Run Sweet  Escape Adventure'],
#   1149953435: ['10pc Alat Pembersih / Pencuci Mesin Cuci Washing Machine Cleaner Washer  Detergent Effervescent Tablet Washer',
#    '12pcs Alat Pembersih Dan Pulpencuci Untuk Mesin Cuci'],
#   1152867952: ['Highlighter Joyko HL-54 Pastel Color - 6 Warna',
#    'Joyko Highlighter Spidol HL-54 Marker 6 Warna Pastel 2 in 1 Dual Tip'],
#   1164893262: ['Pisau Set Gunting Telenan Pisau Buah Pisau Daging Pisau Sayur Pisau Komplit Q2-013P Q2 013P',
#    'Pisau Set Talenan Telenan Knife Set Q2 013 P / Q2-013P / Q2 013P'],
#   1170528859: ['Blouse Combin Absnot', 'Blouse combin absnot'],
#   1173988427: ['Brush Pen / Brushpen /Spidol S nowman BM-1 (PCS)',
#    '[DAVIS] Brush Pen / Spidol Snowman BM-1 (PCS)',
#    'Snowman Brush Pen BM-1'],
#   1179256027: ['Vacuum Cleaner Penyedot Debu Mobil 12V 120W - Vacuum Cleaner Mobil',
#    'Penyedot debu dimobil kuat banget'],
#   1182013677: ['masker kain 3ply elastis earloop flexible masker import anak-remaja-dewasa motif animal cute lucu',
#    'VELVET JUNIOR Masker Anak Remaja Hijab Motif - Masker kain 2 Lapis - Full Print'],
#   1187474281: ['(ECER) Liptint Sasimi Hello Kitty Panjang',
#    '[Per Pc] Liptint Sasimi Doraemon Panjang',
#    '[Per Pc] Liptint Sasimi Hello Kitty Panjang S759',
#    '[Per PCS] Liptint Hello Kitty Sasimi Kode 6051 & S759',
#    'liptint sasimi karakter doraemon dan hellokitty original sweet liptint'],
#   1189638493: ['SERBET RAHAYU WARNA',
#    'SERBET CAP  BINTANG PRODUKSI',
#    'SERBET WARNA KJA'],
#   1191761858: ['EBOOK 4 BAHASA & 3 BAHASA - MAINAN EDUKASI EDUKATIF BUKU PINTAR E BOOK MUSLIM B27C',
#    'R27C E BOOK 4 BAHASA & 3 BAHASA - MAINAN EDUKASI EDUKATIF BUKU PINTAR EBOOK MUSLIM'],
#   1192720845: ['Carrera Spon Sabut Mobil', 'Carrera spon sabut mobil'],
#   1194587271: ['Keju Mozarella Perfetto 1KG / Mozzarella Cheese',
#    'Keju Mozarella Perfetto 1kg repack'],
#   1195866879: ['b"Hershey\'S Chocolate Syrup 680 gr"',
#    'b"Hershey\'s Syrup 680 gr"'],
#   1196220199: ['Grosir - T514 (BSR) Kotak Kosmetik / Kotak MAKE UP / Box MAKE UP / Box Kosmetik / Tempat Kosmetik',
#    'OSM - T514 Kotak Kosmetik / Kotak MAKE UP / Box MAKE UP / Box Kosmetik / Tempat Kosmetik'],
#   1202808302: ['GTA Hanger Folding Jemuran Baju Bulat Untuk Baju Bayi, Anak, Pakaian Dalam Bahan Besi Krom - GTA0025',
#    '[BAJA CHROME] HANGER FOLDING JEMURAN  BAJU BAYI, ANAK, JEMURAN BAJU BULAT HANGER / FOLDING HANGER'],
#   1207781649: ['PUSAT GROSIR SARUNG MAHDA - SARUNG SANTRI - SARUNG PONDOK',
#    'sarung batik mahda cap 32'],
#   1213652028: ['Khimar Ananta Jumbo 90cm Diamond',
#    'BERGO MARYAM KHIMAR ANANTA JUMBO DIAMOND  HIJAB NON PED HIJAB INSTAN'],
#   1218834240: ['Kotak Penyimpanan Perhiasan Barang Berharga Rahasia Model Buku Kamus',
#    '【GOGOMART】Buku Brankas / Safety Box - Size M 24.4 x 15.8 x 5.5 cm',
# ...
#    'Madame Gie Total Cover BB Two Way Cake Refill - Bedak Padat',
#    'Madame Gie Total Cover BB Two Way Cake - Bedak Padat Refill'],
#   2979556657: ['Energen Susu Sereal & Susu Bergizi rasa RENCENG (10 sachets x 30gr). ENERGEN',
#    'VARIAN RENCENG Energen Sereal Minum Makanan Bergizi Sarapan Aneka Rasa Halal MUI - 10pcs',
#    'RENCENG Energen Minum Makanan Bergizi Sarapan Sehat Pagi Hari - 10pcs x 29gr',
#    'RENCENG Mayora Energen Coklat Minum Makanan Bergizi Sereal Sehat Rasa Cokelat Nikmat - 10pcs x 29gr'],
#   2999871385: ['Merries Premium Popok Bayi Celana XL 19',
#    'Merries Pants XL19'],
#   3089782644: ['Lion Star Sahara Tempat Minum Panas dan Dingin / Drink Jar 4 L',
#    'Sahara Drink Jar Lion Star Murah'],
#   3102993776: ['jumper ritha / jump rita / liola TERMUR',
#    'Tk ritha jumper darkblue'],
#   3105935071: ['BUKU TEMATIK KELAS 2 TEMA 8 "KESELAMATAN DIRUMAH DAN PERJALANAN" KURIKULUM 2013 EDISI REVISI 2017',
#    'Buku tematik kurikulum 2013 kelas 2 tema 8 revisi Keselamatan di rumah dan perjalanan',
#    'BUKU TEMATIK SD KELAS 2 TEMA 8 -KESELAMATAN DI RUMAH DAN PERJALANAN-',
#    'Buku Tema 8 Kelas 2 sd kemendikbud',
#    'Buku kelas 2 tema 8 - Keselamatan di rumah dan di perjalanan - revisi 2017 terbaru',
#    'Buku Tematik SD Kelas 2 Tema 8 "Keslamatan di Rumah dan Perjalanan" Kurikulum 2013 Edisi Revisi 2017'],
#   3111883981: ['CANTONESE SUKI DIPPING SAUCE MERK PANTAI 435 ML',
#    'Pantai Cantonese Suki Sauce 435ml'],
#   3121370779: ['Pembersih hidung Bayi / Penyedot ingus Nose Cleaner silikon CherryBabyKidsShop 12 LC',
#    '❤ ELLOBEBE ❤ Pembersih hidung Bayi / Penyedot ingus Nose Cleaner silikon'],
#   3144637630: ['Taffware Bluetooth Audio USB External Soundcard Live Broadcast Microphone Headset - V8 Plus - Black',
#    'Bluetooth Live Mixer Broadcast Audio USB External Soundcard V8 Plus',
#    'Bluetooth Audio USB External Soundcard Live Broadcast Microphone Headset - V8 Plus - Black'],
#   3178097239: ['Strawberry - S8805 / Handphone Flip Dual SIM Card / HP Kamera Murah / Bluetooth',
#    'STRAWBERRY S8805 FLIP - MODE GETAR - CAMERA- MP3- DUAL SIM- LAYAR 2.4 INCH'],
#   3202957389: ['Bamboe Bumbu Nasi Goreng Pedas 40 g',
#    'BUMBU INSTAN NASI GORENG PEDAS - BUMBU BAMBOE',
#    'BAMBOE NASI GORENG PEDAS',
#    'Bumbu Bamboe Nasi Goreng Pedas',
#    'Nasi Goreng Pedas Bumbu Instant Bamboe',
#    'bamboe nasi goreng pedas 40 gr (1,4 oz)',
#    'Bamboe Bumbu Nasi Goreng 40g',
#    '[40 gr] Bamboe Nasi goreng Pedas /Spicy',
#    'Bumbu Nasi Goreng'],
#   3206685987: ['CELANA JOGGER PANJANG / SWEATPANTS / TRAINING PUMA GRADE ORI',
#    'CELANA JOGGER PANJANG PUMA GRADE ORI',
#    'Celana Training Panjang Jogger Puma KECiL Sweatpants Joger Pants pria wanita olahraga polos custom'],
#   3226686138: ['Kewpie Mayonaise Keju 200 gram | Cooking Sauce Cheese Mayo ECER',
#    'KEWPIE 200 gr| CHEESE MAYONISE | KEJU MAYO KUALITAS TERBAIK'],
#   3254898805: ['Mainan Mandi Bayi Kura kura berenang Toy Turtle Kualitas Import- Honey Boo',
#    'CR MB72 Mainan Mandi Bayi Bentuk Kura Kura Berputar Di Kolam Berenang',
#    'Mainan Anak Karakter Turtle Lucu Murah Berkualitas Cocok Menemani Mandi Bisa Bergerak - Pickaboo',
#    'RB MB72 Mainan Mandi Bayi Bentuk Kura Kura Berputar Di Kolam Berenang',
#    'GOGO MB72 Mainan Mandi Bayi Bentuk Kura Kura Berputar Di Kolam Berenang',
#    'MMTOYS MB72 Mainan Mandi Bayi Bentuk Kura Kura Berputar Di Kolam Berenang'],
#   3266934873: ['Car Charger / Colokan Mobil 4 Ports  QC3.0+2.4A+3.1AUSB JOYSEUS Fast Adapter Black - JM0005',
#    'JOYSEUS Q4 Car Charger 4 Ports USB QC3.0+2.4A+3.1A Charger Mobil fast charging'],
#   3279611604: ['Mola Granola Kemasan Baru / Sale / cemilan sehat bumil busui / pelancar Asi',
#    'Mola Granola Rasa Original 100gr'],
#   3291398615: ['Khong Guan Saltcheese Crackers',
#    'Khong Guan Saltcheese Crackers 200 gr'],
#   3323080982: ['Tetes softlens A+ Drop 10 ml',
#    'Tetes Softlens A+ 10ml',
#    'Tetes mata a+',
#    'Tetes mata a+ untuk softlens',
#    'A+ drop 10 ml tetes softlens',
#    'TETES MATA A+',
#    '[IMPORT] - Tetes Mata/ Obat Tetes Cairan Softles A + 10ML',
#    'TETES MATA A+ 10ML / A+ LENS DROP',
#    'CAIRAN SOFTLENS TETES A+ 10 ML / OBAT TETES MATA (DEPKES) (8420609)'],
#   3346396873: ['Sprei Homemade Karakter 120 160 180 Sprei murah seprei motif anak',
#    'Sprei homemade polkadot 160 180 bahan katun halus adem tdk luntur tidur nyenyak'],
#   3381128080: ['( 1KG BISA 4PCS ) Sweater Hoodie Pria War Bahan Fleece Tebal Ukuran M-L',
#    'COD ( 1KG BISA 4PCS ) SV SWEATER WAR LENGAN PANJANG PRIA / SWEATER / SWEATER FASHION PRIA',
#    'LONGTime379 / BISA COD / SWEATER PRIA ST.WAR HOODIE JUMPER / JAKET PRIA LENGAN PANJANG'],
#   3387596372: ['Pasta Gigi Nasa[jk]', 'ODOL NASA-PASTA GIGI NASA'],
#   3390060667: ['BTS8856 Tas Selempang Wanita Capres Kancing Dua Kombinasi 3 Warna Import High Quality',
#    'FUNATIC❤️ CAPRASE!! Tas Selempang Wanita Korea Style 3 Kombinasi Warna Uk 20 X 4 X 14cm FA856'],
#   3458021642: ['goldenfil aneka rasa 1kg',
#    'PROMO GOLDENFIL Varian Rasa 1Kg FREE BUBBLEWRAP',
#    'Goldenfil selai 1 kg'],
#   3468682012: ['Deli Pulpen Ball Pen Capable Halus - Warna Hitam Biru [0.5 mm] EQ02420 EQ02430',
#    'Deli Pulpen Ball pen Cetek halus - Warna Hitam [0.5 mm] EQ02420'],
#   3468800212: ['Perdana Axis non regist',
#    'Kartu Perdana Axis 0k SP Reguler Grosir Eceran'],
#   3469222388: ['Kertas Lipat Origami 12X12',
#    'Kertas Lipat ORIGAMI ASTURO KECIL 12cm'],
#   3485440553: ['(BISA COD) MUKENA RENDA RAYON MUKENA CASSANOVA PUTIH LUNA HJ81',
#    '(BISA COD) Mukena Silky Premium Mukena Travelling Mukena Dewasa dengan Tas Keren UU88',
#    '(COD) Mukena Silky Premium 2in1 Katun Sutera B7B8',
#    '(COD) Mukena tazkia/Mukenah Tazbiya Batik Flower Dewasa Jumbo Katun Rayon Cantik Travelling YT42',
#    'Mukena Cantik Tazkia / Tazbiya Mukena Bali Dewasa tiedye Amna size jumbo bahan adem Asli Bali E2X2',
#    'Mukena Dewasa Bordir Casanova',
#    'MUKENA DEWASA BORDIR CASSANOVA..',
#    'MUKENA DEWASA SEMI SUTRA CASSANOVA PUTIH MUKENA QALLILA MERK MUKENA YANG BAGUS POLOS'],
#   3498742965: ['Makaroni Spiral 500 gram / Spiral / Uril',
#    'Makaroni pipa/spiral 500gr'],
#   3593451990: ['Gery snack sereal keju 5x30gr',
#    'Gery Sereal Snack - Netto 30 gr',
#    'Gery Snack & Sereal Bantal Extrude Keju 27 gr x 5',
#    'Gery Sereal Bantal 30 Gram',
#    'gery sereal snack bantal 30grm'],
#   3599684856: ['[BPOM] NACIFIC Natural Pacific Phyto Niacin Whitening Toner 150ml',
#    'Nacific Phyto Niacin Whitening Toner 150ml',
#    'Nacific Toner Phyto Niacin Whitening Toner 150 ml'],
#   3601222703: ['[BISA BAYAR DI TEMPAT/COD] Everwhite brigtening body cream / ever white brightening body cream',
#    'Everwhite Brightening Body Cream (Strawberry Cherry Blossom)',
#    'Everwhite Brightening Body Cream Strawberry Cherry Blossom 100ml',
#    'EVERWHITE BRIGHTENING BODY CREAM PINK / EVER WHITE ORIGINAL 100 %'],
#   3633346051: ['BACKPACK RABBIT SET  !! TERLARIS / TERMURAH / TAS SEKOLAH',
#    'HANABI tas ransel 4in1 canvas bunny tas laptop sekolah kuliah kerja anak remaja cewe wanita murmer'],
#   3641991970: ['b"GRB - AZZAHRA SYARI - Najibah Gamis Syar\'i asd FLASH SALE SHOPEE LD:110 PB:140 AZZAHRA SYARI SATU"',
#    'Azzahra Syari Free  Hijab',
#    'Azzahra Syari dw',
#    '⭐ Azzahra Gamis Syari Maxi Dress gbmdw'],
#   3642429295: ['Madu Uray 330ml', 'MADU URAY 330ml', 'Puspita M Madu Kecil'],
#   3692357452: ['Q-San Toilet Seat Sanitizer Spray 60ml',
#    'QSAN Q-SAN Toilet Seat Sanitizer Pembersih dudukan Toilet untuk Penggunaan toilet WC Umum Travel'],
#   3701411077: ['Daun Insulin Curah Hikmah 40gr',
#    'yakon daun diabetes herbal ampuh',
#    'Teh Insulin Tubruk'],
#   3725046139: ['ABC Saus Tiram (425ml)', 'ABC Saus Tiram 425 ml'],
#   3725687789: ['Tube Squizzer Karakter  - 20 gr',
#    '[ACQ] Penjepit Pasta Gigi Karakter'],
#   3731124907: ['Tali Phone Strap Tali Gantungan HandPhone HP Flashdisk Kunci',
#    'STRAP TALI GANTUNGAN HP NAMA TAG GANTUNGAN KUNCI PHONE HOLDER',
#    'Tali Gantungan Hp Kamera Flasdisk Gadget Strap Multifungsi',
#    'HCR074 - Aksesoris Tali Gantungan HP Strap Gantungan HP',
#    'Tali Gantungan HP Strap Gantungan HP Smartphone Tab Universal - Random Color',
#    'Tali Gantungan HP 2in1 / Strap Gantungan HP Model Kalung'],
#   3772577569: ['Mama Greentea Botol 400ml',
#    'Mama Lemon Green Tea Botol 400ml'],
#   3779562915: ['(BTS) Sepatu Sneakers Breathable Anti Slip Motif Kartun untuk Unisex',
#    'Sepatu Canvas First Walker Bayi Laki-laki / Perempuan Anti Slip dengan Sol Lembut Model Lace Up',
#    'Sepatu Sneakers Breathable Anti Slip Motif Kartun untuk Laki-Laki / Perempuan',
#    'Sepatu Sneakers Kanvas Sol Lembut Anti Slip untuk Unisex',
#    'Sepatu Sneakers Olahraga Bahan Kanvas Elastis Kualitas Bagus untuk Anak Laki-laki / Perempuan',
#    'Sepatu Sneakers Prewalker Sol Lembut Anti Slip untuk Bayi Laki-laki / Perempuan',
#    'Sepatu Sport Canvas Korea Anak Laki-laki / Perempuan untuk Musim Gugur',
#    'Sepatu Sport Casual Unisex Bahan Kanvas',
#    'Sepatu Convey Fashion Sneakers Kids Shoes Sepatu Anak Import Size 26-32 Usia 3-6 Tahun'],
#   3788290200: ['MOST WANTED Kemeja Garis Garis Lengan Pendek Simple Stripes E-1225 E-1226 E-1227 E-1313',
#    'Kemejalaku Kemeja Garis-Garis Pria SHORT SIMPLE V BLACK STRIPES E-1225'],
#   3821827420: ['Pompa Tiup Angin Manual Tabung BESTWAY Air Hammer Inflation Pump 62002',
#    'Pompa Angin Tangan Bestway 12" 62002',
#    'Bestway 62002 Pompa Angin Tangan 30cm / Pompa Udara Manual 12"'],
#   3830107319: ['Buku Anak - Matematika Ceria untuk TK dan Paud',
#    'BUKU MATEMATIKA CERIA UNTUK TK & PAUD',
#    'Buku Anak - Matematika Ceria',
#    'Buku Matematika Ceria Untuk PAUD / TK Edukatif Murah'],
#   3832981571: ['XiaoMi Redmi Note9 Redmi 9 Note 8 Skin Feel Silicone Anti fall Shockproof Matte Translucence Frosted Case Cover',
#    'XIAOMI REDMI Case Bahan Silikon Matte Anti Jatuh Untuk Xiaomi Redmi 9 Redmi Note9 Note 8'],
#   3844282254: ['TONER BADAN SH COSMETICS TONER WHITENING  100ml',
#    'TONER BADAN WHITENING - SH COSMETICS'],
#   3856009840: ['Neo coffee moccachino 6+3 sachet',
#    'Neo Coffee Moccachino 200 gr'],
#   3868586553: ['FLASH SALE - CL14 - SET SYARI + KHIMAR MAYRAS - GAMIS SYARI KHIMAR',
#    'GGB - GAMIS SYARI + KHIMAR MAYRA - SETELAN SYARI TERLARIS',
#    'GAMIS SYARI TERBARU/ MAIRA SYARI bun'],
#   3926100920: ['Gea Baby Kantong Asi 120ml Thermal Sensor / Geababy Breast Milk Bag Storage 120ml /Kantung Asi Bayi',
#    '[BPOM] GEA Kantong Asi 120ml isi 30 Pcs / GEA Baby Breast Milk Bag / MY MOM',
#    'Kantong Asi Gea Baby Plastik Asip Breastmilk Storage Bag 120ml',
#    '[BPOM] GEA BABY /Gabag Kantong Asi 120ml / Breast Milk Bag isi 30',
#    'GEA BABY Kantong ASI 120ml',
#    'GEA Baby Kantong Asi breast Milk powder storage Bag 120ml 200ml 250ml 50gr safari classic edition',
#    'GEA Baby Kantong Asi 120ml 200ml 250ml | Kantong Susu Bubuk GEA 50g | Breast Milk Storage Bag 30pcs',
#    'KANTONG ASI GEA DENGAN THERMAL SENSOR 120 ML , 200ML DAN 250ML',
#    'Gea Baby Kantong Kantung Plastik Asi Asip 120ml Breastmilk Bag Thermal Sensor Panas Geababy Gea Baby',
#    'Gea Baby Breast Milk Storage Bag 120ml',
#    '[HARGA PROMO] GEA Baby Kantong Asi / Milk Bag Safari Edition 120ml Isi 30pcs',
#    'KANTONG ASI GEA BABY / GEA BREAST MILK STORAGE',
#    'GEA BABY KANTONG ASI 120ml THERMAL SENSOR / GEABABY BREAST MILK BAG 120ML THERMAL SENSOR',
#    'Gea Baby Kantong Asi 120ml',
#    'GEA Baby Kantong Asi Isi 30 Pcs 120ml / Breast Milk Bag Safari Edition',
#    'TERMURAH Kantong Asi dengan SENSOR PANAS Gea Baby 120ml 200ml 250ml cherrybabykidsshop LC',
#    '[BPOM] GEA BABY Kantong Asi 120ml / Breast Milk Bag isi 30 Pcs KANTONG ASI',
#    'GEA Baby Kantong ASI 120ml 200ml 250ml Sensor Panas',
#    '[HARGA PROMO] GEA BABY KANTONG ASI 120 / 200 / 250 ML Milk Bag Safari Mammal Edition 120ml Isi 30pcs',
#    'GEA BABY LION KANTONG ASI 120ML x 30PCS',
#    'Kantong asi gea baby thermal sensor 120 ml 120ml plastik asip sensor panas breastmilk storage brg',
#    'Kantong Asi GEA baby 120ml',
#    'Kantong Plastik ASI | Plastik Air Susu Anti Bocor GEA Baby | Breast Milk Storage Bag BPA Free',
#    'GEA BABY Breastmilk Storage Bags Kantong Asi 120 ml 200 ml 250 ml isi 30 pcs',
#    'GEA BABY Kantong ASI | Breastmilk Storage Bag | Powder Milk Bag [30 Pcs]',
#    'GEA BABY KANTONG ASI 120ml THERMAL SENSOR  / GEABABY BREAST MILK BAG 120ML THERMAL SENSOR',
#    'Kantong Asi dengan Sensor Panas GEA Baby 120ml 200ml 250ml',
#    '1 BOX GEA Baby Kantong Asi / Milk Bag Safari Edition 120ml',
#    'GEA BABY Kantong Asi 120ml 200ml 250ml / Kantong Asi GEA Breast Milk Bag isi 30 Pcs',
#    'Gea Baby Breast Milk Storage Bag 120ml kantong asi'],
#   3989979284: ['Freon Klea Kaleng R134 390 Gram',
#    'Freon Klea HFC 134a kaleng',
#    'Freon HFC 134a'],
#   3991519087: ['Frisian Flag Karya 456 Vanila 400 Gr Box 400 800 1200',
#    'Frisian Flag 456 Cokelat 400 gr [1 Pcs]',
#    'Frisian Flag 456 Vanila 400 gr [1 Pcs]',
#    'Frisian Flag 456 Vanila Cokelat Madu 400gr'],
#   4055533386: ['CITRA Sakura Fair Facial Foam 100 g',
#    'Citra Sakura Fair Facial Foam 100 gr'],
#   4080544366: ['rooster premium',
#    'ROOSTER PREMIUM MULTIVITAMIN SUPLEMEN JAMU HERBAL DOPING AYAM JAGO LAGA'],
#   4085784223: ['Caviplex',
#    'CAVIPLEX MULTIVITAMIN / HARGA PER BOX',
#    'CAVIPLEX MULTIVITAMIN'],
#   4180232347: ['Bathaholic Sweet Dream EO Aromatherapy Oil 15 ml Bathaholic',
#    'Bathaholic Citrus Twist Aromatherapy Pure Essential Oil 15ml Bathaholic'],
#   4184214313: ['Hijab Instan Cadar Niqab Anti Corona / Khimar Masker Cadar / Khimar Syari Jersey Cadar /Khimar Niqab',
#    'JILBAB SAFETY MASK NIQAB ANTI CORONA / JILBAB INSTAN / JILBAB SYRIA / JILBAB JERSY',
#    '( 1KG MUAT 5)  SAIDAH NIQAB FISIK BERGO HIJAB JILBAB KHIMAR INSTANT KHIMAR KERUDUNG SEGIEMPAT  100',
#    'Hijab instan Niqab/niqob jersey/Hijab masker instan jersey ukuran STANDAR',
#    'JILBAB SAFETY MASK NIQAB ANTI CORONA / JILBAB INSTAN / JILBAB SYRIA / JILBAB JERSY / BILLYSCRAFT',
#    'HIJAB BERGO SYRIA AZRIEL + CADAR NON PED KHIMAR INSTAN SUPER JUMBO WOLFIS PREMIUM',
#    'KHIMAR MADINA XXXL ORIGINAL NIZAM SYARI JUMBO NONPED TALI BISA CADAR GOOD JERSY',
#    'FRENCH KHIMAR MADINA 2 IN 1 NIQOB JUMBO XXL',
#    'b"Jilbab syar\'i 2aulia jumbo list Kombi min 5pcs/ model"',
#    'MADINA CADAR HIJAB JUMBO XL uk 100x120cm',
#    'Hijab Instan Jersey Safety Mask Zaina Niqab Anti Corona Non Pad By Kalisha',
#    'JILBAB MADINA CADAR INSTAN TERBARU',
#    'KERUDUNG INSTAN SYARI CADAR MASKER HIJAB JERSEY NIQAB NON PAD MURAH ANTI CORONA KHIMAR BANDUNG',
#    'JILBAB INSTAN AURELLE TUTON/HIJAB SAFETY MASK/ HIJAB INSTAN',
#    'KHIMAR CADAR 2 in 1',
#    'Hijab Instan Syiria Niqab Jilbab Anti Corona Matt Jersey',
#    '(1kg muat 5pcs) MADINA CADAR HIJAB JADI SATU PET ANTEM HIJAB JILBAB KHIMAR KERUDUNG BERGO INSTANT',
#    'Hijab Instan Syria Niqob Anti corona',
#    'HIJAB MADINA ANTI CORONA BERGO NON PET JUMBO MASKER INSTAN JERSEY PREMIUM',
#    'JILBAB SAFETY MASK NIQAB ANTI CORONA / JILBAB INSTAN / JILBAB SYRIA / JILBAB JERSEY',
#    '(1kg muat 5pcs) MADINA CADAR HIJAB JADI SATU PET ANTEM HIJAB JILBAB KHIMAR KERUDUNG',
#    'HIJAB SAFETY MASK NIQAB ANT200I DEBU / HIJAB INSTAN / HIJAB SYRIA / HIJAB JERSY (PET)',
#    'DF - MADINA HIJAB CADAR JADI SATU // TUDUNG JILBAB JUMBO XL',
#    'jilbab 2 in 1 // French jilbab cadar //Khimar Pinguin Tanpa Lengan / French Hijab Yumna /',
#    'Hijab instan safety anti corona / jilbab niqab / hijab niqob / hijab mask / hijab cadar'],
#   4220805733: ['Travel Charger casan Xiaomi Fast Charging Xiaomi Charger - Xiaomi Fast',
#    'Charger Xiaomi Fast Charging QC 3.0 model MDY-08-EL Best OEM Quality.Charger Xiaomi Micro USB Type C'],
#   4223895082: ['KUNCIRAN RAMBUT CHIBI RANDOM',
#    'Bandana Model Ikatan Pita dengan Bahan Kain Elastis untuk Perempuan'],
#   4234045315: ['Masker Organik / Organic Mask 20gr',
#    'Masker Organik / Organic Mask 50gr'],
#   4243244534: ['Mamas Papas Sleepsuit Set 3 in 1 Pink Flower',
#    'BDOSTORE - BEST PRICE! 3in1 Sleepsuit Pink Stripe Flower'],
#   4273295621: ['Cutting Mat Joyko A3 Alas Potong',
#    'Cutting mate A3 tatakan alas potong',
#    'Cutting Mat a3 Joyko Double Side'],
#   4281986560: ['TOPI BASEBALL ANAK POLOS GROSIR MURAH',
#    'Topi Bassball Anak / Topi Anak']}]

# %%
def get_split(f):
    for i,s in enumerate(splits_sets):
        if f in s:
            return i
    raise ValueError(f'File {f} is not presented in any split.')

# %%
f_0 = splits_files[0][984]
f_1 = splits_files[1][65]

get_split(f_0) == 0, get_split(f_1) == 1
# Out:
# (True, True)

# %%
def label_func(f):
    return df_train[df_train['title'] == f]['label_group'].values[0]

# %%
l_0 = train_labels[654]
l_1 = validation_labels[69]

f_0 = np.random.choice(df_train[df_train['label_group'] == l_0]['title'])
f_1 = np.random.choice(df_train[df_train['label_group'] == l_1]['title'])

label_func(f_0) == l_0, label_func(f_1) == l_1
# Out:
# (True, True)

# %%
spacy = WordTokenizer(lang = 'id')
tkn = Tokenizer(spacy)

# %%
class SiameseTransform(Transform):
    def __init__(self, files, splits):
        self.splbl2files = [(df_train.loc[splits[i]]).groupby(['label_group'])['title'].apply(list).to_dict() for i in range(2)]
        self.valid = {f: self._draw(f,1) for f in files[splits[1]]}
             
    def encodes(self, f):
        ## self.valid.get: Return the value for key if key is in the dictionary, else default.
        f2, same = self.valid.get(f, self._draw(f, 0))
        txt1, txt2 = f, f2
        return SiameseText(txt1, txt2, same)
    
    def _draw(self, f, split = 0):
            same = random.random() < 0.5

            cls = label_func(f)
            split = get_split(f)

            if not same:
                cls = random.choice([l for l in labels[split] if l != cls])

            return random.choice([f2 for f2 in self.splbl2files[split][cls] if f2 != f]),int(same)

# %%
tfm = SiameseTransform(files, splits)
tls = TfmdLists(files, [tfm, tkn, Numericalize], splits = splits)
dls = tls.dataloaders(bs = 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-168487af189b> in <module>
#       1 tfm = SiameseTransform(files, splits)
# ----> 2 tls = TfmdLists(files, [tfm, tkn, Numericalize], splits = splits)
#       3 dls = tls.dataloaders(bs = 8)
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/foundation.py in __call__(cls, x, *args, **kwargs)
#      95     def __call__(cls, x=None, *args, **kwargs):
#      96         if not args and not kwargs and x is not None and isinstance(x,cls): return x
# ---> 97         return super().__call__(x, *args, **kwargs)
#      98
#      99 # Cell
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastai/data/core.py in __init__(self, items, tfms, use_list, do_setup, split_idx, train_setup, splits, types, verbose, dl_type)
#     239         if do_setup:
#     240             pv(f"Setting up {self.tfms}", verbose)
# --> 241             self.setup(train_setup=train_setup)
#     242
#     243     def _new(self, items, split_idx=None, **kwargs):
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastai/data/core.py in setup(self, train_setup)
#     255
#     256     def setup(self, train_setup=True):
# --> 257         self.tfms.setup(self, train_setup)
#     258         if len(self) != 0:
#     259             x = super().__getitem__(0) if self.splits is None else super().__getitem__(self.splits[0])[0]
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in setup(self, items, train_setup)
#     190         tfms = self.fs[:]
#     191         self.fs.clear()
# --> 192         for t in tfms: self.add(t,items, train_setup)
#     193
#     194     def add(self,t, items=None, train_setup=False):
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in add(self, t, items, train_setup)
#     193
#     194     def add(self,t, items=None, train_setup=False):
# --> 195         t.setup(items, train_setup)
#     196         self.fs.append(t)
#     197
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/transform.py in setup(self, items, train_setup)
#      77     def setup(self, items=None, train_setup=False):
#      78         train_setup = train_setup if self.train_setup is None else self.train_setup
# ---> 79         return self.setups(getattr(items, 'train', items) if train_setup else items)
#      80
#      81     def _call(self, fn, x, split_idx=None, **kwargs):
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#     116         elif self.inst is not None: f = MethodType(f, self.inst)
#     117         elif self.owner is not None: f = MethodType(f, self.owner)
# --> 118         return f(*args, **kwargs)
#     119
#     120     def __get__(self, inst, owner):
#
# ~/miniconda3/envs/fastai2/lib/python3.8/site-packages/fastai/text/data.py in setups(self, dsets)
#      40         if dsets is None: return
#      41         if self.vocab is None:
# ---> 42             count = dsets.counter if getattr(dsets, 'counter', None) is not None else Counter(p for o in dsets for p in o)
#      43             if self.special_toks is None and hasattr(dsets, 'special_toks'):
#      44                 self.special_toks = dsets.special_toks
#
# ~/miniconda3/envs/fastai2/lib/python3.8/collections/__init__.py in __init__(self, iterable, **kwds)
#     550         '''
#     551         super(Counter, self).__init__()
# --> 552         self.update(iterable, **kwds)
#     553
#     554     def __missing__(self, key):
#
# ~/miniconda3/envs/fastai2/lib/python3.8/collections/__init__.py in update(self, iterable, **kwds)
#     635                     super(Counter, self).update(iterable) # fast path when counter is empty
#     636             else:
# --> 637                 _count_elements(self, iterable)
#     638         if kwds:
#     639             self.update(kwds)
#
# TypeError: unhashable type: 'L'

# %%
b = dls.one_batch()

# %%
dls.vocab
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxrep',
#  'xxwrep',
#  'xxup',
#  'xxmaj',
#  1,
#  0,
#  '✧YUKSHOPING✧ R103 Kaos Kaki Polos 6 Garis Unisex Fashion Wanita/Pria Kaos Kaki Import Murah Jakarta',
#  '[NATURE REPUBLIC] - Fresh Herb Cleansing Foam 170ml',
#  'Botol Susu + Drying Rack Set Disney Isi 4 Winnie The Pooh | Kado Bayi',
#  'Tissue tisu paseo smart handky ( 12sheet )isi 6bungkus',
#  'HANDBAG DOUBLE ZIPPER',
#  'RANGKAIAN BUNGA ARTIFICIAL SEPEDA VESPA MINI BP014',
#  'SALE!!! GOLDENFIL STRAWBERRY & BLUEBERRY ( EXP MARET 2021 )',
#  'Anti Blue Light Film Sony Xperia XZ1 XZ3 XZ/XZ2 Premium XA2 Plus/Ultra Xperia 1 10 Plus Screen Guard',
#  'Joran pancing capung relix nusantara  UL',
#  'kitty plus shampoo jamur kutu anjing kucing250ml',
#  'ASIN829 - D09 DOMPET LIPAT PENDEK FOREVER YOUNG IMPOR',
#  'Celana dalam boxer pria fema sport (Paket isi 6)',
#  'CARYN DRESS BY SHIERAKI INDONESIA',
#  '45Pcs Stiker Kertas Motif Print untuk Dekorasi Album / Scrapbook DIY',
#  'MIYAKO HM620 Hand Mixer / Handmixer HM-620',
#  'Papan tulis anak free spidol+penghapus+Tali beli min 10pcs harga 30rb',
#  'Cover Sarung Pelindung Remote TV AC dll Lucu Bungkus Pembungkus Remot',
#  'FYGALERYJAKARTA - Klip Jepit Foto Mini Bahan Kayu Uk. 35mm Wooden Clip Pack Isi perpack Murah',
#  'Nutrilon Royal 4 VANILA /MADU ACTI Duobio',
#  'Uno Stacko Kayu Jenga 54 Balok Dengan 4 Dadu - Permainan Uno',
#  '[COD] Sajadah Tas Dompet MASJID /pcs Sajadah Turki Tipis Travel Traveling / Oleh Oleh Haji Umroh',
#  'Kikkoman Ponzu Sauce 150 ml Saus Dipping Shabu-shabu',
#  'Makanan Basah Anak Kucing / Wet Food Kitten Whiskas Junior',
#  'GLADIS JAKET JEANS RAWIS CROPED SNOW JACKET WANITA // Nirina Acid Crop Jaket',
#  '4in1 Jam Tangan Arloji Anak Digital Karakter Superhero Avenger Unicorn Frozen Cars LOL Little Pony',
#  'CREAM MALAM Whitening / SPC 0,05 / HTD 0,05',
#  'Food Tongs / PENJEPIT MAKANAN / GORENGAN / BBQ',
#  'Buku Cerita Bergambar Seri Balita pintar dan muslim Paud colour',
#  'Degra Simba Obat WC Mampet - Ecer dan Grosir',
#  'Tenda anak 200 x 200cm',
#  'Kit Wiper Fluid Pouch 400 ml',
#  'Oishi Suky-Suky Seaweed 14gr',
#  'OVERSIZE CARDI MARUKO',
#  'MOMOGI 20pc jagung bakar, keju, coklat,tutti,cappucino',
#  'NYX Professional MakeUp 3 Steps to Sculpt - Face Sculpting Palette Make',
#  'Multi steaming pan merk advance c18 / panci elektrik multifungsi / panci listrik / hiter mug listrik',
#  'Buku Anak - Belajar Bahasa Inggris untuk TK',
#  'Selfie ring led lampu pencerah selfie',
#  'Mc Lewis Saos BBQ 310 gr',
#  'Lens Cap Tutup Lensa untuk Lensa Kamera Canon Nikon Sony Alfa Alpha',
#  'OTG Android Robot',
#  'Kikkoman Soy Sauce All Purpose - jerigen 2L',
#  '3M VHB Double Tape Automotive 4900 tebal 1.1 mm size 12mm x 4.5m - 1 Pcs - Merah',
#  'JAKET CANVAS CSL-MR/ HOODIE / SWEATER /MASKER MIX NATURAL MASK',
#  'Madu Hitam Pahit Pro Raja Lebah plus Propolis POM BPOM Asli 100% Original',
#  '(TERMURAH) 10GRAM BPOM MASKER PEEL OFF PEELOFF MASK PHILOCALY SKIN',
#  'Receiver Parabola KVISION BROMO C2000 K Vision HYBRID C BAND',
#  'Vacuum Cleaner Penyedot Debu Mobil 12V 120W - Vacuum Cleaner Mobil',
#  'TERMOMETER / THERMOMETER AICARE INFRARED [100% BRANDNEW]',
#  'Pelilit Kabel Spiral Warna Metalic / Pelindung Cable Hp Charger Universal / Cord Protector Color',
#  'Pepsodent Action 123 Pasta Gigi Charcoal 160 gr - Pasta Gigi Charcoal Pasta Gigi Action Toothpaste',
#  'Grosir - T514 (BSR) Kotak Kosmetik / Kotak MAKE UP / Box MAKE UP / Box Kosmetik / Tempat Kosmetik',
#  'Tas selempang usb',
#  'Fix LIVE  76rb - 95rb',
#  'PREMIUM Full Cover Tempered Glass 5D 6D 9D Warna Xiaomi Redmi 5 Plus (5.99 inch)',
#  'Nutrijel B Plain Box/ Jeli Tanpa Rasa/ Jeli Plain 15gr',
#  'Nutrijell Plain kemasan 1 kotak isi 12 saset 15grm',
#  'CELANA JEANS PANJANG ANAK LAKI LAKI PENSIL RIB 1-6 TAHUN',
#  'MANOHARA XL MOTIF AKAR',
#  'Jam dinding diy besar 80-130cm diameter',
#  'NOBLUK SOFTLENS ( DREAMCON )',
#  'syana hijab spray (hijab jadi tegak, wangi dan hygiene)',
#  'Wooden Tool Builder Construction Set - Pretend Play Handyman - Mainan Kayu Edukasi Anak Kado',
#  'JE Kelambu Jaring Tenda Kasur K76 160 x 200 cm Kelambu Tempat Tidur jaring anti nyamuk',
#  'Sepatu Safety Boots Pria Cladico Roadster Low Best Seller Terbaru',
#  'Antis hand sanitizer 1 Liter MERK hand sani (murah legit)',
#  'Daster Bali / Dress Bali Black series pilih motif',
#  'Appeton Weight Gain Adult 450gr PROMO SPECIAL',
#  'Gorden jendela kupu kupu minimalis ikat tengah',
#  'Milk frother / pengocok / pengaduk buih susu',
#  'Teh Daun Jati Cina | Teh Jati Cina Original Curah Kencoro Sari | Teh Herbal 100% alami',
#  'lemari plastik triple club flip 3 susun',
#  'b"Dr.Brown\'s Silicone Finger Toothbrush with Case / Sikat gigi bayi / sikat lidah bayi - HG010"',
#  'Pengharum Ruangan Aroma Terapi Essential Oil',
#  'Ikat Pinggang Kanvas Pria Taktikal Militer - Canvas Military Tactical Belt - 125cm',
#  '[DAVIS] Brush Pen / Spidol Snowman BM-1 (PCS)',
#  'PILIHAN CERDAS WARNA LENGKAP FRENCH HIJAB NIQOB/HIJAB KORONA TERMURAH...',
#  'KAFTAN CALAMARY // VNEXT CALAMARY',
#  'Botol Shower Gel Portable Bahan PP Motif Bunga untuk Kamar Mandi',
#  'Super UTENSILE Granite 7 pcs Spatula Set Beige Original Bolde',
#  'Headset JBL XB450',
#  'Jepang CD imut fashion Undies Celana Dalam Wanita Polos high quality katunimport CD sexy import',
#  'Koko lis hedlong baju koko lis simple lengan 3/4 four one  kurta pakistan',
#  'Cedea fish roll 250gr isi 10pcs',
#  'celana dalam gt man bw704 jumbo 3 warna original - ukuran jumbo',
#  'KURU WALKING ASSISTANT/ ALAT BANTU JALAN BABY / BELAJAR JALAN BAYI / BABY WALKING',
#  '[✅COD] A6S TWS Bluetooth 5.0 Wireless Headset Stereo Bass Noise Cancelling for Android IOS',
#  '10pc Alat Pembersih / Pencuci Mesin Cuci Washing Machine Cleaner Washer  Detergent Effervescent Tablet Washer',
#  'Hellgood Litepro or JIANKUN Crank Arm Kiri/Kanan Lipat Untuk Sepeda Balap/Mtb',
#  'RAUTAN PENSIL KARAKTER / RAUTAN PENSIL IMPORT',
#  'HOT SALE /GAMIS HAYLA DRESS MO',
#  'Pompa Galon Elektrik Fleco Original SP-92',
#  'AHDAVASHOP Panci Elektrik Panci Listrik Multifungsi C-18',
#  'HIJAB DEENAY CORNER SERIES ARMY',
#  '[Bayar di Tempat]30Pcs 5ml Plastic Centrifuge Lab Test Tube Vial Sample Container Bottle with Cap',
#  'Ponds Age Miracle Night Cream Moisturizer Krim Wajah Youthful Glow 50g',
#  'KABEL LAN OUTDOOR FTP CAT5 KABEL UTP 20 METER PABRIKAN HIGH QUALITY BIRU',
#  'Isolasi Super Clear / Tape Clear 12mm X 90yard',
#  'Lion Star Botol Saus / Sauce Keeper 325 mL (SK-406)',
#  'CELEMEK - APRON - CELEMEK ANTI AIR KARAKTER ANIMAL',
#  'BROCO KONTRA STEKER GEPENG BIASA HITAM 334LN (HARGA GROSIR) 334N PLUG COUPLER PENYAMBUNG COLOKAN',
#  'Miya Himi Gouache Color 24clr x 30ml with case (free brush & palette)',
#  'Maybelline Color Sensational Powder Matte Lipstick MakeUp',
#  'Tas Ransel 107113 (1 KG MUAT 2) LT1746 EL738 JT7113 127072',
#  'Everwhite Brightening Essence Serum 15Gr / Memutihkan Wajah / Mencerahkan',
#  '⚫️ Alat cukur Pencukur Alis / Pisau Alis Tinkle',
#  'Paket Tabita 40Gr Exclusive Barcode + Exp Date Original',
#  'Plastik pelindung baju dari debu tebal 50 micron MURAH',
#  'Oishi Suky - Suky Seaweed 70gr',
#  '[ BPOM ] MASKER PEEL OF PHILOCALY 10 gr',
#  'PAKET COMBO !! TURUN CEPAT DALAM 1 MINGGU',
#  'Alat Pel Q2-103 Busa Keras Free Refill (Bonus)',
#  'Oxone Pembuka Botol / Can Opener',
#  'MADU HITAM PAHIT CURAH BERKUALITAS',
#  'Kuas Set + Palet Cat Joyko BRUSH SET BRS-7',
#  'REMAX Metal Wired Music Headset With Mic RM-512 (New Package)',
#  'KOJIE SAN FACE LIGHTENING CREAM 30GR',
#  'Silicone Food Brush / Kuas Silikon Makanan',
#  'Air Humidifier aroma oil diffuser Atomizer Ultrasonic USB portable 1000ml',
#  'Sepatu KOREA JINTU 2020',
#  'Balon Latex warna PASTEL Satuan / Balon Karet ( per Biji eceran )',
#  'BOLDe Rice Cooker 3D SUPER COOK 1 Liter - PALLADIUM',
#  'Catok NOVA Mini 2 in 1 BEST QUALITY / Catok Rambut 2in1 Pelurus Curly Straight Lurus Keriting',
#  'sarung batik mahda cap 32',
#  'PEEL OFF MASK 50GR MAHIRA BEAUTY',
#  'Buavita Orange 250 ml',
#  'Spidol Ban TOYO PUTIH - Paint Marker Toyo Kualitas Terbaik',
#  'CASH REGISTER HELLO KITTY DN710 MASIN KASIR KASIRAN kado hadiah Mainan Anak perempuan pink putih',
#  'Test Hamil ONEMED 20mIU',
#  'TAS IMPORT FASHION RANSEL 93211 7072 17113 e738',
#  '[SHARE] NACIFIC Natural Pacific Fresh Herb Origin Serum & Facial Cream & Calendula Tincture Toner',
#  'BG - Laudya dress brukat elsire brokat tile busui seragaman pesta gamis kondangan full tile',
#  'Presto Oxone 4 Liter OX 2004',
#  'Vaya Sport Bra Seamless Ada Busa Art 001',
#  'Silikon payudara tak terlihat mengangkat bra/Tempel Dada Telinga kelinci/Baru Bra Strapless Backless',
#  'Silkoro hair serum treatment',
#  'Temulawak Bubuk Pack',
#  'PAKET COMBO (EXPRESS+DELUXE+TEH)',
#  'TAS TOTE BAG LEVEL . J PREMIUM ( WATERPROOF ) ALA KOREA FASHION WANITA TERBARU IMPORT BATAM SUPERO',
#  '(ORIGINAL) MIRAEL Sugar Waxing Kit Sugar Wax Hair Removal Penghilang Pencukur cukur cabut Bulu',
#  'Makanan Kucing Life Cat Can 400g',
#  'DENORA DRESS Terlaris F.Y',
#  'Kertas watercolour paper Canson A3 200g',
#  'Korean Style Jam Tangan Wanita Transparan Custom',
#  'Jam Weker / Digital Desktop Smart Clock',
#  'Headset Earphone Handsfree Oppo Original',
#  'Sepatu Sneakers Flat Anti Slip Bahan Kanvas dengan Strap',
#  'Adonit jot pro stylus pen drawing android',
#  'TUTUP SILIKON – PENUTUP WADAH SILIKON – SILICONE STRETCH LID -FOOD COVER SILICONE',
#  'BEST SELLER penghitam dashboard motor/mobil PERMANENT 100ml PALING MURAH  Black max',
#  '[GS168] RAK SEPATU 4 SUSUN MOTIF / RAK SEPATU PORTABLE N104',
#  'Tudung Saji Penutup Makanan Penahan Panas Sayur ukuran Large 50x50x20CM KT-033',
#  'Selang Air Taman Magic Hose 30 Meter / Semprotan Air Fleksibel / Selang Air Ajaib 100FT SG-30',
#  'Cussons Baby Mini Bag - Perlengkapan Mandi Bayi',
#  'CELANA PENDEK SANTAI CARGO POLOS DISTRO JALAN PRIA DEWASA / DENGAN KANTONG',
#  'Madame Gie Magnifique Lip Crayon Satin - Lipstik',
#  'Celana joger chinos premium',
#  'Bumbu gule instan bamboe',
#  'Viva Face Tonic Bengkuang 100ml',
#  'WILO DAILY SET',
#  'GELANG Anti Nyamuk BAYI / ANAK LED Gambar Lucu Kartun Untuk Baby dan Anak  JAM anti nyamuk anak',
#  'PaperOne Kertas Fotocopy A4 80gr - 1 Ream (500 lembar)',
#  'Termos kopi Vacum cup',
#  'Panci Mie Stainless Steel Paling Murah',
#  'CUSTOM HOODIE JUMPER UNISEX - NO ONE ASKED',
#  'Dira set by kittyshopgirls',
#  'BERAS SI PULEN LONG GRAIN CRYSTAL 5 KG',
#  'Kunci Shock / sok set 27 Pcs Merek Kenmaster Original',
#  'POP SHOCKET K09 POPSHOCKET RING STAND RINGSTANT HP Aksesoris Handphone',
#  'MCDODO Kabel Charger MICRO USB Gaming Series 90 derajat',
#  '3Pasang Setelan Velvet Junior ZOO TOPIA - Kutung SML.XL.XXL - Celana Pendek .',
#  '6pcs Celana dalam Boxer Pria VI&BB',
#  'Hand Sanitizer 1 Liter BPOM 70% Alkohol Denat',
#  'Margarin Rose Brand 200g margarine',
#  'SENDAL JEPIT WANITA GLANZTON KILAT',
#  'Minyak Kemiri Kukui Original',
#  'HD hitam Kantong plastik kresek hitam LOCO/plastik HD lozo hitam /plastik sampah',
#  'Asus Zenfone Live L2 2/16 GB & 2/32 GB',
#  'REALME 7 / Narzo 20 Pro / Oppo RENO 4F / RENO 4 / RENO 4 PRO / A53 / C11 C12 C15 CASE Slim Black',
#  'Laudya dress by elsire (READY STOK) tile brokat premium dress mutiara gilter busuii',
#  'SOS Hand Sanitizer Antiseptic Botol Spray 100ml',
#  'BBBC Wallpaper dinding Foam 3D Bata Batu Polos Motif Kayu 77x70cm WOOD FOAM KAYU FOAM MURAH',
#  'Headseat / Handsfree / Earphone untuk Xiaomi Piston2',
#  'Mainan Shopping Trolley ( ST003 )',
#  'Tas wanita chale dan keth 2 in 1 / Tas Jinjing / Tas Selempang / Fashion Bag  #10028',
#  'Timbangan Anak Digital Kartun Karakter Doraemon/Helo Kitty Badan Kaca Elektronik 180KG MAX',
#  'Panci Elektrik Multifungsi Advance C-18',
#  'Spidol colour pen CLP-04 Joyko 12 Warna Washable',
#  'KERANJANG BAJU LAUNDRY LIPAT SERBAGUNA CANVAS LAUNDRY BAG',
#  'MASKER KAIN NON MEDIS 3 PLY MOTIF READY STOCK (PART 3) BY AZHANIA',
#  'Pampers Premium Care Pants M46 / M 46',
#  'chandrasurya TUSPIN BUNGA 7 Hijab Jarum Jilbab Aksesoris Wanita Korea Muslim Cantik',
#  'TUSPIN HIJAB PIN PENITI JILBAB FASHION AKSESORIS HIJAB PERAK',
#  'Buku Anak - Cerita Binatang - Dongeng Edukasi Islami - Penerbit Jabal',
#  'A ( A11 )  CIPUT RAJUT KUPLUK/ IKET/ BANDANA/  KUALITAS TERBAIK/ FREE PLASTIK/ TIDAK BISA MEMILIH',
#  'GAMIS WOLFIS BASIC POLOS TERLARIS',
#  'TAS IMPORT TAS FASHION TAS BATAM MURAH TAS WANITA ( PROMO )',
#  'Dodo Soother S 050 with Holder',
#  'b"JOHNSON\'S Baby Powder Blossom 300 gr"',
#  'JILBAB ANAK TOPI HITZ UNTUK USIA 4-8 TAHUN',
#  'Alsyahra Exclusive Niqab Butterfly Hijrah Sifon Silk Jetblack',
#  '[ 15 GR ] MASKER ORGANIK | MASKER WAJAH | FACE MASK | BY LEA GLORIA | 7 VARIAN',
#  'Pohon hias singhonium pink - Tanaman hias rambat - tanaman hias pot gantung',
#  'Mobeo Sarung Setir Kulit Mobil PU Leather Steering Cover Universal 37 cm',
#  'MAXIM Wok 30cm Valentino wajan penggorengan Teflon 30 cm two handle',
#  'b"Hershey\'s Syrup 680 gr"',
#  'Puzzle Matras EVAMAT Angka Tikar Karpet Evamats Playmat Mainan Anak Bayi Murah',
#  'Headset Samsung S8 design by AKG (Superbass)',
#  'Sun Babes Baby Eye Mask Karakter / Kacamata Jemur Bayi',
#  '[BMS Surabaya] Bantex Index (1-10) 26 Holes For Multiring Binder B5 #8608 00',
#  'Perlak Bayi Sugar Baby , Perlak Karet Waterproof Bayi Untuk Ompol , SugarBaby Perlak , Alas Ompol',
#  'Babalil - Teether Rattle stick Mainan Kemericik Bayi / Mainan gigit bayi',
#  'LAMEILA EYESHADOW KODE 3596 LaMeiLa PLAY COLOR EYES EYESHADOW SET 6 COLOR',
#  '[Bayar Di Tempat]Strap Jam Tangan Sport Bahan Nilon Woven 20mm 22mm 24mm untuk Gear S3',
#  'TUTUP MANGKOK SERBAGUNA SILICONE 6 IN 1 STRETCH BOWL COVER LID',
#  'Promo lipstik Shannen creamy lip paint ORI harga Grossir',
#  'Wallpaper dinding sticker 45 cm x 10 m',
#  'REMOT REMOTE SMART TV LG LCD/LED NETFLIX AMAZON AKB75375608 AKB SERIES FOR UK6300 UK7300 Dll',
#  'SWEATER POLOS / SWEATER PB (PB)',
#  'Indoprima 350gr (3 varian)',
#  'SILKORO VITAMIN RAMBUT 80 ML',
#  'Serba Grosir Murah Bando Elastis Bergelombang Bando Rambut Bentuk Gelombang',
#  '❤TOKO MURAH ONLINE❤ Bando Elastis Bergelombang Bando Rambut Bentuk Gelombang',
#  '【Bayar di Tempat】IINS Fashion Mata Kucing Wanita Kacamata Hitam Anti UV400',
#  'JOYKO CLP-04 - 12 PCS WASHABLE MARKER',
#  'Mancis Gas Korek Gas Torch Flame Korek Api Bara Jet Unik Outdoor EDC HMR452',
#  'Element Formula 28 Days Acne Relief Repairing Solution Serum Wajah ELFormula',
#  'SEPATU SAFETY JOGGER TERLARIS OUTDOOR BAHAN KULIT FULL JAHIT CLADICO ROADSTER LOW',
#  'Miyako Kipas Angin KAS 1618 B / Stand Fan 1618B - Biru [16Inch]',
#  'COUPLE ARON MUSLIM TERBARU CP ARON VH1',
#  '10pcs Lampu LED Jagung T10 Senja Kota Sein 5mata 5 Titik Mata Mobil Motor',
#  'Dzikir Pagi & Petang dan Setelah Shalat Fardhu - Darul Haq',
#  'Superseller 10pcs/pak Jepit Rambut Duckbill Motif Kartun Untuk Bayi/Anak Perempuan',
#  'Cussons Baby Cream 50g',
#  'V-SOY MULTI GRAIN 200ML//MILKMART',
#  'Firstsun Pure Essential Fragrance Oils Aromatherapy Diffusers 10ml - TSLM1',
#  'Acne mask 30gr',
#  'Timbangan Gantung Besi 100kg/Timbangan Gantung jarum 100kg',
#  'Sepatu voli mizuno thunderblade 2 MID',
#  'Masker Komedo Masker Gelatin Masker Halal  Masker Organik 3gram',
#  'LITON Knee Support 8628 Deker Pelindung Lutut Elastis 0533',
#  'Dompet Baellerry Ori Model Pendek Lipat Wanita Pria Cewek Cowok Cewe Cowo Kulit Import Branded DP4',
#  'Sprei kintakun 120 100 small single Adalyn, Magali, Inggrid ingrid Leaf, Cornelia, Alamanda',
#  'LED 3 Sisi RTD M02D',
#  '(ECER) Liptint Sasimi Hello Kitty Panjang',
#  '[Per Pc] Liptint Sasimi Doraemon Panjang',
#  'Pipa Leher Jupiter mx New dan Mx Lama',
#  'Minyak Zaitun Rafael Salgado Extra Light Olive Oil 500 ml',
#  'Cream leher dosting whitening arbutin,cream leher dosis tinggi,cream leher original',
#  'Baterai Handphone XiaoMi Redmi Note 3 Pro BM46 Original OEM | Batrai, Batre, Battery, BM 46, Xiao Mi',
#  '[READY JKT]- LAMEILA EYESHADOW 10 CoLour Play colour',
#  'Spons Cuci Piring Spon Polytex',
#  'Polytex Spon Serbaguna',
#  'KARET SABUK AKI RX KING CKD PASS',
#  'Celana Dalam Pria Boxer Rajut - MR DAX UK L,XL',
#  'Huggies Gold Pants M26 / L20 / XL18',
#  '(5-10th) Rysya Koko Kurta Anak Size 6-10',
#  '[LOKAL] DOMMO - D1174 AURORA Tas Selempang Wanita Morymony',
#  'b"ORIGINAL L\'Oreal Paris Revitalift Micronized Centella Essence Water Loreal 130 ML"',
#  'TERMURAH BAJU KOKO KURTA COUPLE LIST HEDLONG PREMIUM',
#  'Twotone Mini Tas Slempang Polos Kombinasi Polos Sling Bag',
#  'isi staples etona no 10',
#  'Speaker mini bluetooth usb Advance TP600 TP 600 (Tanpa micro sd)',
#  'MULES LOVELLY',
#  'Pixy Waterproof Mascara Blue',
#  'Liplapin Lipbalm Tinted ORIGINAL BPOM KEMASAN BARU',
#  'POP SOCKET 3D KARAKTER [SEASON01]',
#  'Kemeja koko anak lengan pendek bahan katun linen',
#  'HARGA PROMO MURAH Solution MPS Ice 60ml Ed 10/2022',
#  'Alkohol Merk Ika 100 ml',
#  'PIXY Waterproof Mascara 7ml',
#  'VALERI JEANS(HW TALI)/CELANA JEANS PANJANG',
#  'chandrasurya TUSPIN PITA Jarum Jilbab Hijab Aksesoris Wanita Muslim Korea Cantik Kerudung',
#  'PROMO Dalaman Jilbab Bandana Rajut 4 Warna / ciput rajut / Random/ACAK #A22B',
#  'Pulpen Gel Kokoro 0.5mm - Bolpen Pena Gel Warna Zebra',
#  'OKHISHOP - Piyama Hotpant HP Satin Velvet',
#  'Daster Manohara/Pilih motif/Dress Adem/Daster Hamil/',
#  'Porto Sandal Jepit Casual Anak Laki-Laki 1028B Size 30-35',
#  'Sorex Bra Busa Kawat kait 2 Setara Cup B Motif Colourful Bunga Rose 19046 Fashion',
#  'SANDAL WANITA SILANG MIKA BULU RASFUR RM 33',
#  'Ricoman Light Brown Sugar/Brown Sugar 500 Gr',
#  'Boci mantap jiwa ori/geprek/korean spicy',
#  'Manset Baju Kaos Polos Uniklo Spandex / Inner Wanita Muslim',
#  'FE1ID Gigi Taring Palsu untuk Kostum / Cosplay nvcw',
#  'TUNIK LOLA/ NINDYA/ OCHA MOSCREPE',
#  'Mommyclopedia 567 Fakta Tentang MPASI - ORIGINAL oleh Dr. Meta Hanindita',
#  'Tes Hamil Onemed Per Strip',
#  'Popok Dewasa Tipe Perekat size XL',
#  '(Gudang1) Softlens Nobluq by urban factory',
#  'READY BEST SELLER! Navina lash silk C dan D curl 0.15- eyelash extension',
#  'Jilbab Al-Hikmah Premium / Jilbab Babat Premium By Fashilah',
#  'One Step Hair Dryer Styler Hot Air Brush Sisir Pengering Rambut 2336',
#  'One Step Sisir Pengering Rambut Hair Dryer Styler Hot Air Brush 2336',
#  'Set 5in1 sedotan stainless straw reusable sedotan ramah lingkungan bisa dicuci ulang',
#  'Sedotan Stainless (1 Paket isi 4 Pcs + Pouch)',
#  'Buku Pintar Berhitung Untuk Anak TK / SD',
#  'Dot Puting Bahan Silikon Model Mulut Lebar',
#  'Gamis Rayon Viscose Ld105 Pb135 Siena',
#  '{COD/Bayar Ditempat} Jaket Jeans Denim Pria M/L/XL/XXL/XXXL',
#  'Earphone PLEXTONE G20 In-Ear Gaming Headset Gaming Plextone G20 Earphone Gaming Headset Plextone G20',
#  'NUTRILON ROYAL 3-4 Vanila/Madu 800gr PROMO JSM',
#  'RAUTAN PENSIL KARAKTER / PERLENGKAPAN ALAT TULIS SEKOLAH',
#  'FREE MASKER & BUBBLE WRAP!! JOK PORTABLE BONCENGAN MOTOR ANAK / JOK SADEL KURSI BONCENG MOTOR',
#  'masker kain 3ply elastis earloop flexible masker import anak-remaja-dewasa motif animal cute lucu',
#  'Dress anak Pony / red strip pony / bahan scuba / usia 2thn s/d dewasa / dress anak import',
#  '5pcs tespek testpack strip tes kehamilan',
#  'pt.yangguangtrading - blueray168 - 1set alat makan + kotak wadah J-01 model serat gandum',
#  'RYO Jayang Yunmo Anti Hair Loss Care Essence 75ml',
#  'SCIENCE MASA DEPAN : Cookie  Run Sweet  Escape Adventure',
#  'Emina sun screen spf pelindung wajah dari matahari',
#  'Tango Wafer Long Cokelat 130gr',
#  'Sandal Swallow Original',
#  'Celery Stick Import China STOCK BARU/ Seledri Stik Impor / Celery Import China',
#  'TEST HAMIL ONEMED - TESTPACK ONE MED',
#  'Skin Aqua UV Moisture Milk SPF 50 40g',
#  'READY Skin Aqua spf 50 PA++',
#  'KOPI BUBUK CAP LIONG BULAN / TANPA GULA // 200 GR',
#  '(Part 1) Mayra instant / hijab mayra instant / hijab instant / bergo instant / khimar instant',
#  'CARDI BUTTON CROP RAJUT',
#  'Miniso Official Frog Soap Holder/gantungan sabun/tempat sabun',
#  'Kabel Lan OUTDOOR FTP CAT5 Kabel UTP 20 Meter Pabrikan High Quality',
#  'Tote bag cantik TULIP BAG / tas wanita / tas bahu / tas kuliah / tas wanita murah /women bag',
#  'JAWHARA DRESS RAYON PREMIUM BANGKOK',
#  'GAMING PSU IMPERION 500W POWER SUPPLY UNIT GAMING 500 WATT 4 PIN VGA',
#  'Pashmina Ceruty Babydoll Import (Jahit Tepi) Part 2',
#  'Eros / Sendok Sayur Stainless Steel SC 504 Kedaung',
#  'Pastry Delight Pancake 200 gram',
#  'celana joger pria list army -jogger pants pria green army-joger cino terbaru murah berkualitas',
#  'ROBOT TRANSFORM POLISI MOBIL BERUBAH JADI ROBOT - KADO MAINAN ANAK',
#  '[FREE ONGKIR ~ COD] WATERPROOF hp ukuran XL',
#  '[JAKARTA] WATERPROOF HP SAFETY XL TAHAN/ANTI AIR KANTONG/POUCH/SARUNG PLASTIK BENING TRANSPARAN',
#  'Listerine Mouthwash All Varian 500ml',
#  'Helm anak sinchan karakter lucu - cip pst',
#  'iPhone 7 7G 8 8G  Kaca Kamera Belakang / Kaca Lensa Back Camera',
#  'Eyebrow Razor / Pisau Pencukur Alis',
#  'CIVETO PF09 MAP Cactus A4 Stationery File Folder',
#  'LACTOGROW 3 dan 4 plain madu vanila 750',
#  'Sepatu Flat Mules Lovelly',
#  'Topi Bayi Rajut / Kupluk Anak Rajut',
#  'IRENE OVERALL MOSCREPE PREMIUM',
#  'Turkish shawl katalog 2 ( Green & brown series )',
#  '[JACK 3.5 mm for IPhone 4 5 6] Genuine Original Apple EarPods Earphone Headset',
#  'cd gt man bw 704 I celana dalam pria merk gt man original full waist brief katun',
#  'PIGEON PERISTALTIC NIPPLE ISI 3 Slim neck /standart neck / NIPPLE PIGEON / DOT BAYI',
#  'BBWORLD Summer Baby Boys Girls Short Sleeve Cartoon Print T-shirt Tops+Shorts Sets',
#  'Konektor PEREKAT RANDOM READY STOK GROSIR',
#  'Spidol Ban Mobil Motor TOYO Karet Car Tyre Paint Marker Toyo Permanent - Putih',
#  'FACE MASK APD SURGICAL MASKER BEDAH SENSI MEDIS 1 BOX ISI 50 PCS HEADLOOP HIJAB ORIGINAL',
#  'Jahe Merah Instan / Seduh Gholiban Kemasan Baru',
#  'Wardah Eyebrow Pencil Black 1.14 G',
#  'ZIARA DRESS',
#  'SECRET STRIKE Essen Pancing Hiu Tikus Aroma Amis - Untuk Umpan Segala Jenis Ikan dan Galatama',
#  'ALFA.ID - SARUNG REMOT MOTIF PITA / PELINDUNG REMOT CONTROL SEDANG DAN KECIL / COVER REMOTE',
#  'Bunga Cherry Blossom Imitasi untuk Dekorasi',
#  'Baggu Bagcu Shopping Bag (Tas Belanja jinjing Modis Lipat Praktis) tas bagcu / tas belanja serbaguna',
#  'Pepsodent Pasta Gigi Action 123 Charcoal 160G\n- ukmmarket',
#  'DUA BELIBIS VALUE SAOS CABE (1kg)',
#  'Alat Pel Q2-103 Busa Keras Berkualitas',
#  'Si Pulen Long Grain Crystal 5 KG',
#  'BEDAK DINGIN BERASTAGI cap ASTAGINA',
#  'Kertas Cellophane Polos 7023',
#  'Honey Twist Snack-Nongshim 75gram',
#  'Pisau Set Gunting Telenan Pisau Buah Pisau Daging Pisau Sayur Pisau Komplit Q2-013P Q2 013P',
#  'Bioderma Sensibio H2O Pump 500 Ml',
#  'Seri Tempo: Chairil Anwar (ORI)',
#  'MIAO Pelindung Kabel - Cord Protector 2 warna',
#  'Hand Mixer Stand Standing Mixer Com 2 IN 1 Cosmos CM-1589 / CM1589 / CM 1589',
#  'VASELINE Superfood Skin Serum Cranberry 200ml',
#  'TERLARIS !! SIAP KIRIM ! RESEP MASAKAN HOMEMADE SNACKS & DESSERTS ALA XANDERS KITCHEN',
#  'Gel Pen Zebra Kokoro 0.5 mm',
#  'Kikkoman Soy Sauce Shoyu 2L',
#  'b"AL-QUR\'AN Terjemahan Perkata Transliterasi Tajwid Warna AL MUMAYYAZ A4 ORIGINAL"',
#  'Philips Avent Bottle Natural 2.0 125ML/4OZ Twin Pack - SCF690/23',
#  'Kitchen Flavor Grain Free ADULT CAT 1.5KG FRESHPACK / Makanan Kucing Kering',
#  'Tas Selempang Wanita Rumbay Fierly',
#  '[SPF 50] Skin Aqua UV Moisture Milk SPF 50 40GR',
#  'Lampu Senja Sein Led Colok Tancap T10 10 mata / titik Motor Mobil',
#  'Masker Motif Kotak "BALI"',
#  'Botol Saos / Kecap / Lion Star Sauce Keeper SK 406 (325 ml) TS 46',
#  'MAULA DRESS MAYOUTFIT (Original)',
#  'Jessen Dodo S-050 Soother With Holder',
#  'Cartridge Filter Air / Sediment 10" - Nano Filter 10 Micron',
#  '13A Karet Lanyard 13mm Karet Gantungan lanyard',
#  'Air Softlens Dream Color I 60mL ORIGINAL / Cairan Dream Color 1 Multi Purpose Solution 60 mL',
#  'BERGO MARYAM KHIMAR ANANTA JUMBO DIAMOND  HIJAB NON PED HIJAB INSTAN',
#  'IU Baby Infant Wide Mouth Bottle Nipples',
#  'Celana Jogger Old Navy Original Lightweight Jersey Knit Jogger',
#  'TASJON Sandal putih - abu abu Size S-M & L-XL',
#  'Goddesskin - Day Cream Whitening',
#  'SANDAL SWALLOW ASLI ( HIJAU ) ( UK 10.5 ) JEPIT KARET GROSIR TERMURAH',
#  'POP SOCKET POLOS  POP SOCKET MURAHPop Socket Polos - Pop Clip Warna Standing HP Popsockets (acp.id)',
#  '[1KG 30PCS] JOLIECOLLECTIONS GELANG NON LED ANTI NYAMUK STRAP SILIKON ANTI NYAMUK MOSQUITO REPELLENT',
#  'Buku Quantum Ikhlas Updated + Cd by Erbe Sentanu',
#  'NATURE REPUBLIC Fresh Herb Snail Cleansing Foam',
#  'Kings - H713 Kotak Sepatu Lipat Serbaguna / Tempat Penyimpanan Sandal / Shoes Storage Box',
#  'EZ Engrave It / Alat Ukir / Pengukir Grafir Kain Kayu Besi / Engrave Ukiran / Engraver pen',
#  'Kiddy Food Maker 7 in 1 Set',
#  '(IZIN BPOM) PARFUM BAYI SWITSBABY 35ML + BOX BONUS POUCH',
#  'ORIGINAL Pure Kids Fever Free Isi 4 lembar cooling patch gel BPOM / Fever Free Pure Baby / LEDI MART',
#  'Blouse combin absnot',
#  'Safi Age Defy Beetox Makeup Remover 100ml',
#  'TAS RANSEL DAYPACK CONSINA GOCTA 30L ORIGINAL OUTDOOR',
#  'BAJU KOKO MUSLIM MODERN LENGAN PENDEK KOKO BATIK FULL KATUN ADEM SRIKAHA',
#  'sepasang sarung tangan cuci piring',
#  'Dapur Ijah Bumbu Opor 50gr',
#  'Matoh Keripik Singkong Rasa Sea Salt 75g',
#  'OX-926 - Pembuka Botol dan Kaleng Oxone',
#  'Balon pastel perpack 12inch',
#  'Wardah Everyday Luminous Liquid Foundation 02 Light Beige 40 ml',
#  'Goddesskin - Night Cream Acne',
#  'Cream leher dosting whitening, cream leher arbutin, cream. Leher pot hitam original bpom',
#  'Jam Dinding DIY Besar 130cm',
#  'Bonibol Cokelat Bola Toples isi 4 Toples @ 250 gram PAKET LEBARAN',
#  'Momogi Box isi 20 pcs',
#  'New Face Shield Kacamata Anak Karakter',
#  'Face shield kacamata anak karakter',
#  '(COD) Kedas Beauty/ Body Serum Kedas Beauty / Body Serum Kedas',
#  'RAK DAPUR PORTABLE SUSUN 2 / RAK BAWAH WASTAFEL DAPUR KITCHEN RACK RUANG MAKAN SERBAGUNA STAINLESS',
#  'Banana Boat Sunblock Sport SPF 50 90 mL',
#  'DREAMHOME Promo Termurah Wallpaper Dinding Dapur dan Kamar Mandi Anti dan Minyak Anti Air 45CM X 5M',
#  'HABBATUSAUDA ORGINAL TRIGONA  200kp / EXTRAFIT',
#  'Masker sensi isi 50 3ply earloopp',
#  'V00P00 VINCI AIR  AUTHENTIC',
#  'Puzzle 3D Animal Wooden Puzzle Anak Puzzle Binatang Mainan Edukasi Wooden Toys Puzzle Kayu',
#  'Batrai jam tangan maxell | 626 |  realpic, harga murah, cocok untuk semua jam tangan',
#  'Batik Couple 2564 Mahardani Brukat IPNU IPPNU Manuk Lawasan Cekeran',
#  'Set cover GKM / Set sarung galon kulkas magicom',
#  'Wardah Eyebrow Pencil Brown 1.14 / pensil alis warna coklat [SLO] [SLO]',
#  'Balon Pastel Perpack 12 INCH',
#  'Velvet Junior Masker Kain 2 Lapis Anak dan Dewasa Bamboo Katun',
#  'Kenmaster Kunci Sok Socket Kunci Set Motor 27 Pcs',
#  'Kenmaster Socket Wrench Set 27pcs Kunci Sok 27 Sockets',
#  'HERBAL ESSENCES Shampoo Colour Me Happy 300ml',
#  'BOLDë Set Sendok Masak + Tempat Sendok / Super Utensilë 7 Pcs - Beige',
#  'HOPYLOVY - Kemeja Wanita Fringe Loose jeans 6208',
#  'Ottogi Cheese Ramen 보들보들 치즈라면',
#  'Buavita Orange 250Ml vit C & A',
#  '(KK) SABUK GESPER TACTICAL MILITARY',
#  'NEW Holder Nano Gel Pad Mobile Phone Holder Transparan Holder Tempel Multi Fungsi',
#  'Snager Triangle Shelf Rak Sudut Pojok Tempat Sabun Tempel Serbaguna',
#  'Netral matrix Optistraight 500ml',
#  'Body Scrub Bibit Pemutih Lulur Bibit Pemutih Lulur SYB Scrub SYB Pemutih Badan Lulur Badan',
#  'Daster arab flora motif by fairuz ori',
#  'SET HIMARU / SETELAN WANITA HIMARU / SETELAN SEHARI-HARI / STELAN PESTA ARISAN / BEST SELLER IMJ',
#  'Arirang Spicy Bibim Ramyun Fried Noodle 135gr HALAL',
#  'Humidifier Deerma F600 5L Air Touch Screen Version Ultrasonic',
#  'Pop Socket 3D Karakter',
#  'avail day use',
#  'Consina Waist Bag Coda',
#  'MANGKOK KUAS MASKER  4in1 mask bowl set',
#  'Hand grip Foam Fitness Untuk memperkuat Tangan Original Speeds 011-05 isi 2 pcs,6bag=1.3kg',
#  'SPEEDS LX 011-5 HANDGRIP HAND GRIP ISI 2PCS LATIHAN TANGAN',
#  'Kuas Kue Barbeque/ Silicone Food Brush',
#  'J31- WALLPAPER 3D FOAM MODEL BATU BATA Uk 70 x 77cm TERMURAH GROSIRAN wall sticker interior',
#  'Asigen Collagen Milk Almond Almon Booster - Susu Pelancar Asi Kolagen Booster Asi 170gr 170 gr',
#  'TOPLES KACA TOPLES CUPANG TOPLES SERBAGUNA JAR TOPLES BOTOL CUPANG SOLITER AQUASCEF OVALTINE',
#  'Meihuadeer litepro MTB Road Bike Folding Bicycle Square Hole Left Right Chainring Crank Arm',
#  '(FREE POUCH MIN PEMBELIAN 3) SAFRON CALENDULA SOAP BAR',
#  'Nayz Puding Box Coklat',
#  'SMST Celana Chino Motz Reguler',
#  'SANDAL KEREN PRIA OFF WHITE FULL BLACK PREMIUM / SLIP ON SANDAL SANDAL SLIDE SANDAL SLOP RUBBER TOP!',
#  'STP sarung tangan plastik sepasang',
#  'HADA LABO GOKUJYUN ULTIMATE MOISTURIZING LIGHT LOTION 100ml (GARIS HIJAU)',
#  'Madame Gie N-Moji Earth Series (Satuan) - MakeUp',
#  'kaos dalam bayi KIKI 1 lusin',
#  'Longtop polos(LP)',
#  'Kertas lakmus 80 pcs suncare ph paper 80 strip blue red litmus paper cek tes air ketuban [PH80]',
#  'Pintar Facil Paint Roller / Kuas Cat Tembok Rumah',
#  'New IPad 2017 2018 2019 IPad 2 3 4 Pro 9.7 10.2 10.5 Mini 1 2 3 4 5 Air 1/2/3 Case, Smart Case Flexible Soft TPU Cover',
#  'Keju Mozarella Perfetto 1kg repack',
#  'SEPATU KELSEY AYFN99',
#  'Laurier Active Day Double Comfort 28',
#  'Set Alat Makan sendok sumpit garpu (Saran terhindar penyakit menular) ACC335',
#  'Skic 10pcs/set Jepit Rambut Duckbill Motif Kartun Untuk Anak Perempuan',
#  '[LOKAL] FOREVER YOUNG - D1154 TOTEBAG NEW - Tote Bag Wanita JAKARTA Tas Tore BISA COD BAYAR DITEMPAT',
#  'Joran Relix Nusantara Capung 662 UL 1-5 lb',
#  'Aida Kids / Gamis Syari Anak / Best Seller',
#  'Aida Kids | Gamis Syari Anak | Baju Muslim Anak Perempuan',
#  'Aida Kids | Baju Gamis Muslim Anak | Fashion Anak',
#  'BEST SELLER SUPER CUTE Aida kids syari | Baju Setelan Muslim Anak',
#  'Tas Sekolah anak/Taskuliah/taspunggung/ Tasvanessa/ tasanak/tasmain/ tasgaya/ tasmurah/ tassekolah 1',
#  'BEST SELLER!! Susu Almond Lactamond Bubuk /Premium 5x minum/ ASI Booster Minuman Pelancar',
#  'SanDisk Flashdisk USB 3.0 Cruzer Glide CZ600 - 256GB',
#  'Speaker Bluetooth JBL TG-113 Tabung Portable',
#  'Mainan Anak musik animal piano farm lampu',
#  'Handgrip grip handfat carbon kitaco',
#  'xvf-153 (3roll 2kg khusus JNE) Wallpaper dinding salur biru,hijau,pink,rainbow ukuran 45cm*10m ^^',
#  'Songkok peci Bordir Logo NU Tinggi 9 & 10',
#  'Bioderma Sensibio H2O Micellar Water 500ml with Pump',
#  'Kabel Data K2 PREMIUM QUALITY K2-C08 GAMING LED USB 2M',
#  'Cussons baby gift bag set MEDIUM dan MINI perlengkapan mandi bayi',
#  'NA Gunting Kuku Karakter / Cartoon Nail Clipper / Nail Clipper',
#  'Doublepow Chargera baterai 4 slot Plus baterai AA/AAA 1200 mah',
#  'Sendok teh kecil',
#  'cuanki INSTAN POUCH PORSI MANGKUK gaiarasa NUNGEUNAH khas garut rasa mantab BISA GROSIR by GAIA',
#  'FREE BUBBLE WRAP!! JOK PORTABLE MULTIFUNGSI KURSI BONCENGAN MOTOR ANAK/ JOK SADEL MOTOR',
#  'Pengaman Pengunci Lemari Laci Kulkas Drawer Safety Belt Lock Model Kain Dari Anak Bayi Baby',
#  'Mediheal Face Mask Pack 10pcs (12 Type)',
#  '[1 Paket] BEAUTY IN THE POT - SKINCARE WHITEGLOW SERIES (COD)',
#  'Dove Creambath - Hair Growth Ritual 30G',
#  'Tanaman hias mawar batik/candy',
#  'SOMEBYMI SNAIL TRUECICA Miracle Repair TONER 135ml',
#  'HF handsfree earphone headset hp samsung S8+ design by AKG Original',
#  'DZIKIR PAGI & PETANG DAN SETELAH SHALAT FARDHU - Sa’id Al-Qahthani',
#  'Herbal Essences Colour Me happy Colour Safe Shampo 300 ml',
#  'MICROFIBER CLOTH 35cm x 35 cm / Kain Lap Micro Fiber Serat Tebal Halus / High Quality / Mobil Motor',
#  'Nano Gel Pad Phone Holder Nanotechnology Gel Pad SerbaGuna Holder Nano',
#  'pompa galon elektrik air minum recharge GEN 4 KODE K7',
#  'Ringlight/ Lampu Selfie Led/ Ring Light',
#  'Sebamed Baby Protective Facial Cream 50ml',
#  'SGM EKSPLOR 1+ 900GR',
#  'Hlg Cetakan Semen Reusable Bahan Batu',
#  'Diamond Pastry Delight Pancake 200 gr',
#  'WW Celana Dalam GT MAN - GSF01 - Pakaian Dalam Pria - Isi 2 pcs - Brief Spandex',
#  '[BELI 5 FREE SPATULA] Masker Organik acone Petal Mask Aconeskin safron rose calendula',
#  'MOMMYCLOPEDIA 567 FAKTA TENTANG MPASI',
#  'BELI 1 GRATIS 1 DOMPET HEADSET DOMPET KOIN DOMPET EARPHONE',
#  'GELPAD Nano Gel Gripping Pad Stick Holder Multi Fungsi Nano Technology',
#  'Mainan alat perkakas anak lelaki bahan kayu - wooden tools set - mainan edukasi',
#  '[BPOM] Pure Kids Fever Free Isi 4 lembar Cooling Patch Gel / Pure BB Fever Free Pure Baby / MY MOM',
#  'EMINA Star Lash Aqua Mascara 5g',
#  '⭐ New Real Bordir Tunik FULL WARNA Termurah Khadijah Syari Gamis Set Jilbab #belanjadarirumah',
#  'Rak Sudut Serbaguna (untuk kamar mandi, atau tempat bumbu dll)',
#  'Paket 1 Cleaner FAAZ 250ml',
#  'KIT WIPER FLUID 400ml',
#  'Grosir BUCKET HAT Premium TERLARIS Topi Rimba Motif Bolak Balik Polos kpop Prt2',
#  'b"Bayar Di Tempat✔SKMEI Jam Tangan Wanita Fashion Square Casual Women\'s Aniti Air Watch"',
#  'Sling Bag Flicka Kode DD 178 MUSTARD',
#  'Set Pakaian Musim Panas Bayi Perempuan Katun Lengan Pendek Kartun 5 Warna',
#  'LACTOGROW 3 / 4 MADU/VANILA/PLAIN 750g',
#  'Tenda dome camping Lipat automatis 2-3 orang anti uv Waterproof 018-13',
#  'Set 2Pcs Kaos T-Shirt Lengan Pendek Gambar Kartun Kucing dan Celana Warna Pink',
#  '[SELLER VIP] JELLY MASK RAECCA/ MASKER JELLY/ SLEEPING MASK 50GR/ JELLY MASK PETALS',
#  'Sustagen Kid Madu 800gr',
#  'Sarung tangan cuci piring Sarung tangan silikon Magic gloves POLOS',
#  'VIV TURUN HARGA STELAN KULOT HIMARU',
#  'MOKERU Semir Herbal Warna Cat Rambut',
#  'CUSSONS BABY Cream Soft & And Smooth/Krim Bayi  CUSSONS BABY Soft & And Smooth 50 gr 50gr 50 gram',
#  'Nutrilon Royal 4 Vanila Susu Pertumbuhan Bubuk 800 gr',
#  'WILO DAILY SET / ONE SET RAYON / SETCEL',
#  'MIX NATURAL MASK BY ASEYORIKU',
#  'Tes kehamilan / testpack One med',
#  'Homey Dress Rayon Bangkok Motif Rusa',
#  'MOKERU SEMIR (Ready stock) HERBAL SHAMPOO MOKERU SHAMPOO WARNA CAT RAMBUT',
#  '[BS] BISA COD Pop Socket BTS BT21 KPOP Phone Holder Grip Popsocket HE001',
#  '[ SET Alat Jahit ] Peralatan Mesin Jahit/BENANG JARUM Lengkap Sewing Box SAJ08/SAJ10',
#  'Faaz Porcelain Cleaner',
#  'Mata Bor Set Kenmaster Besi Kayu Beton Obeng Fischer Murah',
#  'Timbangan Badan Digital 180kg Desain Kartun / karakter Doraemon Hellokitty Murah..',
#  '(2-5thn) Koko Kurta Anak Kids Size Rysya',
#  'Sarung ANAK GAJAH MANGGIS JUNIOR Satuan/Grosir',
#  'Wireless Door Chime Bell / Bel Pintu Rumah Tanpa Kabel V-ZORR 32 Musik',
#  'Sorex Bra 3/4 Cup Rainbow Collection BH 11148 kawat Busa Sedang Kait 2 Cup Setara Cup B',
#  '[ ECER ] Refill Isi Pulpen Frixion Pilot 0.7/0.5',
#  'CHINO PANJANG',
#  'Meja Lipat Belajar,ngaji,laptop simple 6030',
#  'SAMPO KUCING SHAMPO KUCING',
#  'Mic Speaker Bluetooth karaoke',
#  'Test hamil kehamilan test pack Onemed pregnancy test onemed',
#  'Bamboe Bumbu Gule 35g',
#  'MINI CASH REGISTER LS820A2 MESIN KASIRAN MAINAN EDUKASI ANAK',
#  'Kepala Shower Aerator Air Soft Halus Lembut 300 Lubang Low Preasure',
#  'Novel - SENJA & PAGI',
#  'TERMOS KOPI / TERMOS AIR PANAS COFFEE 380ML HOT N COLD COFFE THERMOS',
#  'BH SOREX #READY 34 & 36# BUSA SEDANG & KAWAT # 19046 #',
#  'ORIGINAL FONGE S500 Sport IEM - Earphone with MIC',
#  'KULIT JOK CARBON BIKER BEAT BEAT FI SCOOPY VARIO DLL',
#  'Matahari - Nevada Slip On Bow Wh84 - Pastel Pink',
#  'DC090 ( Part 2 ) Mainan Puzzle Jigsaw Edukasi Anak Motif Hewan, Alat Transportasi dan Buah Buahan',
#  '3M VHB 12mm x 4.5m Double Tape Foam Merah Otomotif & Building ORI',
#  'Sport Earphone Stereo Bass Waterproof with Microphone',
#  'Pop Girl l Sweater Wanita Terbaru',
#  'Humidifier Air Aromaterapi Difuser Pelembab Penjernih Udara Air Purifier Atomizer 1000ml',
#  'Penggaris besi Rl-st15 stainless steel ruler 15cm Joyko',
#  'ORI Ecer LANEIGE Water Sleeping Mask Lavender Laneige Eye Sleeping Mask Laneige Lip Sleeping Maskt',
#  'ICE AIR SOFLENS 60 ml',
#  'TOUCHSCREEN TS LAYAR HP TOUCH SCREEN REDMI4A GLASS XIAOMI REDMI 4A  MI4A ORIGINAL',
#  'NEW RIB Turtle neck (Premium) Ribb kerah Berdiri/ turtle nex full catton  terlaris',
#  'Nano Magic Spons Cuci Pembersih Kerak Noda Panci Piring Penggorengan',
#  'Wallpaper dapur anti minyak & tahan air ukuran 45cm×5m / wallpaper dinding dapur 1kg muat 3pcs',
#  'VETTO Stop Kontak Timer Digital Listrik - 1 Minggu',
#  'Lock&Lock Interlock Grain Bottle',
#  'Brush Set Tube Kuas Rias Make Up 12 Pcs Kuas Make Up Foundation Brush Free Tabung Love',
#  'Pompa Galon Elektrik Otomatis Dispenser Air Minum Higienis USB Rechargeable',
#  'RAKET NYAMUK / TEPOK NYAMUK LISTRIK PEMBASMI NYAMUK LED LAMPU MERAH',
#  'SOFTLENS X2 BIO COLOR / X2 BIO COLOUR HAZEL / BLUE / GREY / SOFTLENS X2 TERMURAH / GROSIR SOFTLENS',
#  'DH - Promo Termurah Matras Anak Matras Playmat Anti Air/Waterproof 2 Sisi (Bolak Balik Beda Corak)',
#  'Cod Testpack Kehamilan Onemed Sensitif Test Pack Hamil Tespek Kehamilan Bisa Grab Promo Cod',
#  'Lameila Play Color Eyes Eyeshadow 10 colors',
#  'DASTER VIRAL',
#  'DapurCantik Spatula Silikon Besar Food Grade Pengaduk Adonan Tahan Panas Anti Lengket - SPAB',
#  '[ Spesial Harga Grosir ] Baju Couple Set l COUPLE ARON',
#  'Cardigan Rajut Wanita Cemerom  Cardi Cameron Outer Knit  Cardigan Wanita Grosir Cardigan Oversize',
#  'Grosir - H690 Rak Jaring Wastafel Sponge Cuci Piring / Perlengkapan Rumah / Homeware / Rak Wastafel',
#  'E97 Lampu tembak LED Bar CREE 6 mata titik worklight Offroad',
#  '3Pasang Setelan Velvet Junior MACHU PICHU - Kutung SML - Celana Pendek',
#  'Plastik vacuum 15x20 cm (100 lbr)',
#  'BERGO LENGAN AZIZAH / BERGO SYARI PAD BUSA ANTEM BERLENGAN BAHAN JERSEY ZOYA',
#  'JILBAB INSTAN ADIBA SERUT JOKOWI POLOS murah | Jilbab Serut Polos | Jilbab Serut | Pet tali',
#  'GRATIS TASBIH ALQURAN EDISI DIAN SASTRO DUSTY PINK - ALQURAN WAKAF TERBITAN ALQURAN EMAS',
#  'MOSEHAT Obat Herbal Ampuh Berkhasiat',
#  'Gamis rayon kancing Ld105 pb135 camelia',
#  'ELFORMULA 28 Days Miracle Whitening Solution Serum Wajah Element Formula Pencerah Wajah Glowing',
#  '❤ BELIA ❤ Masker Organik Premium by LEA Gloria 15g | Face Mask Lea masker bubuk face mask',
#  'Kuas Silikon Roti silicone Cake barbecue Mentega Food Brush KT-05',
#  'Sarung ABG mbak santri motif bola',
#  'Bel Pintu Rumah Tanpa Kabel GP-1766 32 Musik - Wireless Door Chime Bell',
#  'JBL Clip 3 Portable Bluetooth Speaker',
#  'b"Buku Homemade Snacks Desserts Ala Xander\'S Kitchen  ( SC ) & Home Cooking Ala Xanders"',
#  'Imperion Gaming Power Supply PSU 500W',
#  'Miniso Official Soap Holder Tempat Penyimpanan Sabun (Hijau) (01MN-4419)',
#  'Carrera spon sabut mobil',
#  'Pisau Set Talenan Telenan Knife Set Q2 013 P / Q2-013P / Q2 013P',
#  'Silver Queen Chunky Bar 33 Gram . SilverQueen',
#  'SOS HAND SANITIZER ANTISEPTIC SPRAY 100 ML  / ANTISEPTIK',
#  'TERMURAH!!! Sarung anak gajah manggis lembut & nyaman dipakai',
#  'pop socket polos + pack plastik slot clip grip stand phone holder popsocket non hook warna universal',
#  'Jam Weker Digital / Digital Desktop Smart Clock',
#  '【GOGOMART】Buku Brankas / Safety Box - Size M 24.4 x 15.8 x 5.5 cm',
#  'Wallpaper Dinding Stiker Embos Gold Biru 45 cm x 10 m',
#  'SPEAKER BLUETOOTH MINI SPEAKER WIRELESS PORTABLE MINI G2',
#  '✅ BUY 9 GET 10 POUPEEPOU + FREE ONGKIR⭐️ Masker Organik 25 Gram By / Face Organic Original / COD',
#  'Kertas - Paper one - A4 80Gsm - PO',
#  'FILM WATER TRANSFER PRINTING SC-C82 UK 100X50CM',
#  'Totebag Good Luck',
#  'Niqab Butterfly Hijrah Alsyahra Exclusive Sifon Silk Arab',
#  'SPEAKER BLUETOOTH Mini G2 Speaker Termurah',
#  'MM - Handsfree headset earphone bando J XB-450 extra bass / earphone J XB 450 stereo headphones',
#  'Animal Farm Piano Mainan Piano dengan aneka musik ceria - A003',
#  'Safecare Telon Aromatherapy 10ml',
#  'TINTED LIPBALM BY TROPICAL SENSATIANS',
#  'Nivea Extra White Radiant & Smooth Cream 100ml',
#  'catok nova mini 2 in 1 2009',
#  '10 Lembar Stiker Motif Smile/Wajah Tersenyum',
#  'SAFFRON CALENDULA SOAP AZLOE.ID',
#  'TOBELO COKLAT GOLDEN BALLS 45pcs',
#  'TERMURAHHH!!! CH NL BOY',
#  '1pcs CB280 celana dalam wanita dewasa import bahan katun spandek polos simple size L dan XL',
#  'Revlon Touch & Glow Face Powder [24 g] - Creamy Ivory 038',
#  'SEPATU SNEAKERS KELSEY GS102',
#  'Pelindung Kabel Spiral Charger Universal Kabel Pelindung Cord Protector Universal Pelilit Cable',
#  'PANTENE Hair Conditioner Total Damage Care 3 Minute Miracle 180 ml',
#  'MIRANDA TUNIK SALUR FIT XXL',
#  'CERMIN LED MINI FAN kipas karakter / Kipas Mini Portabel Cermin led',
#  'BUMBU BAMBOE - BUMBU INSTAN BALADO',
#  'Mesin alat cukur rambut happy king Hk 900 / cukuran rambut HK900',
#  'Kaos Polos Tangan Pendek Soft Cotton Combed 30s Berkualitas - Female Model',
#  'otg audio jack 3.5mm',
#  '[PIPO MEDAN 6 PCs 60 YARD] PIPO Lakban murah kualitas bagus panjang 60 yard 2 inch isi 6 Pcs',
#  'RAQUNI MAXY /GAMIS RAYON VISCOSE TERMURAH',
#  'Stroller Bayi Pliko Adventure 2 / Kereta Bayi / Stroler Bayi Murah',
#  'opp plastik/plastik kaca lem 15x25 (isi 100 lembar)',
#  'opp plastik/plastik kaca lem 16x25 (isi 100 lembar)',
#  'NA Set Alat Makan 3 in 1 Serat Gandum / Wheat Cutlery Set 3 in 1',
#  'PTT WALLPAPER DINDING FOAM  3D BATA BATU POLOS MOTIF KAYU 77x70cm WOOD FOAM KAYU FOAM MURAH',
#  'Holder HP Jepit AC Mobil Holder AC Car Mount the Ventilation',
#  'Papan Tulis Anak Karakter + Bonus Spidol (Lengkap Penghapus)',
#  'b"Nutrisari Jeruk Nipis 10\'s"',
#  'MFcollection - Tshirt Rainbow List (Kaos Pelangi)',
#  'ID BOLA KARET BASKET 5016 - MAINAN BOLA BASKET',
#  'Mommyclopedia 567 Fakta Tentang Mpasi',
#  'AZARINE EASY WHITE HERBAL MOISTURIZER SERUM 20 ml',
#  'DASTER VIRAL RUFFLE || DASTER RAYON PREMIUM',
#  'Baby care kit/10 set perlengkapan bayi/kado lahiran/newborn gift set/health care set HLT10',
#  'Coklat tobelo golden Ball isi 45',
#  'Gula Halus cap Segi Tiga Emas 250gr',
#  'Mukena Couple ibu dan anak shabby katun jepang safira murah',
#  'BIB / SLABBER SILIKON PLASTIK / CELEMEK MAKAN BAYI ANTI AIR / SLABBER SILIKON BAYI',
#  '1 KG MUAT 4 PCS | LIRA OVERALL / OVERALL WOLFIS / OVERALL POLOS / OVERALL SELEBGRAM',
#  '( TERLARIS ) MASKER KOMEDO / MASKER GELATIN KEMASAN 3gr',
#  'b"DRESS MUSLIM MURAH HAYLA DRESS \'"',
#  'TOPI JEPANG TOPI MASKER TOPI MANCING TOPI PROYEK TOPI KEBUN TOPI PETANI TOPI JEPANG MURAH',
#  'Jilbab Voal Motif Art Premium Square Lasercut Edition , Hijab Segi empat Motif ,Grosir Murah Bandung',
#  '[BPOM] Cussons Gift Bag Mini Cussons Baby Mini Bag Set /',
#  'Penjepit bulu mata magnetik/Alat bantu pasang bulu mata magnetik/Magnetic Eyelashes Applicator',
#  'Real Bubee Pompa ASI Manual Breast Pump BPA Free Powerful Nipple Suction Pumps 150ml',
#  'TOUCHSCREEN ORI TS LAYAR SENTUH HP SCREEN KACA DEPAN ORIGINAL GLASS  XIAOMI REDMI 4A',
#  'FYGALERYJAKARTA - HL0089 Pulpen Emoticon Goyang Per Karakter Gel Unik Lucu Pena Emoji Goyang Import',
#  'Nongshim Honey Twist 75 gr',
#  'Mifa K3 TWS Bluetooth Speaker Stereo Mini TV Soundbar 5Wx2',
#  'Seruni Living  Masker Hijab Kain Motif Bunga (headloop)',
#  'ZPT Hormon HANTU  repack 100 ml - Hantu multiguna tutup biru - hormon organik',
#  'Kojie San Dream White Anti- Aging Facial Toner',
#  'xxfake',
#  'xxfake']

# %%
b
# Out:
# TensorText([[176, 280,  10],
#         [  0,   0,   9],
#         [  0,   0,   9],
#         [641,   0,   9],
#         [397, 338,   9],
#         [  0,   0,  10],
#         [  0,   0,  10],
#         [  0,   0,   9]], device='cuda:0')

# %%
@typedispatch
def show_batch(x:SiameseText, 
               y, 
               samples, 
               ctxs=None, 
               max_n=6, 
               nrows=None, 
               ncols=2, 
               figsize=None, 
               **kwargs
              ):
    if figsize is None: 
        figsize = (ncols*6, max_n//ncols * 3)
    for i,ctx in enumerate(ctxs): 
        SiameseText(x[0][i], x[1][i], ['Not similar','Similar'][x[2][i].item()]).show(ctx=ctx)

# %%
dls.show_batch()

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x1, x2):
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
encoder = create_body(resnet34, cut=-2)

# %%
head = create_head(512*2, 2, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
def loss_func(out, targ):
    return CrossEntropyLossFlat()(out, targ.long())

# %%
learn = Learner(dls,
                model,
                #loss_func = loss_func,
                loss_func = CrossEntropyLossFlat(),
                splitter = siamese_splitter,
                metrics = accuracy
               )

# %%
learn.freeze()

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(7, 3e-3)

# %%
learn.save('full_df_224_frozen_7epos')

# %%
learn.load('full_df_224_frozen_7epos')

# %%
learn.unfreeze()

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(5, slice(5e-7,1e-4))

# %%
@typedispatch
def show_results(x:SiameseImage, 
                 y, 
                 samples, 
                 outs, 
                 ctxs=None, 
                 max_n=6, 
                 nrows=None, 
                 ncols=2, 
                 figsize=None, 
                 **kwargs                
                ):
    if figsize is None: 
        figsize = (ncols*6, max_n//ncols * 3)
        
    if ctxs is None: 
        ctxs = get_grid(min(x[0].shape[0], max_n), nrows=None, ncols=ncols, figsize=figsize)
        
    for i,ctx in enumerate(ctxs):
        title = f'Actual: {["Not similar","Similar"][int(x[2][i].item())]} \n Prediction: {["Not similar","Similar"][y[2][i].argmax().item()]}'
        SiameseImage(x[0][i], x[1][i], title).show(ctx=ctx)

# %%
learn.show_results()

# %%
preds = learn.get_preds()

# %%
print(type(preds[1]))

# %%
len(preds[1]), preds[1].sum()

# %%
@patch
def siampredict(self:Learner, item, rm_type_tfms=None, with_input=False):
    res = self.predict(item, rm_type_tfms=None, with_input=False)
    if res[0] == tensor(0):
        SiameseImage(item[0], item[1], 'Prediction: Not similar').show()
    else:
        SiameseImage(item[0], item[1], 'Prediction: Similar').show()
    return res

# %%
imgtest = PILImage.create(files[0])
imgval = PILImage.create(files[100])
siamtest = SiameseImage(imgval, imgtest)
siamtest.show();

# %%
res = learn.siampredict(siamtest)
